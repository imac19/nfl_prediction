# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
# Import data

qb = pd.read_csv('../modeling/pass_offense_value_modeling_v2/passing_value_model_v2_data/passing_with_value.csv')
qb = qb.drop(columns = ['Unnamed: 0'])
rb = pd.read_csv('../modeling/rush_offense_value_modeling_v2/rushing_value_model_v2_data/rushing_with_value.csv')
rb = rb.drop(columns = ['Unnamed: 0'])
pass_def = pd.read_csv('../modeling/pass_defense_value_modeling_v2/passing_defense_value_model_v2_data/pass_def_with_value.csv')
pass_def = pass_def.drop(columns = ['Unnamed: 0'])
rush_def = pd.read_csv('../modeling/rush_defense_value_modeling_v2/rush_defense_value_model_v2_data/rush_def_with_value.csv')
rush_def = rush_def.drop(columns = ['Unnamed: 0'])

# %%
# Put data into one data frame that just has the game identifiers and value numbers

qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'passing_value']]
# rb = rb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rushing_value', 'qb_rushing_value_pct']]
rb = rb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rushing_value']]
rb['qb_rushing_value_pct'] = 0
pass_def = pass_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'pass_def_value']]
rush_def = rush_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rush_def_value']]
df = qb.copy()
df = df.merge(rb).merge(pass_def).merge(rush_def)
df = df.drop_duplicates()
df.head()
# Out:
#    season  week team opponent  score  opponent_score           qb  \
# 0    2014     1  ARI      LAC     18              17    C. Palmer
# 1    2014     1  ATL       NO     37              34      M. Ryan
# 2    2014     1  BAL      CIN     16              23    J. Flacco
# 3    2014     1  BUF      CHI     23              20    E. Manuel
# 4    2014     1  CAR       TB     20              14  D. Anderson
#
#    passing_value  rushing_value  qb_rushing_value_pct  pass_def_value  \
# 0       0.472651      -1.258735                     0       -0.014745
# 1       1.515659       0.682493                     0        0.748551
# 2      -0.552992       0.180459                     0        0.934747
# 3      -0.063069       1.014793                     0       -0.700995
# 4       0.690009      -0.984362                     0       -1.035469
#
#    rush_def_value
# 0       -1.468394
# 1        1.005162
# 2       -0.727127
# 3        0.187514
# 4        0.392165

# %%
# Fix team names

def fix_team_names(game, is_team=True):
    team_mapping = {
        'ARI':'Arizona Cardinals',
        'ATL':'Atlanta Falcons',
        'BAL':'Baltimore Ravens',
        'BUF':'Buffalo Bills',
        'CAR':'Carolina Panthers',
        'CHI':'Chicago Bears',
        'CIN':'Cincinnati Bengals',
        'CLE':'Cleveland Browns',
        'DAL':'Dallas Cowboys',
        'DEN':'Denver Broncos',
        'DET':'Detroit Lions',
        'GB':'Green Bay Packers',
        'HOU':'Houston Texans',
        'IND':'Indianapolis Colts',
        'JAX':'Jacksonville Jaguars',
        'KC':'Kansas City Chiefs',
        'OAK':'Las Vegas Raiders',
        'LV':'Las Vegas Raiders',
        'LAC':'Los Angeles Chargers',
        'LAR':'Los Angeles Rams',
        'LA':'Los Angeles Rams',
        'MIA':'Miami Dolphins',
        'MIN':'Minnesota Vikings',
        'NE':'New England Patriots',
        'NO':'New Orleans Saints',
        'NYG':'New York Giants',
        'NYJ':'New York Jets',
        'PHI':'Philadelphia Eagles',
        'PIT':'Pittsburgh Steelers',
        'SF':'San Francisco 49ers',
        'SEA':'Seattle Seahawks',
        'TB':'Tampa Bay Buccaneers',
        'TEN':'Tennessee Titans',
        'WSH':'Washington Football Team',
        'WAS':'Washington Football Team'
    }
    
    if is_team:
        return team_mapping[game['team']]
    
    else:
        return team_mapping[game['opponent']]
    
df['team_full'] = df.apply(lambda x: fix_team_names(x, is_team=True), axis=1)
df['opponent_full'] = df.apply(lambda x: fix_team_names(x, is_team=False), axis=1)
df.head()
# Out:
#    season  week team opponent  score  opponent_score           qb  \
# 0    2014     1  ARI      LAC     18              17    C. Palmer
# 1    2014     1  ATL       NO     37              34      M. Ryan
# 2    2014     1  BAL      CIN     16              23    J. Flacco
# 3    2014     1  BUF      CHI     23              20    E. Manuel
# 4    2014     1  CAR       TB     20              14  D. Anderson
#
#    passing_value  rushing_value  qb_rushing_value_pct  pass_def_value  \
# 0       0.472651      -1.258735                     0       -0.014745
# 1       1.515659       0.682493                     0        0.748551
# 2      -0.552992       0.180459                     0        0.934747
# 3      -0.063069       1.014793                     0       -0.700995
# 4       0.690009      -0.984362                     0       -1.035469
#
#    rush_def_value          team_full         opponent_full
# 0       -1.468394  Arizona Cardinals  Los Angeles Chargers
# 1        1.005162    Atlanta Falcons    New Orleans Saints
# 2       -0.727127   Baltimore Ravens    Cincinnati Bengals
# 3        0.187514      Buffalo Bills         Chicago Bears
# 4        0.392165  Carolina Panthers  Tampa Bay Buccaneers

# %%
# Save raw data frame with values

df.to_csv('../data/value_models_combined.csv')

# %%
# Save data frame with past 6 games rolling stats

# Notes:
# Pure average for now, not weighted (possible future adjustment?)
# Resets every new season. Previous iterations had used the final 6 games of the last season to predict week 1,
# but not sure if thats the best way to do it since things vary a lot from season to season. Can revisit later.

offense_base = df.copy()[['season', 'week', 'team', 'qb']]
defense_base = df.copy()[['season', 'week', 'team']]

offense_rolling = df.groupby(by=['season', 'team', 'qb']).rolling(
    6, closed='left', min_periods=1).mean()[[
    'passing_value', 'rushing_value', 'qb_rushing_value_pct']].reset_index(
    level=['season', 'team',  'qb'])[['passing_value', 'rushing_value', 'qb_rushing_value_pct']]

defense_rolling = df[['season', 'week', 'team', 'pass_def_value', 'rush_def_value']].drop_duplicates().groupby(
    by=['season', 'team']).rolling(6, closed='left', min_periods=1).mean()[[
    'pass_def_value', 'rush_def_value']].reset_index(level=['season', 'team'])[['pass_def_value', 'rush_def_value']]

offense = offense_base.join(offense_rolling)
defense = defense_base.join(defense_rolling).dropna()

combined = offense.merge(defense, how='left')
# Out:
# <ipython-input-13-c84e907adb2a>:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['opponent', 'opponent_full', 'team_full'], dtype='object')
#   offense_rolling = df.groupby(by=['season', 'team', 'qb']).rolling(

# %%
# NOTE: Pretty sure everything in previous code block is good, but do some checks next time i look at this

combined[combined.team=='LV'].tail(15)
# Out:
#       season  week team          qb  passing_value  rushing_value  \
# 4540    2022     4   LV     D. Carr      -0.215512       0.155383
# 4574    2022     5   LV     D. Carr      -0.263448       0.453226
# 4634    2022     7   LV     D. Carr      -0.103413       0.506608
# 4662    2022     8   LV     D. Carr       0.087521       0.612734
# 4663    2022     8   LV  J. Stidham            NaN            NaN
# 4691    2022     9   LV     D. Carr      -0.011856       0.412003
# 4718    2022    10   LV     D. Carr       0.169041       0.306876
# 4747    2022    11   LV     D. Carr       0.116217       0.070542
# 4776    2022    12   LV     D. Carr       0.278586      -0.141497
# 4806    2022    13   LV     D. Carr       0.385250      -0.153452
# 4834    2022    14   LV     D. Carr       0.072342      -0.227610
# 4865    2022    15   LV     D. Carr       0.244344       0.064464
# 4897    2022    16   LV     D. Carr       0.059637       0.199212
# 4930    2022    17   LV  J. Stidham      -0.274394      -1.130636
# 4963    2022    18   LV  J. Stidham       0.105401      -0.668621
#
#       qb_rushing_value_pct  pass_def_value  rush_def_value
# 4540                   0.0        0.496360        0.103418
# 4574                   0.0        0.327135       -0.258491
# 4634                   0.0        0.496351       -0.159492
# 4662                   0.0        0.445580       -0.078853
# 4663                   NaN        0.445580       -0.078853
# 4691                   0.0        0.362218        0.217381
# 4718                   0.0        0.684642       -0.143948
# 4747                   0.0        0.530316        0.149098
# 4776                   0.0        0.567988        0.344332
# 4806                   0.0        0.479651        0.150268
# 4834                   0.0        0.335302        0.091025
# 4865                   0.0        0.222314       -0.179766
# 4897                   0.0       -0.123498       -0.071075
# 4930                   0.0       -0.133103       -0.377454
# 4963                   0.0       -0.036467        0.015861

# %%
df[df.team == 'LV'].tail(15)
# Out:
#       season  week team opponent  score  opponent_score          qb  \
# 4540    2022     4   LV      DEN     32              23     D. Carr
# 4574    2022     5   LV       KC     29              30     D. Carr
# 4634    2022     7   LV      HOU     38              20     D. Carr
# 4662    2022     8   LV       NO      0              24     D. Carr
# 4663    2022     8   LV       NO      0              24  J. Stidham
# 4691    2022     9   LV      JAX     20              27     D. Carr
# 4718    2022    10   LV      IND     20              25     D. Carr
# 4747    2022    11   LV      DEN     22              16     D. Carr
# 4776    2022    12   LV      SEA     40              34     D. Carr
# 4806    2022    13   LV      LAC     27              20     D. Carr
# 4834    2022    14   LV       LA     16              17     D. Carr
# 4865    2022    15   LV       NE     30              24     D. Carr
# 4897    2022    16   LV      PIT     10              13     D. Carr
# 4930    2022    17   LV       SF     34              37  J. Stidham
# 4963    2022    18   LV       KC     13              31  J. Stidham
#
#       passing_value  rushing_value  qb_rushing_value_pct  pass_def_value  \
# 4540      -0.407256       1.346756                     0       -0.180543
# 4574       0.536725       0.720135                     0        1.173216
# 4634       1.042196       1.143365                     0        0.191728
# 4662      -1.207371      -1.130636                     0        0.769853
# 4663      -0.274394      -1.130636                     0        0.769853
# 4691       0.644839      -0.662253                     0        1.132799
# 4718       0.088167      -0.994115                     0        0.094845
# 4747       0.566960       0.074520                     0        0.045489
# 4776       1.176710       0.648405                     0        0.643191
# 4806      -0.835251       0.698422                     0       -0.674367
# 4834      -0.175364       0.621804                     0        0.091925
# 4865      -0.463401       0.146235                     0       -0.942070
# 4897      -0.588739      -0.523108                     0        0.037216
# 4930       0.485195      -0.206605                     0        0.625304
# 4963      -0.983051      -0.016786                     0        0.004435
#
#       rush_def_value          team_full         opponent_full
# 4540       -1.344218  Las Vegas Raiders        Denver Broncos
# 4574        0.236504  Las Vegas Raiders    Kansas City Chiefs
# 4634        0.324343  Las Vegas Raiders        Houston Texans
# 4662        0.159348  Las Vegas Raiders    New Orleans Saints
# 4663        0.159348  Las Vegas Raiders    New Orleans Saints
# 4691       -0.004129  Las Vegas Raiders  Jacksonville Jaguars
# 4718        1.522742  Las Vegas Raiders    Indianapolis Colts
# 4747       -0.172814  Las Vegas Raiders        Denver Broncos
# 4776       -0.927884  Las Vegas Raiders      Seattle Seahawks
# 4806       -0.031113  Las Vegas Raiders  Los Angeles Chargers
# 4834       -1.465395  Las Vegas Raiders      Los Angeles Rams
# 4865        0.648017  Las Vegas Raiders  New England Patriots
# 4897       -0.315534  Las Vegas Raiders   Pittsburgh Steelers
# 4930        2.187076  Las Vegas Raiders   San Francisco 49ers
# 4963        2.674979  Las Vegas Raiders    Kansas City Chiefs

# %%
combined
# Out:
#       season  week team           qb  passing_value  rushing_value  \
# 0       2014     1  ARI    C. Palmer            NaN            NaN
# 1       2014     1  ATL      M. Ryan            NaN            NaN
# 2       2014     1  BAL    J. Flacco            NaN            NaN
# 3       2014     1  BUF    E. Manuel            NaN            NaN
# 4       2014     1  CAR  D. Anderson            NaN            NaN
# ...      ...   ...  ...          ...            ...            ...
# 4999    2022    21   KC   P. Mahomes       0.538192       0.433467
# 5000    2022    21  PHI     J. Hurts       0.137651       2.439576
# 5001    2022    21   SF   J. Johnson            NaN            NaN
# 5002    2022    22   KC   P. Mahomes       0.563517       0.272761
# 5003    2022    22  PHI     J. Hurts       0.216553       1.956546
#
#       qb_rushing_value_pct  pass_def_value  rush_def_value
# 0                      NaN             NaN             NaN
# 1                      NaN             NaN             NaN
# 2                      NaN             NaN             NaN
# 3                      NaN             NaN             NaN
# 4                      NaN             NaN             NaN
# ...                    ...             ...             ...
# 4999                   0.0       -0.901990        0.379622
# 5000                   0.0       -0.584781        0.512271
# 5001                   NaN       -0.407733       -0.362456
# 5002                   0.0       -0.796702        0.412985
# 5003                   0.0       -0.579625       -0.031984
#
# [5004 rows x 9 columns]

# %%
# fix team names

combined['team_full'] = combined.apply(lambda x: fix_team_names(x, is_team=True), axis=1)
# combined['opponent_full'] = combined.apply(lambda x: fix_team_names(x, is_team=False), axis=1)
combined.head()
# Out:
#    season  week team           qb  passing_value  rushing_value  \
# 0    2014     1  ARI    C. Palmer            NaN            NaN
# 1    2014     1  ATL      M. Ryan            NaN            NaN
# 2    2014     1  BAL    J. Flacco            NaN            NaN
# 3    2014     1  BUF    E. Manuel            NaN            NaN
# 4    2014     1  CAR  D. Anderson            NaN            NaN
#
#    qb_rushing_value_pct  pass_def_value  rush_def_value          team_full
# 0                   NaN             NaN             NaN  Arizona Cardinals
# 1                   NaN             NaN             NaN    Atlanta Falcons
# 2                   NaN             NaN             NaN   Baltimore Ravens
# 3                   NaN             NaN             NaN      Buffalo Bills
# 4                   NaN             NaN             NaN  Carolina Panthers

# %%
# Save aggregated data frame with values

combined.to_csv('../data/value_models_combined_6_game_rolling.csv')

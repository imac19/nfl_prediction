# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
# Import data

qb = pd.read_csv('../modeling/qb_value_modeling/qb_value_data/qb_with_values.csv')
qb = qb.drop(columns = ['Unnamed: 0'])
rb = pd.read_csv('../modeling/rush_offense_value_modeling/rush_offense_value_data/rb_with_values.csv')
rb = rb.drop(columns = ['Unnamed: 0'])
pass_def = pd.read_csv('../modeling/pass_defense_value_modeling/pass_defense_value_data/pass_defense_with_values.csv')
pass_def = pass_def.drop(columns = ['Unnamed: 0'])
rush_def = pd.read_csv('../modeling/rush_defense_value_modeling/rush_defense_value_data/rush_defense_with_values.csv')
rush_def = rush_def.drop(columns = ['Unnamed: 0'])

# %%
# Put data into one data frame that just has the game identifiers and value numbers

qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'passing_value']]
rb = rb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rushing_value', 'qb_rushing_value_pct']]
pass_def = pass_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'pass_def_value']]
rush_def = rush_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rush_def_value']]
df = qb.copy()
df = df.merge(rb).merge(pass_def).merge(rush_def)
df = df.drop_duplicates()
df
# Out:
#       season  week team opponent  score  opponent_score            qb  \
# 0       2014     1  ARI      LAC     18              17     C. Palmer
# 1       2014     1  ATL       NO     37              34       M. Ryan
# 2       2014     1  BAL      CIN     16              23     J. Flacco
# 3       2014     1  BUF      CHI     23              20     E. Manuel
# 4       2014     1  CAR       TB     20              14   D. Anderson
# ...      ...   ...  ...      ...    ...             ...           ...
# 4740    2022    10   TB      SEA     21              16      T. Brady
# 4741    2022    10  TEN      DEN     17              10  R. Tannehill
# 4742    2022    10  WAS      PHI     32              21   T. Heinicke
# 4743    2022    11   GB      TEN     17              27    A. Rodgers
# 4744    2022    11  TEN       GB     27              17  R. Tannehill
#
#       passing_value  rushing_value  qb_rushing_value_pct  pass_def_value  \
# 0          0.604567       0.194004              0.270270        0.493942
# 1          0.846419       0.721665              0.120968        0.254835
# 2          0.310023       0.578230              0.073684        0.191127
# 3          0.422696       0.763580              0.116162        0.696008
# 4          0.712989       0.312710              0.087719        0.843228
# ...             ...            ...                   ...             ...
# 4740       0.909411       0.611409              0.000000        0.372324
# 4741       0.570619       0.098195              0.187500        0.708770
# 4742       0.534081       0.675205              0.089172        0.897627
# 4743       0.487381       0.269715              0.000000        0.043549
# 4744       0.942799       0.449820              0.000000        0.433688
#
#       rush_def_value
# 0           0.855757
# 1           0.216091
# 2           0.693342
# 3           0.408553
# 4           0.321939
# ...              ...
# 4740        0.741143
# 4741        0.570952
# 4742        0.159860
# 4743        0.537460
# 4744        0.718606
#
# [4745 rows x 12 columns]

# %%
# Save raw data frame with values

df.to_csv('../data/value_models_combined.csv')

# %%
# Save data frame with past 6 games rolling stats

# Notes:
# Pure average for now, not weighted (possible future adjustment?)
# Resets every new season. Previous iterations had used the final 6 games of the last season to predict week 1,
# but not sure if thats the best way to do it since things vary a lot from season to season. Can revisit later.

base = df.copy()[['season', 'team', 'week', 'qb']]

qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().reset_index().groupby(
    by=['season', 'team', 'qb']).rolling(
    6, closed='left', min_periods=1).mean().reset_index(
    level=['qb', 'season', 'team'])[['qb', 'season', 'team', 'passing_value']]

other_rolling = df.groupby(by=['season', 'team', 'week']).mean().rolling(
    6, closed='left', min_periods=1).mean().reset_index(
    level=['season', 'team', 'week'])[['season', 'team', 'week', 'rushing_value', 
                                       'qb_rushing_value_pct', 'pass_def_value', 'rush_def_value']]

base = qb_rolling.merge(other_rolling)
base = base[['season', 'team', 'week', 'qb', 'passing_value', 'rushing_value', 
                                       'qb_rushing_value_pct', 'pass_def_value', 'rush_def_value']]
# Out:
# <ipython-input-123-a9e7e94cf074>:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().rolling(
# <ipython-input-123-a9e7e94cf074>:14: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   other_rolling = df.groupby(by=['season', 'team', 'week']).mean().rolling(

# %%
base
# Out:
#       season team  week           qb  passing_value  rushing_value  \
# 0       2014  ARI     1    C. Palmer            NaN            NaN
# 1       2014  ARI     2   D. Stanton       0.604567       0.194004
# 2       2014  ARI     3   D. Stanton       0.428231       0.391087
# 3       2014  ARI     5   D. Stanton       0.535634       0.452549
# 4       2014  ARI     6    C. Palmer       0.475280       0.371278
# ...      ...  ...   ...          ...            ...            ...
# 4740    2022  WAS     6     C. Wentz       0.435165       0.445968
# 4741    2022  WAS     7  T. Heinicke       0.292100       0.492684
# 4742    2022  WAS     8  T. Heinicke       0.243559       0.523155
# 4743    2022  WAS     9  T. Heinicke       0.244251       0.460470
# 4744    2022  WAS    10  T. Heinicke       0.249419       0.488580
#
#       qb_rushing_value_pct  pass_def_value  rush_def_value
# 0                      NaN             NaN             NaN
# 1                 0.270270        0.493942        0.855757
# 2                 0.135135        0.477170        0.820346
# 3                 0.170676        0.386578        0.717531
# 4                 0.128007        0.331807        0.656903
# ...                    ...             ...             ...
# 4740              0.176340        0.425100        0.560599
# 4741              0.178924        0.511041        0.472391
# 4742              0.156401        0.524770        0.548866
# 4743              0.163158        0.521156        0.640387
# 4744              0.143074        0.593203        0.614816
#
# [4745 rows x 9 columns]

# %%
current = base[base.season==2022]
current[current.team == 'LV']
# Out:
#       season team  week          qb  passing_value  rushing_value  \
# 4608    2022   LV     1     D. Carr       0.417879       0.540968
# 4609    2022   LV     2     D. Carr       0.315332       0.538961
# 4610    2022   LV     3     D. Carr       0.269735       0.462231
# 4611    2022   LV     4     D. Carr       0.338547       0.454356
# 4612    2022   LV     5     D. Carr       0.354941       0.570247
# 4613    2022   LV     7     D. Carr       0.377072       0.624449
# 4614    2022   LV     8     D. Carr       0.488709       0.671456
# 4615    2022   LV     8  J. Stidham       0.458406       0.671456
# 4616    2022   LV     9     D. Carr       0.449820       0.593296
# 4617    2022   LV    10     D. Carr       0.470136       0.552155
#
#       qb_rushing_value_pct  pass_def_value  rush_def_value
# 4608              0.174493        0.566478        0.270568
# 4609              0.174493        0.448187        0.396405
# 4610              0.182638        0.522957        0.371302
# 4611              0.191577        0.404470        0.376737
# 4612              0.156234        0.449292        0.478653
# 4613              0.154004        0.327968        0.522275
# 4614              0.083491        0.345824        0.513135
# 4615              0.083491        0.345824        0.513135
# 4616              0.083491        0.359617        0.444101
# 4617              0.064973        0.255357        0.506020

# %%
df[df.team=='LV'].tail(11)
# Out:
#       season  week team opponent  score  opponent_score          qb  \
# 4418    2021    19   LV      CIN     19              26     D. Carr
# 4455    2022     1   LV      LAC     19              24     D. Carr
# 4487    2022     2   LV      ARI     23              29     D. Carr
# 4519    2022     3   LV      TEN     22              24     D. Carr
# 4551    2022     4   LV      DEN     32              23     D. Carr
# 4585    2022     5   LV       KC     29              30     D. Carr
# 4645    2022     7   LV      HOU     38              20     D. Carr
# 4673    2022     8   LV       NO      0              24     D. Carr
# 4674    2022     8   LV       NO      0              24  J. Stidham
# 4704    2022     9   LV      JAX     20              27     D. Carr
# 4731    2022    10   LV      IND     20              25     D. Carr
#
#       passing_value  rushing_value  qb_rushing_value_pct  pass_def_value  \
# 4418       0.412575       0.832673              0.192308        0.186235
# 4455       0.242689       0.510120              0.000000        0.095614
# 4487       0.293302       0.499345              0.111111        0.717448
# 4519       0.553403       0.671853              0.175258        0.090085
# 4551       0.289745       0.793759              0.195349        0.577519
# 4585       0.681519       0.731097              0.019231        0.169965
# 4645       0.871595       0.822565              0.000000        0.424311
# 4673       0.060872       0.041160              0.000000        0.178376
# 4674       0.241789       0.041160              0.000000        0.178376
# 4704       0.675298       0.252498              0.000000        0.091885
# 4731       0.465886       0.227262              0.000000        0.434850
#
#       rush_def_value
# 4418        0.594935
# 4455        0.827463
# 4487        0.075474
# 4519        0.538289
# 4551        0.882914
# 4585        0.391064
# 4645        0.363604
# 4673        0.413264
# 4674        0.413264
# 4704        0.446986
# 4731        0.134010

# %%
qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().reset_index()
qb_rolling[qb_rolling.team == 'LV'].tail(10)
# Out:
# <ipython-input-131-259aa5730414>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().reset_index()
#       season team  week          qb  score  opponent_score  passing_value  \
# 4608    2022   LV     1     D. Carr   19.0            24.0       0.242689
# 4609    2022   LV     2     D. Carr   23.0            29.0       0.293302
# 4610    2022   LV     3     D. Carr   22.0            24.0       0.553403
# 4611    2022   LV     4     D. Carr   32.0            23.0       0.289745
# 4612    2022   LV     5     D. Carr   29.0            30.0       0.681519
# 4613    2022   LV     7     D. Carr   38.0            20.0       0.871595
# 4614    2022   LV     8     D. Carr    0.0            24.0       0.060872
# 4615    2022   LV     8  J. Stidham    0.0            24.0       0.241789
# 4616    2022   LV     9     D. Carr   20.0            27.0       0.675298
# 4617    2022   LV    10     D. Carr   20.0            25.0       0.465886
#
#       rushing_value  qb_rushing_value_pct  pass_def_value  rush_def_value
# 4608       0.510120              0.000000        0.095614        0.827463
# 4609       0.499345              0.111111        0.717448        0.075474
# 4610       0.671853              0.175258        0.090085        0.538289
# 4611       0.793759              0.195349        0.577519        0.882914
# 4612       0.731097              0.019231        0.169965        0.391064
# 4613       0.822565              0.000000        0.424311        0.363604
# 4614       0.041160              0.000000        0.178376        0.413264
# 4615       0.041160              0.000000        0.178376        0.413264
# 4616       0.252498              0.000000        0.091885        0.446986
# 4617       0.227262              0.000000        0.434850        0.134010

# %%
df[['season', 'team', 'week', 'score', 'opponent_score', 'rushing_value', 'qb_rushing_value_pct', 
   'pass_def_value', 'rush_def_value']].drop_duplicates().groupby(by=['season', 'team']).rolling(
    6, closed='left', min_periods=1).mean().reset_index(
    level=['season', 'team'])
# Out:
#       season team  week      score  opponent_score  rushing_value  \
# 0       2014  ARI   NaN        NaN             NaN            NaN
# 33      2014  ARI  1.00  18.000000       17.000000       0.194004
# 65      2014  ARI  1.50  21.500000       15.500000       0.391087
# 126     2014  ARI  2.00  22.000000       15.000000       0.452549
# 158     2014  ARI  2.75  21.500000       21.500000       0.371278
# ...      ...  ...   ...        ...             ...            ...
# 4628    2022  WAS  3.00  18.000000       25.600000       0.445198
# 4656    2022  WAS  3.50  17.000000       22.500000       0.492684
# 4687    2022  WAS  4.50  16.166667       22.333333       0.523155
# 4714    2022  WAS  5.50  14.500000       19.000000       0.460470
# 4742    2022  WAS  6.50  16.000000       18.333333       0.488580
#
#       qb_rushing_value_pct  pass_def_value  rush_def_value
# 0                      NaN             NaN             NaN
# 33                0.270270        0.493942        0.855757
# 65                0.135135        0.477170        0.820346
# 126               0.170676        0.386578        0.717531
# 158               0.128007        0.331807        0.656903
# ...                    ...             ...             ...
# 4628              0.211608        0.423382        0.528998
# 4656              0.178924        0.511041        0.472391
# 4687              0.156401        0.524770        0.548866
# 4714              0.163158        0.521156        0.640387
# 4742              0.143074        0.593203        0.614816
#
# [4591 rows x 9 columns]

# %%
qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().reset_index().groupby(
    by=['season', 'team', 'qb']).rolling(
    6, closed='left', min_periods=1).mean().reset_index(
    level=['qb', 'season', 'team'])[['qb', 'season', 'team', 'passing_value']]
qb_rolling
# Out:
# <ipython-input-151-1b31e9d74662>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   qb_rolling = df.groupby(by=['season', 'team', 'week', 'qb']).mean().reset_index().groupby(
#                qb  season team  passing_value
# 0       C. Palmer    2014  ARI            NaN
# 4       C. Palmer    2014  ARI       0.604567
# 5       C. Palmer    2014  ARI       0.589692
# 6       C. Palmer    2014  ARI       0.641113
# 7       C. Palmer    2014  ARI       0.637922
# ...           ...     ...  ...            ...
# 4740     C. Wentz    2022  WAS       0.333638
# 4741  T. Heinicke    2022  WAS            NaN
# 4742  T. Heinicke    2022  WAS       0.361894
# 4743  T. Heinicke    2022  WAS       0.416002
# 4744  T. Heinicke    2022  WAS       0.304781
#
# [4745 rows x 4 columns]

# %%
base = df.copy()[['season', 'team', 'week', 'qb']]
base
# Out:
#       season team  week            qb
# 0       2014  ARI     1     C. Palmer
# 1       2014  ATL     1       M. Ryan
# 2       2014  BAL     1     J. Flacco
# 3       2014  BUF     1     E. Manuel
# 4       2014  CAR     1   D. Anderson
# ...      ...  ...   ...           ...
# 4740    2022   TB    10      T. Brady
# 4741    2022  TEN    10  R. Tannehill
# 4742    2022  WAS    10   T. Heinicke
# 4743    2022   GB    11    A. Rodgers
# 4744    2022  TEN    11  R. Tannehill
#
# [4745 rows x 4 columns]

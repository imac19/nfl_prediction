# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Jul 30 21:45:18 2023

@author: ian
"""

# Import packages

import pandas as pd 
import numpy as np 
import os

# Import data

rb = pd.read_csv('data/06_seasontest_adjusted_rushing_values.csv')
rb = rb.drop(columns = ['Unnamed: 0'])
pass_def = pd.read_csv('data/06_seasontest_adjusted_pass_defense_values.csv')
pass_def = pass_def.drop(columns = ['Unnamed: 0'])
rush_def = pd.read_csv('data/06_seasontest_adjusted_rush_defense_values.csv')
rush_def = rush_def.drop(columns = ['Unnamed: 0'])
qb = pd.read_csv('data/06_seasontest_adjusted_qb_values.csv')
qb = qb.drop(columns = ['Unnamed: 0'])
st = pd.read_csv('data/04_seasontest_initial_st_values.csv')
st = st.drop(columns = ['Unnamed: 0'])
extra = pd.read_csv('data/04_seasontest_initial_extra_values.csv')
extra = extra.drop(columns = ['Unnamed: 0'])

# Put data into one data frame that just has the game identifiers and value numbers

# qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'qb_value', 'passing_value']]
qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'passing_value_adjusted']]
rb = rb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rushing_value_adjusted']]
pass_def = pass_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'pass_def_value_adjusted']]
rush_def = rush_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rush_def_value_adjusted']]
st = st.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'special_teams_value']]
extra = extra.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'total_plays_standardized', 'total_possession_time_standardized', 'pass_percentage_standardized']]
df = qb.copy()
df = df.merge(rb).merge(pass_def).merge(rush_def).merge(st).merge(extra)
df = df.drop_duplicates()

# Add current week data

df2 = df.copy()
current_week_data = pd.read_csv('data/04_seasontest_current_week_data.csv')

home_week = current_week_data[['season', 'week', 'home', 'away', 'home_qb']]
home_week = home_week.rename(columns = {'home': 'team', 
                                       'away': 'opponent',
                                       'home_qb': 'qb'})
away_week = current_week_data[['season', 'week', 'home', 'away', 'away_qb']]
away_week = away_week.rename(columns = {'away': 'team', 
                                       'home': 'opponent',
                                       'away_qb': 'qb'})
away_week

df = pd.concat([df2, home_week, away_week], axis=0).reset_index()
df

# Fix team names

# Move to helper functions

def fix_team_names(game, is_team=True):
    team_mapping = {
        'ARI':'Arizona Cardinals',
        'ATL':'Atlanta Falcons',
        'BAL':'Baltimore Ravens',
        'BUF':'Buffalo Bills',
        'CAR':'Carolina Panthers',
        'CHI':'Chicago Bears',
        'CIN':'Cincinnati Bengals',
        'CLE':'Cleveland Browns',
        'DAL':'Dallas Cowboys',
        'DEN':'Denver Broncos',
        'DET':'Detroit Lions',
        'GB':'Green Bay Packers',
        'HOU':'Houston Texans',
        'IND':'Indianapolis Colts',
        'JAX':'Jacksonville Jaguars',
        'KC':'Kansas City Chiefs',
        'OAK':'Las Vegas Raiders',
        'LV':'Las Vegas Raiders',
        'LAC':'Los Angeles Chargers',
        'LAR':'Los Angeles Rams',
        'LA':'Los Angeles Rams',
        'MIA':'Miami Dolphins',
        'MIN':'Minnesota Vikings',
        'NE':'New England Patriots',
        'NO':'New Orleans Saints',
        'NYG':'New York Giants',
        'NYJ':'New York Jets',
        'PHI':'Philadelphia Eagles',
        'PIT':'Pittsburgh Steelers',
        'SF':'San Francisco 49ers',
        'SEA':'Seattle Seahawks',
        'TB':'Tampa Bay Buccaneers',
        'TEN':'Tennessee Titans',
        'WSH':'Washington Football Team',
        'WAS':'Washington Football Team'
    }
    
    if is_team:
        return team_mapping[game['team']]
    
    else:
        return team_mapping[game['opponent']]
    
df['team_full'] = df.apply(lambda x: fix_team_names(x, is_team=True), axis=1)
df['opponent_full'] = df.apply(lambda x: fix_team_names(x, is_team=False), axis=1)

# Save raw data frame with values

df.to_csv('data/07_seasontest_adjusted_value_models_combined.csv')

# Save data frame with past 5 games rolling stats

# Weighted average approach

def weighted_avg(values):
    if len(values) == 1:
        weights = np.array([1])
    elif len(values) == 2:
        weights = np.array([.4, .6])
    elif len(values) == 3:
        weights = np.array([.23, .33, .43])
    elif len(values) == 4:
        weights = np.array([.1, .2, .3, .4])
    elif len(values) == 5:
        weights = np.array([.05, .15, .2, .25, .35])
    
    return np.sum(weights * values)

# Uncomment and use this if even weights are desired

# def weighted_avg(values):
#     if len(values) == 1:
#         weights = np.array([1])
#     elif len(values) == 2:
#         weights = np.array([.5, .5])
#     elif len(values) == 3:
#         weights = np.array([.333, .333, .333])
#     elif len(values) == 4:
#         weights = np.array([.25, .25, .25, .25])
#     elif len(values) == 5:
#         weights = np.array([.2, .2, .2, .2, .2])
    
#     return np.sum(weights * values)


offense_base = df.copy()[['season', 'week', 'team_full', 'qb']]
defense_base = df.copy()[['season', 'week', 'team_full']]

offense_rolling = df[['team_full', 'qb', 'passing_value_adjusted', 'rushing_value_adjusted',
                     'total_plays_standardized', 'total_possession_time_standardized', 
                     'pass_percentage_standardized']]
offense_rolling = offense_rolling.groupby(by=['team_full', 'qb']).rolling(
    5, closed='left', min_periods=1).apply(lambda x: weighted_avg(x)).reset_index(level=['team_full', 'qb'], drop=True)

defense_rolling = df[['team_full', 'pass_def_value_adjusted', 'rush_def_value_adjusted', 'special_teams_value']]
defense_rolling = defense_rolling.groupby(by=['team_full']).rolling(
    5, closed='left', min_periods=1).apply(lambda x: weighted_avg(x)).reset_index(level=['team_full'], drop=True)

offense = offense_base.join(offense_rolling)
defense = defense_base.join(defense_rolling).dropna()

combined = offense.merge(defense, how='left')

# fix team names

# combined['team_full'] = combined.apply(lambda x: fix_team_names(x, is_team=True), axis=1)

# Save aggregated data frame with values

combined.to_csv('data/07_seasontest_adjusted_value_models_aggregated.csv')

print('07_adjusted_value_models_combination_and_aggregation Complete')
# Out:
# 07_adjusted_value_models_combination_and_aggregation Complete

# %%
df[df.team == 'NYG']
# Out:
#      index  season  week team opponent  score  opponent_score            qb  \
# 23      23    2022     1  NYG      TEN   21.0            20.0      D. Jones
# 55      55    2022     2  NYG      CAR   19.0            16.0      D. Jones
# 87      87    2022     3  NYG      DAL   16.0            23.0      D. Jones
# 119    119    2022     4  NYG      CHI   20.0            12.0      D. Jones
# 151    151    2022     5  NYG       GB   27.0            22.0      D. Jones
# 180    180    2022     6  NYG      BAL   24.0            20.0      D. Jones
# 208    208    2022     7  NYG      JAX   23.0            17.0      D. Jones
# 236    236    2022     8  NYG      SEA   13.0            27.0      D. Jones
# 290    290    2022    10  NYG      HOU   24.0            16.0      D. Jones
# 319    319    2022    11  NYG      DET   18.0            31.0      D. Jones
# 349    349    2022    12  NYG      DAL   20.0            28.0      D. Jones
# 379    379    2022    13  NYG      WAS   20.0            20.0      D. Jones
# 406    406    2022    14  NYG      PHI   22.0            48.0      D. Jones
# 437    437    2022    15  NYG      WAS   20.0            12.0      D. Jones
# 469    469    2022    16  NYG      MIN   24.0            27.0      D. Jones
# 499    499    2022    17  NYG      IND   38.0            10.0      D. Jones
# 531    531    2022    18  NYG      PHI   16.0            22.0       D. Webb
# 548    548    2022    19  NYG      MIN   31.0            24.0      D. Jones
# 557    557    2022    20  NYG      PHI    7.0            38.0      D. Jones
# 581     13    2023     1  NYG      DAL    NaN             NaN  Daniel Jones
#
#      passing_value_adjusted  rushing_value_adjusted  pass_def_value_adjusted  \
# 23                      NaN                     NaN                      NaN
# 55                -0.118730               -1.131197                 1.080286
# 87                -1.058303                1.336523                -0.318995
# 119               -0.491497                0.810202                 0.595780
# 151                1.723347                0.455023                -0.254477
# 180                1.237920               -0.391276                 0.145457
# 208                0.280867                1.246991                -0.779162
# 236               -0.029495               -0.901689                 0.387050
# 290                2.209673               -0.314092                -0.674783
# 319               -0.193184                0.032795                -0.238006
# 349               -0.251453                0.224810                -1.026134
# 379               -0.089815               -0.495170                 0.010963
# 406               -0.473122                0.834952                -0.543863
# 437                0.275759                0.673447                 1.136047
# 469               -0.371221                1.305728                 0.091935
# 499                0.937174                0.789355                 0.726952
# 531               -0.052839                1.601445                 0.365626
# 548                1.315557                1.796146                -0.548813
# 557               -1.637508                0.570596                -0.819482
# 581                     NaN                     NaN                      NaN
#
#      rush_def_value_adjusted  special_teams_value  total_plays_standardized  \
# 23                       NaN             0.955098                 -0.869675
# 55                 -1.192864             1.938629                  0.986934
# 87                 -1.370052            -0.123295                  0.638820
# 119                -0.015182            -1.289792                 -0.173446
# 151                -0.211884            -0.112723                 -0.521561
# 180                -1.365414             0.992859                 -0.289484
# 208                 0.363079            -0.011320                  0.870896
# 236                 0.638330            -2.591894                  0.058630
# 290                 0.818168            -0.395974                  0.290706
# 319                -0.906206            -1.744459                  0.754858
# 349                 0.417292             1.028437                 -0.521561
# 379                -0.627642             1.306277                  0.290706
# 406                -3.298506            -0.384515                 -0.289484
# 437                -0.785247             0.163569                  0.058630
# 469                -0.434205            -0.235072                  0.406744
# 499                -0.208444             1.188162                  0.290706
# 531                -0.474599            -1.701564                 -0.173446
# 548                -0.203823            -0.321448                  0.406744
# 557                -2.608708            -0.534669                 -1.565903
# 581                      NaN                  NaN                       NaN
#
#      total_possession_time_standardized  pass_percentage_standardized  \
# 23                            -0.358917                     -1.105563
# 55                             1.273640                     -0.267887
# 87                            -0.729427                      0.468597
# 119                            0.192987                     -2.630289
# 151                            0.401399                     -0.660547
# 180                            0.328069                     -0.434268
# 208                            0.860676                     -1.169137
# 236                            0.721735                     -0.104278
# 290                            0.667702                     -2.413640
# 319                           -0.521015                      0.619635
# 349                           -1.065201                      0.451992
# 379                           -0.378215                     -0.373441
# 406                           -0.683113                      0.451992
# 437                            0.235441                     -0.283416
# 469                           -0.285587                      0.999959
# 499                            0.868395                     -1.608942
# 531                           -0.436107                      0.869194
# 548                            0.729454                      0.173857
# 557                           -1.427992                      0.366412
# 581                                 NaN                           NaN
#
#            team_full             opponent_full
# 23   New York Giants          Tennessee Titans
# 55   New York Giants         Carolina Panthers
# 87   New York Giants            Dallas Cowboys
# 119  New York Giants             Chicago Bears
# 151  New York Giants         Green Bay Packers
# 180  New York Giants          Baltimore Ravens
# 208  New York Giants      Jacksonville Jaguars
# 236  New York Giants          Seattle Seahawks
# 290  New York Giants            Houston Texans
# 319  New York Giants             Detroit Lions
# 349  New York Giants            Dallas Cowboys
# 379  New York Giants  Washington Football Team
# 406  New York Giants       Philadelphia Eagles
# 437  New York Giants  Washington Football Team
# 469  New York Giants         Minnesota Vikings
# 499  New York Giants        Indianapolis Colts
# 531  New York Giants       Philadelphia Eagles
# 548  New York Giants         Minnesota Vikings
# 557  New York Giants       Philadelphia Eagles
# 581  New York Giants            Dallas Cowboys

# %%
df
# Out:
#      index  season  week team opponent  score  opponent_score  \
# 0        0    2022     1  ARI       KC   21.0            44.0
# 1        1    2022     1  ATL       NO   26.0            27.0
# 2        2    2022     1  BAL      NYJ   24.0             9.0
# 3        3    2022     1  BUF       LA   31.0            10.0
# 4        4    2022     1  CAR      CLE   24.0            26.0
# ..     ...     ...   ...  ...      ...    ...             ...
# 593     10    2023     1  LAR      SEA    NaN             NaN
# 594     11    2023     1   GB      CHI    NaN             NaN
# 595     12    2023     1   LV      DEN    NaN             NaN
# 596     13    2023     1  DAL      NYG    NaN             NaN
# 597     14    2023     1  BUF      NYJ    NaN             NaN
#
#                    qb  passing_value_adjusted  rushing_value_adjusted  \
# 0           K. Murray                     NaN                     NaN
# 1          M. Mariota                     NaN                     NaN
# 2          L. Jackson                     NaN                     NaN
# 3            J. Allen                     NaN                     NaN
# 4         B. Mayfield                     NaN                     NaN
# ..                ...                     ...                     ...
# 593  Matthew Stafford                     NaN                     NaN
# 594       Jordan Love                     NaN                     NaN
# 595   Jimmy Garoppolo                     NaN                     NaN
# 596       D. Prescott                     NaN                     NaN
# 597          J. Allen                     NaN                     NaN
#
#      pass_def_value_adjusted  rush_def_value_adjusted  special_teams_value  \
# 0                        NaN                      NaN             0.252584
# 1                        NaN                      NaN             1.054228
# 2                        NaN                      NaN             1.589315
# 3                        NaN                      NaN             0.477646
# 4                        NaN                      NaN            -0.428776
# ..                       ...                      ...                  ...
# 593                      NaN                      NaN                  NaN
# 594                      NaN                      NaN                  NaN
# 595                      NaN                      NaN                  NaN
# 596                      NaN                      NaN                  NaN
# 597                      NaN                      NaN                  NaN
#
#      total_plays_standardized  total_possession_time_standardized  \
# 0                   -0.289484                           -1.192564
# 1                    1.219011                            0.760330
# 2                   -1.333827                           -0.683113
# 3                   -0.753637                            0.181409
# 4                   -1.681941                           -2.057086
# ..                        ...                                 ...
# 593                       NaN                                 NaN
# 594                       NaN                                 NaN
# 595                       NaN                                 NaN
# 596                       NaN                                 NaN
# 597                       NaN                                 NaN
#
#      pass_percentage_standardized
# 0                        0.869194
# 1                       -1.041990
# 2                        0.473806
# 3                        0.042109
# 4                        0.520107
# ..                            ...
# 593                           NaN
# 594                           NaN
# 595                           NaN
# 596                           NaN
# 597                           NaN
#
# [598 rows x 16 columns]

# %%
df[df.team == 'GB']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df[df.team == 'GB']
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'team'

# %%
df = pd.read_csv(('data/final_predictive_dataframe.csv'))

# %%
df
# Out:
#     Unnamed: 0  season  week home away        home_qb        away_qb  \
# 0            0    2023     1  MIN   TB     K. Cousins    B. Mayfield
# 1            1    2023     1  PIT   SF     K. Pickett       B. Purdy
# 2            2    2023     1  BAL  HOU     L. Jackson    C.J. Stroud
# 3            3    2023     1  IND  JAX  A. Richardson    T. Lawrence
# 4            4    2023     1  CLE  CIN      D. Watson      J. Burrow
# 5            5    2023     1   NO  TEN        D. Carr   R. Tannehill
# 6            6    2023     1  WAS  ARI      S. Howell       J. Dobbs
# 7            7    2023     1  ATL  CAR      D. Ridder       B. Young
# 8            8    2023     1   NE  PHI       M. Jones       J. Hurts
# 9            9    2023     1  LAC  MIA     J. Herbert  T. Tagovailoa
# 10          10    2023     1  SEA  LAR       G. Smith    M. Stafford
# 11          11    2023     1  CHI   GB      J. Fields        J. Love
# 12          12    2023     1  DEN   LV      R. Wilson   J. Garoppolo
# 13          13    2023     1  NYG  DAL       D. Jones    D. Prescott
# 14          14    2023     1  NYJ  BUF     A. Rodgers       J. Allen
#
#     passing_value_adjusted_home  rushing_value_adjusted_home  \
# 0                      0.673185                    -0.393193
# 1                      0.780551                     0.181826
# 2                      0.121977                     0.328151
# 3                           NaN                          NaN
# 4                     -0.211152                     0.442853
# 5                           NaN                          NaN
# 6                     -1.284806                    -0.082328
# 7                      0.047900                    -0.218146
# 8                     -0.240548                    -0.266291
# 9                      0.620026                    -0.263069
# 10                    -0.407814                     0.324747
# 11                    -1.965486                     0.192967
# 12                    -0.253223                     0.394569
# 13                    -0.098699                     1.036148
# 14                          NaN                          NaN
#
#     pass_def_value_adjusted_home  ...  total_plays_standardized_away  \
# 0                      -0.434404  ...                            NaN
# 1                      -0.187822  ...                      -0.005191
# 2                      -0.040230  ...                            NaN
# 3                            NaN  ...                      -0.138635
# 4                       0.359798  ...                       0.308112
# 5                            NaN  ...                      -0.776844
# 6                      -0.122658  ...                            NaN
# 7                      -0.121759  ...                            NaN
# 8                      -0.275203  ...                       0.853491
# 9                       0.441181  ...                      -1.496281
# 10                     -0.163599  ...                      -0.550570
# 11                     -0.759591  ...                            NaN
# 12                     -0.632103  ...                            NaN
# 13                     -0.237257  ...                       0.389338
# 14                           NaN  ...                      -0.103824
#
#     pass_percentage_standardized_home  pass_percentage_standardized_away  \
# 0                            0.602722                                NaN
# 1                           -0.893167                          -0.768058
# 2                           -0.747644                                NaN
# 3                                 NaN                           0.741425
# 4                           -0.335390                           0.787408
# 5                                 NaN                           0.219419
# 6                           -1.952529                                NaN
# 7                           -0.911153                                NaN
# 8                            0.631381                          -0.910959
# 9                            0.429984                           0.506390
# 10                          -0.209923                          -0.032649
# 11                          -0.529574                                NaN
# 12                          -0.038453                                NaN
# 13                          -0.014257                           0.061580
# 14                                NaN                           0.456243
#
#     home_moneyline  away_moneyline  home_spread  away_spread  \
# 0             -205             170         -4.5          4.5
# 1             -105            -125          2.0         -2.0
# 2             -500             380         -9.5          9.5
# 3              170            -205          3.5         -3.5
# 4              102            -122          1.5         -1.5
# 5             -148             124         -3.0          3.0
# 6             -340             270         -7.0          7.0
# 7             -192             160         -3.5          3.5
# 8              154            -185          3.5         -3.5
# 9             -162             136         -3.0          3.0
# 10            -225             185         -5.0          5.0
# 11            -118            -102         -1.0          1.0
# 12            -170             142         -3.5          3.5
# 13             140            -166          3.0         -3.0
# 14             114            -135          2.5         -2.5
#
#     total_score_line  home_implied_prob  away_implied_prob
# 0               45.5           0.672131           0.370370
# 1               41.5           0.512195           0.555556
# 2               43.5           0.833333           0.208333
# 3               46.0           0.370370           0.672131
# 4               47.0           0.495050           0.549550
# 5               42.0           0.596774           0.446429
# 6               38.0           0.772727           0.270270
# 7               40.5           0.657534           0.384615
# 8               44.5           0.393701           0.649123
# 9               51.0           0.618321           0.423729
# 10              46.0           0.692308           0.350877
# 11              41.0           0.541284           0.504950
# 12              43.5           0.629630           0.413223
# 13              45.0           0.416667           0.624060
# 14              45.5           0.467290           0.574468
#
# [15 rows x 30 columns]

# %%
df = pd.read_csv('data/05_seasontest_value_models_aggregated.csv')

# %%
df[df.team == 'GB']
# Out:
#      Unnamed: 0  season  week team          qb  passing_value  rushing_value  \
# 11           11    2022     1   GB  A. Rodgers            NaN            NaN
# 43           43    2022     2   GB  A. Rodgers      -1.118190       0.287694
# 75           75    2022     3   GB  A. Rodgers       0.183339       0.326167
# 107         107    2022     4   GB  A. Rodgers       0.141313      -0.154513
# 139         139    2022     5   GB  A. Rodgers      -0.001626       0.083764
# 170         170    2022     6   GB  A. Rodgers       0.110901       0.253827
# 198         198    2022     7   GB  A. Rodgers      -0.263099      -0.653026
# 227         227    2022     8   GB  A. Rodgers      -0.381807      -0.520603
# 253         253    2022     9   GB  A. Rodgers      -0.389982       0.278537
# 280         280    2022    10   GB  A. Rodgers      -0.759135       0.395865
# 310         310    2022    11   GB  A. Rodgers       0.050379       0.467234
# 338         338    2022    12   GB  A. Rodgers       0.035995       0.046802
# 368         368    2022    13   GB  A. Rodgers       0.049175       0.632279
# 426         426    2022    15   GB  A. Rodgers       0.296586       0.880656
# 458         458    2022    16   GB  A. Rodgers       0.412056       0.593932
# 488         488    2022    17   GB  A. Rodgers       0.246211       0.094665
# 520         520    2022    18   GB  A. Rodgers       0.268449       0.782292
#
#      total_plays_standardized  total_possession_time_standardized  \
# 11                        NaN                                 NaN
# 43                  -0.521561                           -0.424529
# 75                  -0.115427                            0.575075
# 107                 -0.250554                            0.611771
# 139                  0.029620                            0.827871
# 170                 -0.121046                            0.357405
# 198                  0.389522                            0.712090
# 227                 -0.643217                           -0.309126
# 253                 -0.097838                            0.333862
# 280                  0.006596                            0.298355
# 310                 -0.237084                            0.758018
# 338                 -0.596802                            0.005807
# 368                 -0.933313                           -0.226533
# 426                 -0.445953                            0.269795
# 458                 -0.329915                            0.727914
# 488                 -0.190669                            0.177167
# 520                 -0.097838                            0.768053
#
#      pass_percentage_standardized  pass_def_value  rush_def_value  \
# 11                            NaN             NaN             NaN
# 43                       1.225112       -0.960630        0.214257
# 75                      -0.025805        0.458858       -0.190358
# 107                      0.059232        0.494608        0.106710
# 139                     -0.104999        0.632868       -0.279113
# 170                      0.351738       -0.308777       -0.451942
# 198                      0.450177        0.707425       -0.827548
# 227                      1.076474        0.174942       -0.176403
# 253                      0.295285       -0.014367       -0.994273
# 280                      0.938756       -0.112165        0.079887
# 310                     -0.367321        0.391678       -0.751860
# 338                      0.430483       -0.859051        0.031878
# 368                     -0.113856        0.033912       -2.040841
# 426                     -0.278714       -0.107879       -1.312466
# 458                     -0.558427        0.096861       -1.056909
# 488                      0.304366       -0.219366       -0.694576
# 520                     -0.598139        0.739838       -0.939379
#
#      special_teams_value          team_full
# 11                   NaN  Green Bay Packers
# 43             -0.357025  Green Bay Packers
# 75              0.061943  Green Bay Packers
# 107            -0.157338  Green Bay Packers
# 139            -0.133811  Green Bay Packers
# 170            -0.050687  Green Bay Packers
# 198            -0.505547  Green Bay Packers
# 227            -0.673987  Green Bay Packers
# 253            -0.859983  Green Bay Packers
# 280            -0.610783  Green Bay Packers
# 310            -1.472214  Green Bay Packers
# 338            -0.590658  Green Bay Packers
# 368            -0.737126  Green Bay Packers
# 426            -0.425060  Green Bay Packers
# 458             0.162180  Green Bay Packers
# 488             1.008544  Green Bay Packers
# 520             1.190851  Green Bay Packers

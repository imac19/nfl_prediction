# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import statsmodels.api as sm
from scipy import stats

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
nfl = pd.read_csv('../data/nfl_game_by_game_raw_stats.csv')

# %%
nfl_sub = nfl[['season', 'week', 'team', 'opponent', 'qb', 'total_pass_attempts']]
nfl_sub['qb_ranking'] = nfl_sub.groupby(
    by=['season', 'week', 'team', 'opponent'])['total_pass_attempts'].rank(method='first', ascending=False)
nfl_sub
# Out:
# <ipython-input-9-9e2cbf40fc38>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl_sub['qb_ranking'] = nfl_sub.groupby(
#       season  week team opponent            qb  total_pass_attempts  \
# 0       2014     1  ARI      LAC     C. Palmer                   38
# 1       2014     1  ATL       NO       M. Ryan                   42
# 2       2014     1  BAL      CIN     J. Flacco                   62
# 3       2014     1  BUF      CHI     E. Manuel                   22
# 4       2014     1  CAR       TB   D. Anderson                   33
# ...      ...   ...  ...      ...           ...                  ...
# 5866    2022    21   SF      PHI      B. Purdy                    4
# 5867    2022    21   SF      PHI  C. McCaffrey                    1
# 5868    2022    21   SF      PHI    J. Johnson                   13
# 5869    2022    22   KC      PHI    P. Mahomes                   27
# 5870    2022    22  PHI       KC      J. Hurts                   38
#
#       qb_ranking
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...          ...
# 5866         2.0
# 5867         3.0
# 5868         1.0
# 5869         1.0
# 5870         1.0
#
# [5871 rows x 7 columns]

# %%
lookup = nfl_sub[nfl_sub.qb_ranking==1]
lookup = lookup[['season', 'week', 'team', 'opponent', 'qb']]

# %%
lookup.to_csv('../data/team_primary_qb_lookup.csv')

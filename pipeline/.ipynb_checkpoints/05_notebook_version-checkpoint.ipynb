# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

# %%
# Import data

rb = pd.read_csv('data/04_initial_rushing_values.csv')
rb = rb.drop(columns = ['Unnamed: 0'])
pass_def = pd.read_csv('data/04_initial_pass_defense_values.csv')
pass_def = pass_def.drop(columns = ['Unnamed: 0'])
rush_def = pd.read_csv('data/04_initial_rush_defense_values.csv')
rush_def = rush_def.drop(columns = ['Unnamed: 0'])
qb = pd.read_csv('data/04_initial_qb_values.csv')
qb = qb.drop(columns = ['Unnamed: 0'])
qb = qb.drop(columns = ['Unnamed: 0.1'])
st = pd.read_csv('data/04_initial_st_values.csv')
st = st.drop(columns = ['Unnamed: 0'])
extra = pd.read_csv('data/04_initial_extra_values.csv')
extra = extra.drop(columns = ['Unnamed: 0'])

# %%
extra
# Out:
#       season  week team opponent  score  opponent_score  total_plays  \
# 0       2014     1  ARI      LAC     18              17         67.0
# 1       2014     1  ATL       NO     37              34         72.0
# 2       2014     1  BAL      CIN     16              23         87.0
# 3       2014     1  BUF      CHI     23              20         59.0
# 4       2014     1  CAR       TB     20              14         71.0
# ...      ...   ...  ...      ...    ...             ...          ...
# 4875    2022    21   KC      CIN     23              20         69.0
# 4876    2022    21  PHI       SF     31               7         71.0
# 4877    2022    21   SF      PHI      7              31         45.0
# 4878    2022    22   KC      PHI     38              35         55.0
# 4879    2022    22  PHI       KC     35              38         74.0
#
#       total_possession_time_seconds  pass_percentage  run_percentage  \
# 0                            1909.0         0.606061        0.393939
# 1                            1878.0         0.632353        0.367647
# 2                            1770.0         0.755814        0.244186
# 3                            1832.0         0.425926        0.574074
# 4                            2112.0         0.507463        0.492537
# ...                             ...              ...             ...
# 4875                         1971.0         0.696970        0.303030
# 4876                         2246.0         0.382353        0.617647
# 4877                         1354.0         0.466667        0.533333
# 4878                         1453.0         0.529412        0.470588
# 4879                         2147.0         0.547945        0.452055
#
#       total_plays_standardized  total_possession_time_standardized  \
# 0                     0.122744                            0.332304
# 1                     0.683585                            0.216847
# 2                     2.366110                           -0.185390
# 3                    -0.774603                            0.045524
# 4                     0.571417                            1.088360
# ...                        ...                                 ...
# 4875                  0.347080                            0.563217
# 4876                  0.571417                            1.587432
# 4877                 -2.344959                           -1.734748
# 4878                 -1.223276                           -1.366030
# 4879                  0.907922                            1.218715
#
#       pass_percentage_standardized
# 0                         0.156718
# 1                         0.405160
# 2                         1.571768
# 3                        -1.545411
# 4                        -0.774954
# ...                            ...
# 4875                      1.015737
# 4876                     -1.957141
# 4877                     -1.160443
# 4878                     -0.567552
# 4879                     -0.392426
#
# [4880 rows x 13 columns]

# %%
# Put data into one data frame that just has the game identifiers and value numbers

# qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'qb_value', 'passing_value']]
qb = qb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'qb', 'passing_value']]
rb = rb.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rushing_value']]
pass_def = pass_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'pass_def_value']]
rush_def = rush_def.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'rush_def_value']]
st = st.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'special_teams_value']]
extra = extra.copy()[['season', 'week', 'team', 'opponent', 'score', 'opponent_score', 'total_plays_standardized', 'total_possession_time_standardized', 'pass_percentage_standardized']]
df = qb.copy()
df = df.merge(rb).merge(pass_def).merge(rush_def).merge(st).merge(extra)
df = df.drop_duplicates()
df.head()
# Out:
#    season  week team opponent  score  opponent_score           qb  \
# 0    2014     1  ARI      LAC     18              17    C. Palmer
# 1    2014     1  ATL       NO     37              34      M. Ryan
# 2    2014     1  BAL      CIN     16              23    J. Flacco
# 3    2014     1  BUF      CHI     23              20    E. Manuel
# 4    2014     1  CAR       TB     20              14  D. Anderson
#
#    passing_value  rushing_value  pass_def_value  rush_def_value  \
# 0       0.366264      -1.119941        0.027688        1.468394
# 1       1.099442       0.747193       -0.559094       -1.005162
# 2      -0.333911       0.246643       -0.765953        0.727127
# 3      -0.054710       0.919752        0.504718       -0.187514
# 4       0.643818      -0.619783        0.982581       -0.392165
#
#    special_teams_value  total_plays_standardized  \
# 0            -0.996743                  0.122744
# 1            -0.243872                  0.683585
# 2            -0.442100                  2.366110
# 3             0.780553                 -0.774603
# 4            -0.725290                  0.571417
#
#    total_possession_time_standardized  pass_percentage_standardized
# 0                            0.332304                      0.156718
# 1                            0.216847                      0.405160
# 2                           -0.185390                      1.571768
# 3                            0.045524                     -1.545411
# 4                            1.088360                     -0.774954

# %%
# Fix team names

# Move to helper functions

def fix_team_names(game, is_team=True):
    team_mapping = {
        'ARI':'Arizona Cardinals',
        'ATL':'Atlanta Falcons',
        'BAL':'Baltimore Ravens',
        'BUF':'Buffalo Bills',
        'CAR':'Carolina Panthers',
        'CHI':'Chicago Bears',
        'CIN':'Cincinnati Bengals',
        'CLE':'Cleveland Browns',
        'DAL':'Dallas Cowboys',
        'DEN':'Denver Broncos',
        'DET':'Detroit Lions',
        'GB':'Green Bay Packers',
        'HOU':'Houston Texans',
        'IND':'Indianapolis Colts',
        'JAX':'Jacksonville Jaguars',
        'KC':'Kansas City Chiefs',
        'OAK':'Las Vegas Raiders',
        'LV':'Las Vegas Raiders',
        'LAC':'Los Angeles Chargers',
        'LAR':'Los Angeles Rams',
        'LA':'Los Angeles Rams',
        'MIA':'Miami Dolphins',
        'MIN':'Minnesota Vikings',
        'NE':'New England Patriots',
        'NO':'New Orleans Saints',
        'NYG':'New York Giants',
        'NYJ':'New York Jets',
        'PHI':'Philadelphia Eagles',
        'PIT':'Pittsburgh Steelers',
        'SF':'San Francisco 49ers',
        'SEA':'Seattle Seahawks',
        'TB':'Tampa Bay Buccaneers',
        'TEN':'Tennessee Titans',
        'WSH':'Washington Football Team',
        'WAS':'Washington Football Team'
    }
    
    if is_team:
        return team_mapping[game['team']]
    
    else:
        return team_mapping[game['opponent']]
    
df['team_full'] = df.apply(lambda x: fix_team_names(x, is_team=True), axis=1)
df['opponent_full'] = df.apply(lambda x: fix_team_names(x, is_team=False), axis=1)
df.head()
# Out:
#    season  week team opponent  score  opponent_score           qb  \
# 0    2014     1  ARI      LAC     18              17    C. Palmer
# 1    2014     1  ATL       NO     37              34      M. Ryan
# 2    2014     1  BAL      CIN     16              23    J. Flacco
# 3    2014     1  BUF      CHI     23              20    E. Manuel
# 4    2014     1  CAR       TB     20              14  D. Anderson
#
#    passing_value  rushing_value  pass_def_value  rush_def_value  \
# 0       0.366264      -1.119941        0.027688        1.468394
# 1       1.099442       0.747193       -0.559094       -1.005162
# 2      -0.333911       0.246643       -0.765953        0.727127
# 3      -0.054710       0.919752        0.504718       -0.187514
# 4       0.643818      -0.619783        0.982581       -0.392165
#
#    special_teams_value  total_plays_standardized  \
# 0            -0.996743                  0.122744
# 1            -0.243872                  0.683585
# 2            -0.442100                  2.366110
# 3             0.780553                 -0.774603
# 4            -0.725290                  0.571417
#
#    total_possession_time_standardized  pass_percentage_standardized  \
# 0                            0.332304                      0.156718
# 1                            0.216847                      0.405160
# 2                           -0.185390                      1.571768
# 3                            0.045524                     -1.545411
# 4                            1.088360                     -0.774954
#
#            team_full         opponent_full
# 0  Arizona Cardinals  Los Angeles Chargers
# 1    Atlanta Falcons    New Orleans Saints
# 2   Baltimore Ravens    Cincinnati Bengals
# 3      Buffalo Bills         Chicago Bears
# 4  Carolina Panthers  Tampa Bay Buccaneers

# %%
# Save raw data frame with values

df.to_csv('data/05_value_models_combined.csv')

# %%
# Save data frame with past 5 games rolling stats

# Weighted average approach

def weighted_avg(values):
    if len(values) == 1:
        weights = np.array([1])
    elif len(values) == 2:
        weights = np.array([.25, .75])
    elif len(values) == 3:
        weights = np.array([.1, .3, .6])
    elif len(values) == 4:
        weights = np.array([.1, .15, .25, .5])
    elif len(values) == 5:
        weights = np.array([.1, .1, .15, .15, .5])
    
    return np.sum(weights * values)

offense_base = df.copy()[['season', 'week', 'team', 'qb']]
defense_base = df.copy()[['season', 'week', 'team']]

offense_rolling = df[['team', 'qb', 'passing_value', 'rushing_value',
                     'total_plays_standardized', 'total_possession_time_standardized', 
                     'pass_percentage_standardized']]
offense_rolling = offense_rolling.groupby(by=['team', 'qb']).rolling(
    5, closed='left', min_periods=1).apply(lambda x: weighted_avg(x)).reset_index(level=['team', 'qb'], drop=True)

defense_rolling = df[['team', 'pass_def_value', 'rush_def_value', 'special_teams_value']]
defense_rolling = defense_rolling.groupby(by=['team']).rolling(
    5, closed='left', min_periods=1).apply(lambda x: weighted_avg(x)).reset_index(level=['team'], drop=True)

offense = offense_base.join(offense_rolling)
defense = defense_base.join(defense_rolling).dropna()

combined = offense.merge(defense, how='left')

# %%
combined
# Out:
#       season  week team           qb  passing_value  rushing_value  \
# 0       2014     1  ARI    C. Palmer            NaN            NaN
# 1       2014     1  ATL      M. Ryan            NaN            NaN
# 2       2014     1  BAL    J. Flacco            NaN            NaN
# 3       2014     1  BUF    E. Manuel            NaN            NaN
# 4       2014     1  CAR  D. Anderson            NaN            NaN
# ...      ...   ...  ...          ...            ...            ...
# 4866    2022    21   KC   P. Mahomes       0.601189       0.460893
# 4867    2022    21  PHI     J. Hurts       0.336387       1.784683
# 4868    2022    21   SF   J. Johnson            NaN            NaN
# 4869    2022    22   KC   P. Mahomes       0.404213      -0.042373
# 4870    2022    22  PHI     J. Hurts      -0.074393       1.385724
#
#       total_plays_standardized  total_possession_time_standardized  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN                                 NaN
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN
# ...                        ...                                 ...
# 4866                 -0.112810                            0.293756
# 4867                  0.571417                            0.722064
# 4868                       NaN                                 NaN
# 4869                 -0.157677                            0.089844
# 4870                  0.644326                            1.049812
#
#       pass_percentage_standardized  pass_def_value  rush_def_value  \
# 0                              NaN             NaN             NaN
# 1                              NaN             NaN             NaN
# 2                              NaN             NaN             NaN
# 3                              NaN             NaN             NaN
# 4                              NaN             NaN             NaN
# ...                            ...             ...             ...
# 4866                     -0.042104        0.667588       -0.924365
# 4867                     -1.156340        1.071502       -0.584493
# 4868                           NaN        0.459523        0.086384
# 4869                      0.486147        0.561616       -0.780062
# 4870                     -1.428685        1.027831        0.814121
#
#       special_teams_value
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 4866            -0.554750
# 4867             0.282612
# 4868            -0.025820
# 4869            -0.348834
# 4870            -0.104304
#
# [4871 rows x 12 columns]

# %%
# NOTE: Pretty sure everything in previous code block is good, but do some checks next time i look at this

combined[combined.team=='LV'].tail(15)
# Out:
#       season  week team          qb  passing_value  rushing_value  \
# 4386    2022     3   LV     D. Carr      -0.289039       0.240253
# 4418    2022     4   LV     D. Carr      -0.072366       0.440675
# 4450    2022     5   LV     D. Carr      -0.275119       0.741493
# 4508    2022     7   LV     D. Carr       0.167159       0.637845
# 4536    2022     8   LV     D. Carr       0.621373       0.933959
# 4564    2022     9   LV     D. Carr      -0.468231      -0.776979
# 4591    2022    10   LV     D. Carr       0.254681      -0.433269
# 4620    2022    11   LV     D. Carr       0.065582      -0.781660
# 4649    2022    12   LV     D. Carr       0.295305      -0.329531
# 4679    2022    13   LV     D. Carr       0.488269      -0.183098
# 4707    2022    14   LV     D. Carr      -0.158723       0.268598
# 4737    2022    15   LV     D. Carr      -0.042790       0.375619
# 4769    2022    16   LV     D. Carr      -0.221285       0.360137
# 4799    2022    17   LV  J. Stidham            NaN            NaN
# 4831    2022    18   LV  J. Stidham       0.433121      -0.045708
#
#       total_plays_standardized  total_possession_time_standardized  \
# 4386                  0.038617                           -0.027289
# 4418                  0.201262                            0.070663
# 4450                  0.975223                            0.740127
# 4508                 -0.174502                            0.033419
# 4536                  0.178828                            0.658749
# 4564                 -0.454923                           -0.310531
# 4591                 -0.438098                           -0.205502
# 4620                 -0.466140                           -0.134366
# 4649                 -0.253020                            0.163960
# 4679                  0.571417                            0.733051
# 4707                 -0.079159                            0.155394
# 4737                 -0.124027                            0.276251
# 4769                 -0.039900                            0.507165
# 4799                       NaN                                 NaN
# 4831                  0.234912                            0.373272
#
#       pass_percentage_standardized  pass_def_value  rush_def_value  \
# 4386                      0.806264       -0.013109       -0.811653
# 4418                      1.097439       -0.866178        0.148637
# 4450                      0.216354       -0.195409        0.581759
# 4508                      0.149405       -0.643835        0.064132
# 4536                     -0.277125       -0.228220       -0.188846
# 4564                      0.813593       -0.656645       -0.005825
# 4591                      0.439543       -0.824652        0.040282
# 4620                      0.492800       -0.458321       -0.840738
# 4649                      0.402571       -0.319527       -0.189754
# 4679                     -0.168349       -0.505156        0.245931
# 4707                     -0.391962        0.027123        0.028800
# 4737                     -1.363946       -0.062324        0.741554
# 4769                     -0.300723        0.488679        0.010537
# 4799                           NaN        0.123155        0.376274
# 4831                     -0.702300       -0.100750       -0.993759
#
#       special_teams_value
# 4386             0.778108
# 4418             0.387344
# 4450            -0.110940
# 4508             0.671475
# 4536             0.437196
# 4564             0.536275
# 4591             0.592378
# 4620             1.073924
# 4649             0.637303
# 4679            -0.010756
# 4707             0.448950
# 4737             0.367414
# 4769             0.391560
# 4799             0.672824
# 4831             0.681719

# %%
df[df.team == 'LV'].tail(15)
# Out:
#       season  week team opponent  score  opponent_score          qb  \
# 4386    2022     3   LV      TEN     22              24     D. Carr
# 4418    2022     4   LV      DEN     32              23     D. Carr
# 4450    2022     5   LV       KC     29              30     D. Carr
# 4508    2022     7   LV      HOU     38              20     D. Carr
# 4536    2022     8   LV       NO      0              24     D. Carr
# 4564    2022     9   LV      JAX     20              27     D. Carr
# 4591    2022    10   LV      IND     20              25     D. Carr
# 4620    2022    11   LV      DEN     22              16     D. Carr
# 4649    2022    12   LV      SEA     40              34     D. Carr
# 4679    2022    13   LV      LAC     27              20     D. Carr
# 4707    2022    14   LV       LA     16              17     D. Carr
# 4737    2022    15   LV       NE     30              24     D. Carr
# 4769    2022    16   LV      PIT     10              13     D. Carr
# 4799    2022    17   LV       SF     34              37  J. Stidham
# 4831    2022    18   LV       KC     13              31  J. Stidham
#
#       passing_value  rushing_value  pass_def_value  rush_def_value  \
# 4386       0.246131       0.561686       -1.252657        0.235539
# 4418      -0.389152       1.057473        0.216146        1.344218
# 4450       0.558517       0.784474       -0.846055       -0.236504
# 4508       1.218571       1.203649       -0.129459       -0.324343
# 4536      -1.440984      -2.474226       -0.813333       -0.159348
# 4564       0.542212      -0.853754       -1.240484        0.004129
# 4591       0.045378      -0.962550       -0.105394       -1.522742
# 4620       0.458815       0.139945       -0.046733        0.172814
# 4649       1.005034       0.546181       -0.553910        0.927884
# 4679      -0.874118       0.694619        0.503614        0.031113
# 4707      -0.225692       0.543519       -0.079134        1.465395
# 4737      -0.405397       0.211607        0.970142       -0.648017
# 4769      -0.616708      -0.672422       -0.010933        0.315534
# 4799       0.433121      -0.045708       -0.574159       -2.187076
# 4831      -0.874341       0.054613       -0.021967       -2.674979
#
#       special_teams_value  total_plays_standardized  \
# 4386            -0.218493                  0.234912
# 4418            -0.504775                  1.917436
# 4450             1.170337                 -0.774603
# 4508             0.578142                  0.010575
# 4536             0.692660                 -1.111108
# 4564             0.670404                 -0.774603
# 4591             1.389234                 -0.213761
# 4620             0.402555                  0.010575
# 4649            -0.831662                  1.580932
# 4679             0.614703                 -0.438098
# 4707             0.441557                 -0.550266
# 4737             0.552064                 -0.101593
# 4769             1.090953                 -1.447612
# 4799             0.659282                  0.234912
# 4831             0.129630                  0.347080
#
#       total_possession_time_standardized  pass_percentage_standardized  \
# 4386                            0.093941                      1.158906
# 4418                            1.714062                     -0.845470
# 4450                           -0.323194                     -0.265256
# 4508                            0.905864                     -0.578040
# 4536                           -1.157463                      1.817487
# 4564                           -0.613698                      0.729397
# 4591                            0.146083                      0.390195
# 4620                            0.518524                      0.221375
# 4649                            1.620952                     -1.029545
# 4679                           -0.237532                     -0.765392
# 4707                            0.004555                     -2.311726
# 4737                            0.656328                      0.483324
# 4769                           -0.665840                      0.426538
# 4799                            0.373272                     -0.702300
# 4831                            0.868620                      0.353309
#
#               team_full         opponent_full
# 4386  Las Vegas Raiders      Tennessee Titans
# 4418  Las Vegas Raiders        Denver Broncos
# 4450  Las Vegas Raiders    Kansas City Chiefs
# 4508  Las Vegas Raiders        Houston Texans
# 4536  Las Vegas Raiders    New Orleans Saints
# 4564  Las Vegas Raiders  Jacksonville Jaguars
# 4591  Las Vegas Raiders    Indianapolis Colts
# 4620  Las Vegas Raiders        Denver Broncos
# 4649  Las Vegas Raiders      Seattle Seahawks
# 4679  Las Vegas Raiders  Los Angeles Chargers
# 4707  Las Vegas Raiders      Los Angeles Rams
# 4737  Las Vegas Raiders  New England Patriots
# 4769  Las Vegas Raiders   Pittsburgh Steelers
# 4799  Las Vegas Raiders   San Francisco 49ers
# 4831  Las Vegas Raiders    Kansas City Chiefs

# %%
# fix team names

combined['team_full'] = combined.apply(lambda x: fix_team_names(x, is_team=True), axis=1)
# combined['opponent_full'] = combined.apply(lambda x: fix_team_names(x, is_team=False), axis=1)
combined.head()
# Out:
#    season  week team           qb  passing_value  rushing_value  \
# 0    2014     1  ARI    C. Palmer            NaN            NaN
# 1    2014     1  ATL      M. Ryan            NaN            NaN
# 2    2014     1  BAL    J. Flacco            NaN            NaN
# 3    2014     1  BUF    E. Manuel            NaN            NaN
# 4    2014     1  CAR  D. Anderson            NaN            NaN
#
#    total_plays_standardized  total_possession_time_standardized  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#    pass_percentage_standardized  pass_def_value  rush_def_value  \
# 0                           NaN             NaN             NaN
# 1                           NaN             NaN             NaN
# 2                           NaN             NaN             NaN
# 3                           NaN             NaN             NaN
# 4                           NaN             NaN             NaN
#
#    special_teams_value          team_full
# 0                  NaN  Arizona Cardinals
# 1                  NaN    Atlanta Falcons
# 2                  NaN   Baltimore Ravens
# 3                  NaN      Buffalo Bills
# 4                  NaN  Carolina Panthers

# %%
# Save aggregated data frame with values

combined.to_csv('data/05_value_models_aggregated.csv')

# %%
combined[(combined.team == 'BAL') & (combined.season==2022)]
# Out:
#       season  week team          qb  passing_value  rushing_value  \
# 4306    2022     1  BAL  L. Jackson      -0.415754       0.485301
# 4338    2022     2  BAL  L. Jackson      -0.137177       0.193148
# 4370    2022     3  BAL  L. Jackson       0.681141      -0.124710
# 4402    2022     4  BAL  L. Jackson       0.218432       1.283315
# 4434    2022     5  BAL  L. Jackson      -0.216507       0.983557
# 4466    2022     6  BAL  L. Jackson      -0.260497       0.913281
# 4494    2022     7  BAL  L. Jackson      -0.200016       1.505811
# 4522    2022     8  BAL  L. Jackson      -0.673509       0.912814
# 4551    2022     9  BAL  L. Jackson      -0.349834       1.362202
# 4605    2022    11  BAL  L. Jackson       0.020695       1.035226
# 4633    2022    12  BAL  L. Jackson      -0.338241       0.566294
# 4664    2022    13  BAL  T. Huntley      -0.903672       0.588670
# 4694    2022    14  BAL  T. Huntley      -0.405933       0.560989
# 4721    2022    15  BAL  T. Huntley      -0.118231       0.676406
# 4753    2022    16  BAL  T. Huntley      -1.055927       0.660167
# 4785    2022    17  BAL  T. Huntley      -0.493282       0.521435
# 4815    2022    18  BAL    A. Brown            NaN            NaN
# 4845    2022    19  BAL  T. Huntley       0.008815       0.046649
#
#       total_plays_standardized  total_possession_time_standardized  \
# 4306                  0.975223                            1.349442
# 4338                  0.004967                            0.501020
# 4370                 -0.499790                           -0.275894
# 4402                 -0.499790                            0.052414
# 4434                 -0.353972                            0.787986
# 4466                 -0.404447                            0.055579
# 4494                 -0.477357                           -0.102522
# 4522                 -0.157677                            0.513496
# 4551                  0.532158                            1.118900
# 4605                  0.184436                            1.171228
# 4633                  0.268562                            0.878676
# 4664                  0.818187                            0.314799
# 4694                  0.610676                            0.308840
# 4721                  0.218087                            0.475507
# 4753                  0.122744                           -0.096004
# 4785                 -0.550266                           -0.300289
# 4815                       NaN                                 NaN
# 4845                 -0.970897                           -0.621147
#
#       pass_percentage_standardized  pass_def_value  rush_def_value  \
# 4306                      0.163035       -0.561149        0.493865
# 4338                      0.058586       -0.104427        0.357672
# 4370                     -0.163475       -0.906975       -0.275513
# 4402                     -0.093808        0.061227       -0.458992
# 4434                     -0.448500       -0.135005       -0.170218
# 4466                     -0.338509        0.320536       -0.601620
# 4494                     -0.259192       -0.528033       -0.176052
# 4522                     -1.489984        0.013299       -0.650980
# 4551                     -0.658421       -0.227432       -0.164781
# 4605                     -1.446409        0.164520        0.101168
# 4633                     -0.766208        0.804131        0.301297
# 4664                     -0.459973       -0.226250        1.100445
# 4694                     -0.129478        0.113002        1.090537
# 4721                     -1.376789       -0.023500        0.675097
# 4753                     -0.748505        0.239210       -0.071832
# 4785                     -1.670043        0.046439        0.893889
# 4815                           NaN       -0.104945       -0.502998
# 4845                     -1.415910        0.334822        0.259330
#
#       special_teams_value         team_full
# 4306             0.506075  Baltimore Ravens
# 4338             1.035229  Baltimore Ravens
# 4370             0.958328  Baltimore Ravens
# 4402             0.878303  Baltimore Ravens
# 4434             0.576509  Baltimore Ravens
# 4466             1.140967  Baltimore Ravens
# 4494            -0.017267  Baltimore Ravens
# 4522             1.002998  Baltimore Ravens
# 4551             0.902648  Baltimore Ravens
# 4605             0.712932  Baltimore Ravens
# 4633             0.098064  Baltimore Ravens
# 4664             0.150370  Baltimore Ravens
# 4694             0.017128  Baltimore Ravens
# 4721             0.584930  Baltimore Ravens
# 4753             0.124101  Baltimore Ravens
# 4785            -0.075770  Baltimore Ravens
# 4815             0.616377  Baltimore Ravens
# 4845             0.308205  Baltimore Ravens

# %%
df[df.team == 'SF'].tail(15)
# Out:
#       season  week team opponent  score  opponent_score            qb  \
# 4489    2022     6   SF      ATL     14              28  J. Garoppolo
# 4516    2022     7   SF       KC     23              44  J. Garoppolo
# 4546    2022     8   SF       LA     31              14  J. Garoppolo
# 4599    2022    10   SF      LAC     22              16  J. Garoppolo
# 4628    2022    11   SF      ARI     38              10  J. Garoppolo
# 4659    2022    12   SF       NO     13               0  J. Garoppolo
# 4689    2022    13   SF      MIA     33              17      B. Purdy
# 4716    2022    14   SF       TB     35               7      B. Purdy
# 4747    2022    15   SF      SEA     21              13      B. Purdy
# 4779    2022    16   SF      WAS     37              20      B. Purdy
# 4809    2022    17   SF       LV     37              34      B. Purdy
# 4841    2022    18   SF      ARI     38              13      B. Purdy
# 4855    2022    19   SF      SEA     41              23      B. Purdy
# 4864    2022    20   SF      DAL     19              12      B. Purdy
# 4868    2022    21   SF      PHI      7              31    J. Johnson
#
#       passing_value  rushing_value  pass_def_value  rush_def_value  \
# 4489       0.150830      -2.791287       -1.014961       -0.508785
# 4516       0.087143       0.580775       -2.218665       -1.196759
# 4546       1.600826       0.151594        0.054764        0.743690
# 4599       0.369584       0.220537        0.736455       -0.106955
# 4628       1.536268       1.026531        0.550368        0.747276
# 4659      -0.001005      -0.190469        0.640552        1.454999
# 4689      -0.053421      -0.126492        1.348306       -0.111838
# 4716       1.089423       0.527490        0.606800        0.483648
# 4747       0.651377       1.057992        1.113096       -0.261235
# 4779       0.791740       0.146685       -0.484144        2.863790
# 4809       0.552776       2.237359       -0.452415        0.206605
# 4841       0.771077      -0.094765        1.819759        0.196554
# 4855       2.023435       0.681747       -0.139021       -0.472432
# 4864       0.259976      -0.198592        0.602136       -0.358547
# 4868      -0.560147      -2.345301        0.172187       -1.337421
#
#       special_teams_value  total_plays_standardized  \
# 4489             0.131760                 -0.998939
# 4516             1.248613                  1.020090
# 4546             0.408923                 -1.447612
# 4599            -0.568912                  0.795753
# 4628             0.188465                 -0.886771
# 4659             1.070847                  0.347080
# 4689             0.470714                  2.029605
# 4716             1.237796                 -0.774603
# 4747            -2.123656                 -0.438098
# 4779             1.415588                 -1.335444
# 4809            -0.659282                  0.010575
# 4841             0.633354                 -0.438098
# 4855             0.568763                  0.234912
# 4864            -0.563537                  0.122744
# 4868             0.597381                 -2.344959
#
#       total_possession_time_standardized  pass_percentage_standardized  \
# 4489                           -0.837163                      1.226723
# 4516                            0.764336                      1.217384
# 4546                           -0.088555                     -0.300324
# 4599                            1.486873                     -1.598667
# 4628                           -0.263603                     -0.587765
# 4659                            1.006423                     -0.045922
# 4689                            2.324866                      0.024851
# 4716                            0.522249                     -1.822974
# 4747                            0.600462                     -1.171305
# 4779                           -0.874407                     -0.938109
# 4809                            0.175878                     -0.058037
# 4841                            0.872344                     -1.852352
# 4855                            0.544595                     -0.845470
# 4864                            0.570666                     -0.920464
# 4868                           -1.734748                     -1.160443
#
#                 team_full             opponent_full
# 4489  San Francisco 49ers           Atlanta Falcons
# 4516  San Francisco 49ers        Kansas City Chiefs
# 4546  San Francisco 49ers          Los Angeles Rams
# 4599  San Francisco 49ers      Los Angeles Chargers
# 4628  San Francisco 49ers         Arizona Cardinals
# 4659  San Francisco 49ers        New Orleans Saints
# 4689  San Francisco 49ers            Miami Dolphins
# 4716  San Francisco 49ers      Tampa Bay Buccaneers
# 4747  San Francisco 49ers          Seattle Seahawks
# 4779  San Francisco 49ers  Washington Football Team
# 4809  San Francisco 49ers         Las Vegas Raiders
# 4841  San Francisco 49ers         Arizona Cardinals
# 4855  San Francisco 49ers          Seattle Seahawks
# 4864  San Francisco 49ers            Dallas Cowboys
# 4868  San Francisco 49ers       Philadelphia Eagles

# %%
offense_base[offense_base.team == 'SF']
# Out:
#       season  week team             qb
# 28      2014     1   SF  C. Kaepernick
# 60      2014     2   SF  C. Kaepernick
# 92      2014     3   SF  C. Kaepernick
# 118     2014     4   SF  C. Kaepernick
# 148     2014     5   SF  C. Kaepernick
# ...      ...   ...  ...            ...
# 4809    2022    17   SF       B. Purdy
# 4841    2022    18   SF       B. Purdy
# 4855    2022    19   SF       B. Purdy
# 4864    2022    20   SF       B. Purdy
# 4868    2022    21   SF     J. Johnson
#
# [153 rows x 4 columns]

# %%
defense
# Out:
#       season  week team  pass_def_value  rush_def_value  special_teams_value
# 32      2014     2  ARI        0.027688        1.468394            -0.996743
# 33      2014     2  ATL       -0.559094       -1.005162            -0.243872
# 34      2014     2  BAL       -0.765953        0.727127            -0.442100
# 35      2014     2  BUF        0.504718       -0.187514             0.780553
# 36      2014     2  CAR        0.982581       -0.392165            -0.725290
# ...      ...   ...  ...             ...             ...                  ...
# 4866    2022    21   KC        0.667588       -0.924365            -0.554750
# 4867    2022    21  PHI        1.071502       -0.584493             0.282612
# 4868    2022    21   SF        0.459523        0.086384            -0.025820
# 4869    2022    22   KC        0.561616       -0.780062            -0.348834
# 4870    2022    22  PHI        1.027831        0.814121            -0.104304
#
# [4839 rows x 6 columns]

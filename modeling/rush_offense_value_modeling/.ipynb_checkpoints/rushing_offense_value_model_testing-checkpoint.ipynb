# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
rb = pd.read_csv('rush_offense_value_data/rb.csv')
rb = rb.drop(columns = ['Unnamed: 0'])

# %%
# Import selected model for testing

model_name = 'logistic_regression'
model_filepath = 'rush_offense_value_saved_models/' + model_name + '.joblib'

clf = load(model_filepath)

# %%
# Add model predictions to the data frame

from rushing_offense_value_helper_functions import get_features, get_label

rb_features = get_features(rb)
rb_win_pred = clf.predict(rb_features)
rb_win_probs = clf.predict_proba(rb_features)[:,1]

rb['rb_win_pred'] = rb_win_pred
rb['rb_value'] = rb_win_probs

# %%
# See descriptive stats for qb value

rb.rb_value.describe()
# Out:
# count    5339.000000
# mean        0.504126
# std         0.247354
# min         0.000029
# 25%         0.305934
# 50%         0.511331
# 75%         0.708077
# max         0.986027
# Name: rb_value, dtype: float64

# %%
# See what factors were most important to qb value

feature_importance = rb_features.columns.to_frame().reset_index(drop=True)
feature_importance.columns = ['feature']
feature_importance['mean'] = rb_features.mean().to_numpy()
feature_importance['std'] = rb_features.std().to_numpy()
feature_importance['importance'] = clf.coef_[0]
feature_importance['importance'] = feature_importance['importance'] * feature_importance['std']
feature_importance['abs_importance'] = abs(feature_importance.importance)
feature_importance_sorted = feature_importance.sort_values(by='abs_importance', ascending=False)
feature_importance_sorted
# Out:
#                  feature      mean       std  importance  abs_importance
# 0  rushing_epa_per_carry -0.059581  0.214574     1.33834         1.33834

# %%
feature_importance_sorted.plot.bar(x='feature', y='importance')

feature_importance_sorted.plot.bar(x='feature', y='abs_importance')

# %%
# See where the algorithm went wrong

incorrect = rb[rb.rb_win != rb_win_pred]
pred_win_but_loss = len(incorrect[incorrect.rb_win_pred==1])
pred_loss_but_win = len(incorrect[incorrect.rb_win_pred==0])
total = len(incorrect)

print('Predicted Win, Actual Loss: {}, {}%'.format(pred_win_but_loss, np.round(pred_win_but_loss*100/total, 2)))
print('Predicted Loss, Actual Win: {}, {}%'.format(pred_loss_but_win, np.round(pred_loss_but_win*100/total, 2)))
# Out:
# Predicted Win, Actual Loss: 791, 53.37%
# Predicted Loss, Actual Win: 691, 46.63%

# %%
incorrect.head(10)
# Out:
#     season  week team opponent  score  opponent_score  total_rushes  \
# 0     2014     1  ARI      LAC     18              17            26
# 2     2014     1  BAL      CIN     16              23            21
# 4     2014     1  CAR       TB     20              14            33
# 5     2014     1  CHI      BUF     20              23            18
# 8     2014     1  DAL       SF     17              28            23
# 9     2014     1  DEN      IND     31              24            28
# 11    2014     1   GB      SEA     16              36            21
# 12    2014     1  HOU      WAS     17               6            32
# 20    2014     1  MIN       LA     34               6            29
# 21    2014     1   NE      MIA     20              33            20
#
#     total_rush_yards  rushing_epa  rush_tds  qb_rush_yards  qb_rushing_epa  \
# 0              110.0    -7.697317       0.0           30.0        1.681309
# 2               94.0    -0.093163       1.0            7.0        1.793058
# 4              113.0    -6.247634       0.0           10.0        1.929123
# 5               86.0    -0.055888       0.0            0.0        0.000000
# 8              127.0    -1.887739       1.0            0.0        0.000000
# 9              105.0     0.667838       1.0            0.0        0.000000
# 11              80.0     0.380068       1.0            0.0        0.000000
# 12             117.0    -9.128966       0.0           12.0        0.282968
# 20             188.0    -1.898818       1.0            0.0       -4.712413
# 21              89.0     3.505328       1.0            3.0        1.358701
#
#     qb_rush_tds  rb_win       ypc  rushing_epa_per_carry  rb_win_pred  \
# 0           0.0       1  4.230769              -0.296051            0
# 2           0.0       0  4.476190              -0.004436            1
# 4           0.0       1  3.424242              -0.189322            0
# 5           0.0       0  4.777778              -0.003105            1
# 8           0.0       1  5.521739              -0.082076            0
# 9           0.0       0  3.750000               0.023851            1
# 11          0.0       0  3.809524               0.018098            1
# 12          0.0       1  3.656250              -0.285280            0
# 20          0.0       1  6.482759              -0.065476            0
# 21          0.0       0  4.450000               0.175266            1
#
#     rb_value
# 0   0.186079
# 2   0.584958
# 4   0.307889
# 5   0.586973
# 8   0.464786
# 9   0.627053
# 11  0.618624
# 12  0.196468
# 20  0.490611
# 21  0.812144

# %%
# Look at some of the best rushing offenses by rb value

rb_avg_value = rb.groupby(by='team').rb_value.agg(['mean', 'min', 'max', 'count'])
rb_avg_value.sort_values(by='mean', ascending=False)
# Out:
#           mean       min       max  count
# team
# KC    0.595928  0.013160  0.978185    177
# BAL   0.589936  0.011074  0.973945    173
# GB    0.583207  0.045986  0.979453    170
# DAL   0.566152  0.032502  0.944428    170
# BUF   0.565719  0.047486  0.986027    181
# SEA   0.564989  0.002622  0.972146    166
# NE    0.558142  0.064090  0.952833    180
# CAR   0.541503  0.003361  0.978439    179
# NO    0.538975  0.015258  0.962222    183
# TEN   0.530673  0.003665  0.973950    186
# PHI   0.523939  0.016573  0.955133    169
# CLE   0.509730  0.044117  0.969739    173
# IND   0.505517  0.010078  0.966445    160
# SF    0.503891  0.024123  0.942553    164
# CHI   0.495049  0.000029  0.950225    162
# CIN   0.488426  0.008542  0.962079    166
# JAX   0.484663  0.015673  0.967267    162
# WAS   0.483862  0.010931  0.961799    159
# PIT   0.482125  0.010876  0.954918    168
# MIN   0.479936  0.008292  0.943057    154
# DEN   0.477718  0.001272  0.928391    161
# ARI   0.477477  0.030916  0.973907    162
# NYG   0.472600  0.022982  0.937219    158
# TB    0.470461  0.018812  0.928505    161
# LAC   0.468694  0.009248  0.965396    152
# HOU   0.465255  0.049530  0.974900    167
# NYJ   0.458229  0.020700  0.879274    161
# ATL   0.454889  0.009418  0.976380    155
# LA    0.445523  0.020797  0.963535    176
# LV    0.440970  0.006463  0.902496    156
# DET   0.429580  0.013611  0.938752    155
# MIA   0.428388  0.016198  0.978713    173

# %%
rb
# Out:
#       season  week team opponent  score  opponent_score  total_rushes  \
# 0       2014     1  ARI      LAC     18              17            26
# 1       2014     1  ATL       NO     37              34            25
# 2       2014     1  BAL      CIN     16              23            21
# 3       2014     1  BUF      CHI     23              20            31
# 4       2014     1  CAR       TB     20              14            33
# ...      ...   ...  ...      ...    ...             ...           ...
# 5334    2022    10   TB      SEA     21              16            38
# 5335    2022    10  TEN      DEN     17              10            23
# 5336    2022    10  WAS      PHI     32              21            47
# 5337    2022    11   GB      TEN     17              27            19
# 5338    2022    11  TEN       GB     27              17            29
#
#       total_rush_yards  rushing_epa  rush_tds  qb_rush_yards  qb_rushing_epa  \
# 0                110.0    -7.697317       0.0           30.0        1.681309
# 1                123.0     2.559394       1.0           15.0        0.272050
# 2                 94.0    -0.093163       1.0            7.0        1.793058
# 3                197.0     4.315138       1.0           23.0        0.222908
# 4                113.0    -6.247634       0.0           10.0        1.929123
# ...                ...          ...       ...            ...             ...
# 5334             164.0     0.708687       1.0            0.0        0.000000
# 5335              63.0    -9.867366       0.0           12.0        1.323566
# 5336             156.0     3.071281       2.0           14.0        0.929012
# 5337              56.0    -4.261430       0.0            0.0        0.000000
# 5338              91.0    -2.641367       1.0            0.0        0.000000
#
#       qb_rush_tds  rb_win       ypc  rushing_epa_per_carry  rb_win_pred  \
# 0             0.0       1  4.230769              -0.296051            0
# 1             0.0       1  4.920000               0.102376            1
# 2             0.0       0  4.476190              -0.004436            1
# 3             1.0       1  6.354839               0.139198            1
# 4             0.0       1  3.424242              -0.189322            0
# ...           ...     ...       ...                    ...          ...
# 5334          0.0       1  4.315789               0.018650            1
# 5335          0.0       0  2.739130              -0.429016            0
# 5336          0.0       1  3.319149               0.065346            1
# 5337          0.0       0  2.947368              -0.224286            0
# 5338          0.0       0  3.137931              -0.091082            0
#
#       rb_value
# 0     0.186079
# 1     0.732896
# 2     0.584958
# 3     0.775396
# 4     0.307889
# ...        ...
# 5334  0.619435
# 5335  0.090708
# 5336  0.685337
# 5337  0.263456
# 5338  0.450843
#
# [5339 rows x 18 columns]

# %%
rb.sort_values(by='rb_value', ascending = False)
# Out:
#       season  week team opponent  score  opponent_score  total_rushes  \
# 4968    2021    19  BUF       NE     47              17            26
# 2960    2018    16   GB      NYJ     44              38            20
# 2736    2018    10   GB      MIA     31              12            22
# 2892    2018    14  MIA       NE     34              33            21
# 1120    2015    16  CAR      ATL     13              20            20
# ...      ...   ...  ...      ...    ...             ...           ...
# 1149    2015    16  TEN      HOU      6              34            11
# 3088    2019     2  CAR       TB     14              20            19
# 1146    2015    16  SEA       LA     17              23            22
# 1647    2016    14  DEN      TEN     10              13             9
# 3260    2019     7  CHI       NO     25              36             7
#
#       total_rush_yards  rushing_epa  rush_tds  qb_rush_yards  qb_rushing_epa  \
# 4968             176.0    16.197870       2.0           66.0        6.223160
# 2960             130.0    11.202056       3.0           35.0        7.273476
# 2736             198.0    12.302527       2.0           24.0        1.449932
# 2892             189.0    11.640470       2.0           13.0        0.674982
# 1120             155.0    11.044158       1.0           46.0        5.428125
# ...                ...          ...       ...            ...             ...
# 1149              30.0   -10.539284       0.0            0.0        0.000000
# 3088              39.0   -18.469515       0.0            0.0       -8.741419
# 1146              59.0   -22.264070       0.0           38.0       -1.739370
# 1647              18.0   -10.153645       0.0            0.0        0.000000
# 3260              17.0   -12.140250       0.0            0.0        0.000000
#
#       qb_rush_tds  rb_win       ypc  rushing_epa_per_carry  rb_win_pred  \
# 4968          0.0       1  6.769231               0.622995            1
# 2960          2.0       1  6.500000               0.560103            1
# 2736          0.0       1  9.000000               0.559206            1
# 2892          0.0       1  9.000000               0.554308            1
# 1120          1.0       1  7.750000               0.552208            1
# ...           ...     ...       ...                    ...          ...
# 1149          0.0       0  2.727273              -0.958117            0
# 3088          0.0       0  2.052632              -0.972080            0
# 1146          0.0       0  2.681818              -1.012003            0
# 1647          0.0       0  2.000000              -1.128183            0
# 3260          0.0       0  2.428571              -1.734321            0
#
#       rb_value
# 4968  0.986027
# 2960  0.979453
# 2736  0.979340
# 2892  0.978713
# 1120  0.978439
# ...        ...
# 1149  0.003665
# 3088  0.003361
# 1146  0.002622
# 1647  0.001272
# 3260  0.000029
#
# [5339 rows x 18 columns]

# %%
incorrect.sort_values(by='rb_value', ascending=False)
# Out:
#       season  week team opponent  score  opponent_score  total_rushes  \
# 1204    2015    19  SEA      CAR     24              31            12
# 2577    2018     5  JAX       KC     14              30            17
# 258     2014     8  IND      PIT     34              51             9
# 5181    2022     6  CIN       NO     30              26            13
# 4531    2021     6  PHI       TB     22              28            19
# ...      ...   ...  ...      ...    ...             ...           ...
# 2394    2017    17  TEN      JAX     15              10            38
# 4082    2020    12   SF       LA     23              20            33
# 2023    2017     7  CAR      CHI      3              17            30
# 364     2014    11  PHI       GB     20              53            31
# 1259    2016     2   KC      HOU     12              19            19
#
#       total_rush_yards  rushing_epa  rush_tds  qb_rush_yards  qb_rushing_epa  \
# 1204              78.0     6.121391       0.0           32.0        3.446021
# 2577             101.0     8.218390       1.0           34.0        7.619121
# 258               64.0     4.313873       1.0           27.0        2.717112
# 5181              76.0     5.492002       1.0           26.0        3.608881
# 4531             100.0     7.581882       2.0           44.0        5.261005
# ...                ...          ...       ...            ...             ...
# 2394             117.0   -19.525873       0.0           61.0       -6.099564
# 4082             112.0   -17.209580       1.0            0.0        0.000000
# 2023             108.0   -17.080074       0.0           50.0      -12.673642
# 364              109.0   -20.012804       0.0            0.0      -16.318796
# 1259             119.0   -14.281271       0.0            2.0       -5.798549
#
#       qb_rush_tds  rb_win       ypc  rushing_epa_per_carry  rb_win_pred  \
# 1204          0.0       0  6.500000               0.510116            1
# 2577          1.0       0  5.941176               0.483435            1
# 258           0.0       0  7.111111               0.479319            1
# 5181          1.0       0  5.846154               0.422462            1
# 4531          2.0       0  5.263158               0.399046            1
# ...           ...     ...       ...                    ...          ...
# 2394          0.0       1  3.078947              -0.513839            0
# 4082          0.0       1  3.393939              -0.521502            0
# 2023          0.0       1  3.600000              -0.569336            0
# 364           0.0       1  3.516129              -0.645574            0
# 1259          0.0       1  6.263158              -0.751646            0
#
#       rb_value
# 1204  0.972146
# 2577  0.967267
# 258   0.966445
# 5181  0.952836
# 4531  0.945821
# ...        ...
# 2394  0.055510
# 4082  0.053057
# 2023  0.039917
# 364   0.025191
# 1259  0.013160
#
# [1482 rows x 18 columns]

# %%
# Test what resulting rb value would be for different inputs
# total rushes, rushing epa

game = [[25, -15]]
clf.predict_proba(game)[0][1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-edfd21ef41a0> in <module>
#       3
#       4 game = [[25, -15]]
# ----> 5 clf.predict_proba(game)[0][1]
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in predict_proba(self, X)
#    1466                                                 self.solver == 'liblinear')))
#    1467         if ovr:
# -> 1468             return super()._predict_proba_lr(X)
#    1469         else:
#    1470             decision = self.decision_function(X)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _predict_proba_lr(self, X)
#     319         multiclass is handled by normalizing that over all classes.
#     320         """
# --> 321         prob = self.decision_function(X)
#     322         expit(prob, out=prob)
#     323         if prob.ndim == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 2 features per sample; expecting 1

# %%
rb[rb.season == 2022].groupby(by='team').mean()['rb_value'].sort_values(ascending=False)
# Out:
# team
# CHI    0.759852
# BAL    0.734587
# PHI    0.731240
# CLE    0.711668
# BUF    0.662603
# NYG    0.642694
# ATL    0.634045
# NYJ    0.625139
# ARI    0.621921
# KC     0.610159
# CAR    0.604739
# DAL    0.597121
# CIN    0.589854
# PIT    0.583138
# JAX    0.558924
# MIN    0.548448
# DET    0.544043
# GB     0.531251
# LV     0.526487
# NE     0.522634
# HOU    0.517113
# SF     0.514109
# WAS    0.506463
# MIA    0.502288
# SEA    0.496973
# NO     0.480496
# LAC    0.472204
# LA     0.437997
# TEN    0.434989
# DEN    0.393458
# IND    0.366551
# TB     0.306673
# Name: rb_value, dtype: float64

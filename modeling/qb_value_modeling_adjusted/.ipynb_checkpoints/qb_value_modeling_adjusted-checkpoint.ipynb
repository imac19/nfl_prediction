# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import statsmodels.api as sm
from scipy import stats

from joblib import dump, load

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
nfl = pd.read_csv('../../data/value_models_combined.csv')
nfl_rolling = pd.read_csv('../../data/value_models_combined_6_game_rolling.csv')

# %%
# Want to adjust the qb rating to take into account how good the opposing defense they faced was
# Example: Two qbs have an epa of 10 in a game. But one qb played a team that normally gives up 20 epa
# The other qb played a team that normally gives up 0 epa. By the current model, both qbs had equivalent games, 
# but in reality the qb that played a tougher defense had the better performance when defense is taken into account

# %%
qb = nfl[['season', 'week', 'team_full', 'opponent_full', 
          'qb', 'qb_value']]
opposing_def = nfl_rolling[['season', 'week', 'team_full', 
          'qb_def_value']]

# %%
df = qb.merge(opposing_def, left_on=['season', 'week', 'opponent_full'], 
             right_on=['season', 'week', 'team_full'], suffixes = ('','_opponent'))
df = df.drop(columns=['team_full_opponent'])

# %%
df
# Out:
#       season  week            team_full         opponent_full           qb  \
# 0       2014     1    Arizona Cardinals  Los Angeles Chargers    C. Palmer
# 1       2014     1      Atlanta Falcons    New Orleans Saints      M. Ryan
# 2       2014     1     Baltimore Ravens    Cincinnati Bengals    J. Flacco
# 3       2014     1        Buffalo Bills         Chicago Bears    E. Manuel
# 4       2014     1    Carolina Panthers  Tampa Bay Buccaneers  D. Anderson
# ...      ...   ...                  ...                   ...          ...
# 5123    2022    21   Kansas City Chiefs    Cincinnati Bengals   P. Mahomes
# 5124    2022    21  Philadelphia Eagles   San Francisco 49ers     J. Hurts
# 5125    2022    21  San Francisco 49ers   Philadelphia Eagles   J. Johnson
# 5126    2022    22   Kansas City Chiefs   Philadelphia Eagles   P. Mahomes
# 5127    2022    22  Philadelphia Eagles    Kansas City Chiefs     J. Hurts
#
#       qb_value  qb_def_value
# 0     0.506878           NaN
# 1     2.017670           NaN
# 2    -0.497235           NaN
# 3    -0.157862           NaN
# 4     0.744780           NaN
# ...        ...           ...
# 5123  0.515940      0.509250
# 5124 -0.135298      0.407030
# 5125 -0.824454      0.398366
# 5126  1.261225      0.601635
# 5127  1.190519      0.591341
#
# [5128 rows x 7 columns]

# %%
# Not sure the best way to adjust ratings
# One possibility - qb_value over expected, which would be qb_value - qb_def_value. However, this is a huge adjustment
# Another possibility is a small adjustment to the qb_value based on the qb value over expected, which I think
# makes the most sense. 

# Implementing the above:
# There are going to be two adjustable thresholds
# original_value_percentage: the amount of the original value that should be kept
# adjustment_threshold: how much more value do we want to add or take away for the performance based on 
# the value over or under expected
# original value percentage of 1 and adjustment threshold of 0 means value is unchanged
# original value percentage of 0 and adjustment threshold of 1 means the value is entirely based on the value over expected
# Will likely need to mess around with these values and see what works the best 


def value_adjustment(value, adjusting_value, original_value_percentage=.95, adjustment_threshold=.1):
    value_over_expected = value + adjusting_value
    adjusted_value = (value_over_expected*adjustment_threshold) + (value*original_value_percentage)
    adjustment = adjusted_value - value
    
    return adjustment, adjusted_value

df[['qb_adjustment', 'qb_adjusted_value']] = df.apply(lambda x: value_adjustment(x.qb_value, x.qb_def_value, 
                                original_value_percentage=.7, adjustment_threshold=.3), axis=1, result_type='expand')

# %%
# Save df here later
df.to_csv('qb_value_modeling_adjusted_data/qb_values_with_adjustment.csv')

# %%
testing = df.dropna()
testing.sort_values(by='qb_adjustment', ascending=False)
# Out:
#       season  week             team_full         opponent_full           qb  \
# 1742    2017     2      Tennessee Titans  Jacksonville Jaguars   M. Mariota
# 1718    2017     2      Cleveland Browns      Baltimore Ravens     D. Kizer
# 1719    2017     2      Cleveland Browns      Baltimore Ravens     K. Hogan
# 2280    2018     2    Cincinnati Bengals      Baltimore Ravens    A. Dalton
# 3030    2019     8      Cleveland Browns  New England Patriots  B. Mayfield
# ...      ...   ...                   ...                   ...          ...
# 2281    2018     2      Cleveland Browns    New Orleans Saints    T. Taylor
# 2833    2019     2         Buffalo Bills       New York Giants     J. Allen
# 4590    2022     2     Las Vegas Raiders     Arizona Cardinals      D. Carr
# 2853    2019     2  New England Patriots        Miami Dolphins     T. Brady
# 2852    2019     2  New England Patriots        Miami Dolphins     T. Brady
#
#       qb_value  qb_def_value  qb_adjustment  qb_adjusted_value
# 1742  0.213188      3.467329       1.040199           1.253387
# 1718 -1.622627      2.724325       0.817298          -0.805329
# 1719 -0.002974      2.724325       0.817298           0.814324
# 2280  0.657139      2.582997       0.774899           1.432038
# 3030 -0.917465      2.368926       0.710678          -0.206787
# ...        ...           ...            ...                ...
# 2281 -0.062169     -2.540035      -0.762011          -0.824180
# 2833  0.585039     -2.654348      -0.796304          -0.211265
# 4590  0.198744     -2.705768      -0.811730          -0.612986
# 2853  1.320209     -3.204956      -0.961487           0.358722
# 2852  1.320209     -3.204956      -0.961487           0.358722
#
# [4827 rows x 9 columns]

# %%
testing[(testing.season==2022) & (testing.team_full=='San Francisco 49ers')]
# Out:
#       season  week            team_full             opponent_full  \
# 4600    2022     2  San Francisco 49ers          Seattle Seahawks
# 4632    2022     3  San Francisco 49ers            Denver Broncos
# 4668    2022     4  San Francisco 49ers          Los Angeles Rams
# 4700    2022     5  San Francisco 49ers         Carolina Panthers
# 4732    2022     6  San Francisco 49ers           Atlanta Falcons
# 4760    2022     7  San Francisco 49ers        Kansas City Chiefs
# 4791    2022     8  San Francisco 49ers          Los Angeles Rams
# 4844    2022    10  San Francisco 49ers      Los Angeles Chargers
# 4873    2022    11  San Francisco 49ers         Arizona Cardinals
# 4904    2022    12  San Francisco 49ers        New Orleans Saints
# 4934    2022    13  San Francisco 49ers            Miami Dolphins
# 4961    2022    14  San Francisco 49ers      Tampa Bay Buccaneers
# 4994    2022    15  San Francisco 49ers          Seattle Seahawks
# 5028    2022    16  San Francisco 49ers  Washington Football Team
# 5029    2022    16  San Francisco 49ers  Washington Football Team
# 5064    2022    17  San Francisco 49ers         Las Vegas Raiders
# 5098    2022    18  San Francisco 49ers         Arizona Cardinals
# 5112    2022    19  San Francisco 49ers          Seattle Seahawks
# 5121    2022    20  San Francisco 49ers            Dallas Cowboys
# 5125    2022    21  San Francisco 49ers       Philadelphia Eagles
#
#                 qb  qb_value  qb_def_value  qb_adjustment  qb_adjusted_value
# 4600  J. Garoppolo  0.354298     -1.121366      -0.336410           0.017888
# 4632  J. Garoppolo -1.214300      0.393242       0.117972          -1.096328
# 4668  J. Garoppolo  0.852190     -0.164655      -0.049397           0.802793
# 4700  J. Garoppolo  1.483275      0.275055       0.082517           1.565791
# 4732  J. Garoppolo  0.154802     -0.657147      -0.197144          -0.042342
# 4760  J. Garoppolo  0.049889     -0.194913      -0.058474          -0.008585
# 4791  J. Garoppolo  1.200116      0.153740       0.046122           1.246238
# 4844  J. Garoppolo  0.808838      0.016583       0.004975           0.813812
# 4873  J. Garoppolo  1.337973      0.255564       0.076669           1.414642
# 4904  J. Garoppolo -0.143541     -0.070199      -0.021060          -0.164601
# 4934      B. Purdy -0.153728      0.161549       0.048465          -0.105263
# 4961      B. Purdy  0.673609      0.084809       0.025443           0.699052
# 4994      B. Purdy  0.444228      0.053274       0.015982           0.460210
# 5028      B. Purdy  0.323539      0.337193       0.101158           0.424697
# 5029      B. Purdy  0.323539      0.337193       0.101158           0.424697
# 5064      B. Purdy  0.512983      0.181031       0.054309           0.567293
# 5098      B. Purdy  0.362710     -0.014839      -0.004452           0.358258
# 5112      B. Purdy  2.005488      0.570082       0.171025           2.176512
# 5121      B. Purdy  0.024652      0.060550       0.018165           0.042817
# 5125    J. Johnson -0.824454      0.398366       0.119510          -0.704944

# %%
testing.sort_values(by='qb_adjusted_value', ascending=False)
# Out:
#       season  week             team_full         opponent_full  \
# 249     2014     8   Pittsburgh Steelers    Indianapolis Colts
# 3435    2020     3    Kansas City Chiefs      Baltimore Ravens
# 2943    2019     5        Houston Texans       Atlanta Falcons
# 4417    2021    16    Cincinnati Bengals      Baltimore Ravens
# 2289    2018     2    Kansas City Chiefs   Pittsburgh Steelers
# ...      ...   ...                   ...                   ...
# 3741    2020    13  Los Angeles Chargers  New England Patriots
# 1919    2017     8        Miami Dolphins      Baltimore Ravens
# 4469    2021    17       New York Giants         Chicago Bears
# 2954    2019     5         New York Jets   Philadelphia Eagles
# 2434    2018     7     Arizona Cardinals        Denver Broncos
#
#                      qb  qb_value  qb_def_value  qb_adjustment  \
# 249   B. Roethlisberger  3.499406      0.673309       0.201993
# 3435         P. Mahomes  3.047450      0.724304       0.217291
# 2943          D. Watson  3.123994     -0.543057      -0.162917
# 4417          J. Burrow  2.994638     -0.150829      -0.045249
# 2289         P. Mahomes  2.536044      1.235829       0.370749
# ...                 ...       ...           ...            ...
# 3741         J. Herbert -2.809425     -0.699435      -0.209831
# 1919           M. Moore -3.122335      0.102239       0.030672
# 4469         M. Glennon -3.399172     -0.053857      -0.016157
# 2954            L. Falk -3.369153     -0.826012      -0.247804
# 2434           J. Rosen -3.637763     -0.312883      -0.093865
#
#       qb_adjusted_value
# 249            3.701399
# 3435           3.264741
# 2943           2.961077
# 4417           2.949389
# 2289           2.906792
# ...                 ...
# 3741          -3.019256
# 1919          -3.091663
# 4469          -3.415329
# 2954          -3.616957
# 2434          -3.731628
#
# [4827 rows x 9 columns]

# %%
testing.groupby(by=['season','qb']).mean().sort_values(by='qb_value', ascending=False)[0:30]
# Out:
#                                week  qb_value  qb_def_value  qb_adjustment  \
# season qb
# 2020   M. Mariota         15.000000  1.602432     -0.019556      -0.005867
# 2016   J. Garoppolo        2.000000  1.446610      0.841281       0.252384
# 2019   M. Schaub           8.000000  1.439760     -0.139806      -0.041942
# 2018   M. Barkley         10.000000  1.080328     -0.046157      -0.013847
#        P. Mahomes         10.529412  1.079358      0.098557       0.029567
# 2016   M. Ryan            10.700000  1.021611      0.053600       0.016080
# 2020   P. Mahomes         10.500000  0.970314      0.091109       0.027333
# 2018   K. Allen           17.000000  0.949465      0.080587       0.024176
# 2021   J. Johnson         12.500000  0.924551      0.037502       0.011251
# 2022   P. Mahomes         11.842105  0.912049      0.245187       0.073556
# 2020   A. Rodgers         11.055556  0.900424     -0.198099      -0.059430
# 2019   P. Mahomes         11.437500  0.895539     -0.009692      -0.002908
# 2016   T. Brady           12.933333  0.893302      0.121076       0.036323
# 2021   J. Allen           11.117647  0.889181     -0.242225      -0.072667
# 2014   A. Rodgers         10.705882  0.881616      0.224096       0.067229
# 2020   C. Henne           17.000000  0.874702     -0.160465      -0.048140
# 2014   T. Romo            10.882353  0.822846     -0.015864      -0.004759
# 2018   B. Roethlisberger   9.666667  0.806447     -0.080118      -0.024036
# 2019   L. Jackson          9.733333  0.801201      0.110924       0.033277
# 2020   D. Prescott         3.500000  0.794987     -0.952601      -0.285780
# 2015   L. McCown           3.000000  0.784333      1.249160       0.374748
# 2020   R. Fitzpatrick      7.111111  0.774317     -0.341824      -0.102547
# 2017   J. Garoppolo       14.833333  0.756471      0.219910       0.065973
# 2016   A. Rodgers         11.157895  0.744009     -0.064994      -0.019498
#        D. Prescott         9.800000  0.733132     -0.003925      -0.001177
# 2018   D. Brees           10.500000  0.721232      0.037888       0.011366
# 2017   T. Brady           11.368421  0.705885     -0.149649      -0.044895
# 2020   M. Rudolph         17.000000  0.698071     -0.268375      -0.080513
# 2021   A. Rodgers         10.500000  0.689123     -0.023344      -0.007003
#        P. Mahomes         11.473684  0.680938      0.143578       0.043073
#
#                           qb_adjusted_value
# season qb
# 2020   M. Mariota                  1.596565
# 2016   J. Garoppolo                1.698994
# 2019   M. Schaub                   1.397818
# 2018   M. Barkley                  1.066481
#        P. Mahomes                  1.108925
# 2016   M. Ryan                     1.037691
# 2020   P. Mahomes                  0.997647
# 2018   K. Allen                    0.973641
# 2021   J. Johnson                  0.935802
# 2022   P. Mahomes                  0.985605
# 2020   A. Rodgers                  0.840995
# 2019   P. Mahomes                  0.892631
# 2016   T. Brady                    0.929625
# 2021   J. Allen                    0.816513
# 2014   A. Rodgers                  0.948844
# 2020   C. Henne                    0.826562
# 2014   T. Romo                     0.818087
# 2018   B. Roethlisberger           0.782411
# 2019   L. Jackson                  0.834478
# 2020   D. Prescott                 0.509207
# 2015   L. McCown                   1.159081
# 2020   R. Fitzpatrick              0.671770
# 2017   J. Garoppolo                0.822444
# 2016   A. Rodgers                  0.724511
#        D. Prescott                 0.731954
# 2018   D. Brees                    0.732599
# 2017   T. Brady                    0.660990
# 2020   M. Rudolph                  0.617558
# 2021   A. Rodgers                  0.682119
#        P. Mahomes                  0.724012

# %%
testing.groupby(by=['season', 'qb']).mean().sort_values(by='qb_adjusted_value', ascending=False)[0:30]
# Out:
#                                week  qb_value  qb_def_value  qb_adjustment  \
# season qb
# 2016   J. Garoppolo        2.000000  1.446610      0.841281       0.252384
# 2020   M. Mariota         15.000000  1.602432     -0.019556      -0.005867
# 2019   M. Schaub           8.000000  1.439760     -0.139806      -0.041942
# 2015   L. McCown           3.000000  0.784333      1.249160       0.374748
# 2018   P. Mahomes         10.529412  1.079358      0.098557       0.029567
#        M. Barkley         10.000000  1.080328     -0.046157      -0.013847
# 2016   M. Ryan            10.700000  1.021611      0.053600       0.016080
# 2020   P. Mahomes         10.500000  0.970314      0.091109       0.027333
# 2022   P. Mahomes         11.842105  0.912049      0.245187       0.073556
# 2018   K. Allen           17.000000  0.949465      0.080587       0.024176
# 2014   A. Rodgers         10.705882  0.881616      0.224096       0.067229
# 2021   J. Johnson         12.500000  0.924551      0.037502       0.011251
# 2016   T. Brady           12.933333  0.893302      0.121076       0.036323
# 2019   P. Mahomes         11.437500  0.895539     -0.009692      -0.002908
# 2020   A. Rodgers         11.055556  0.900424     -0.198099      -0.059430
# 2019   L. Jackson          9.733333  0.801201      0.110924       0.033277
# 2020   C. Henne           17.000000  0.874702     -0.160465      -0.048140
# 2017   J. Garoppolo       14.833333  0.756471      0.219910       0.065973
# 2014   T. Romo            10.882353  0.822846     -0.015864      -0.004759
# 2021   J. Allen           11.117647  0.889181     -0.242225      -0.072667
# 2018   B. Roethlisberger   9.666667  0.806447     -0.080118      -0.024036
# 2014   T. Brady           11.222222  0.658596      0.340726       0.102218
# 2018   D. Brees           10.500000  0.721232      0.037888       0.011366
# 2016   D. Prescott         9.800000  0.733132     -0.003925      -0.001177
#        A. Rodgers         11.157895  0.744009     -0.064994      -0.019498
# 2021   P. Mahomes         11.473684  0.680938      0.143578       0.043073
# 2017   C. Wentz            7.833333  0.673604      0.150648       0.045195
# 2021   A. Rodgers         10.500000  0.689123     -0.023344      -0.007003
# 2020   R. Fitzpatrick      7.111111  0.774317     -0.341824      -0.102547
# 2022   J. Hurts           11.352941  0.614158      0.179080       0.053724
#
#                           qb_adjusted_value
# season qb
# 2016   J. Garoppolo                1.698994
# 2020   M. Mariota                  1.596565
# 2019   M. Schaub                   1.397818
# 2015   L. McCown                   1.159081
# 2018   P. Mahomes                  1.108925
#        M. Barkley                  1.066481
# 2016   M. Ryan                     1.037691
# 2020   P. Mahomes                  0.997647
# 2022   P. Mahomes                  0.985605
# 2018   K. Allen                    0.973641
# 2014   A. Rodgers                  0.948844
# 2021   J. Johnson                  0.935802
# 2016   T. Brady                    0.929625
# 2019   P. Mahomes                  0.892631
# 2020   A. Rodgers                  0.840995
# 2019   L. Jackson                  0.834478
# 2020   C. Henne                    0.826562
# 2017   J. Garoppolo                0.822444
# 2014   T. Romo                     0.818087
# 2021   J. Allen                    0.816513
# 2018   B. Roethlisberger           0.782411
# 2014   T. Brady                    0.760814
# 2018   D. Brees                    0.732599
# 2016   D. Prescott                 0.731954
#        A. Rodgers                  0.724511
# 2021   P. Mahomes                  0.724012
# 2017   C. Wentz                    0.718798
# 2021   A. Rodgers                  0.682119
# 2020   R. Fitzpatrick              0.671770
# 2022   J. Hurts                    0.667882

# %%
testing.groupby(by=['season', 'qb']).mean().sort_values(by='qb_adjustment', ascending=False)[0:30]
# Out:
#                             week  qb_value  qb_def_value  qb_adjustment  \
# season qb
# 2019   C. McCoy         5.000000 -2.138187      2.061393       0.618418
# 2015   L. McCown        3.000000  0.784333      1.249160       0.374748
# 2022   J. Winston       2.500000 -0.697624      1.238571       0.371571
# 2019   M. Barkley      10.500000 -0.769619      1.236488       0.370947
# 2020   R. Griffin      12.000000 -1.725688      1.156411       0.346923
# 2021   I. Book         16.000000 -2.867578      1.146971       0.344091
# 2020   N. Sudfeld      17.000000 -1.202101      1.048018       0.314405
# 2018   S. Bradford      2.500000 -1.007430      1.018638       0.305591
# 2022   T. Siemian      12.000000 -0.944547      1.002780       0.300834
# 2020   R. Finley       15.000000 -0.238594      0.962683       0.288805
# 2017   K. Hogan         4.333333 -0.599853      0.943411       0.283023
# 2020   C. Streveler    17.000000 -1.413360      0.907172       0.272152
# 2016   J. Garoppolo     2.000000  1.446610      0.841281       0.252384
# 2021   B. Allen        18.000000 -1.215401      0.826635       0.247990
# 2014   J. Garoppolo    17.000000 -1.257592      0.792428       0.237728
# 2018   M. Cassel       16.000000 -0.728578      0.743227       0.222968
# 2019   R. Griffin III  17.000000 -0.720541      0.673627       0.202088
# 2015   D. Orlovsky      5.000000 -0.231031      0.655085       0.196526
# 2017   E. Manuel        4.500000 -0.251652      0.645492       0.193648
# 2016   J. Cutler        7.750000 -0.698010      0.644326       0.193298
#        J. Brissett      3.500000 -0.748542      0.611360       0.183408
#        M. McGloin      17.000000 -0.638376      0.593214       0.177964
# 2014   R. Lindley      17.000000 -1.071752      0.565277       0.169583
# 2016   C. Cook         17.500000 -1.863572      0.564024       0.169207
# 2019   B. Mayfield      9.666667 -0.108922      0.524786       0.157436
# 2020   G. Gilbert       9.000000 -0.543944      0.515163       0.154549
# 2015   J. Manziel      11.000000 -0.194329      0.496249       0.148875
# 2017   B. Petty        16.000000 -0.918187      0.494162       0.148249
# 2021   C. Rush          8.000000 -0.047101      0.485955       0.145786
# 2015   A. Luck          5.833333 -0.240365      0.473956       0.142187
#
#                        qb_adjusted_value
# season qb
# 2019   C. McCoy                -1.519769
# 2015   L. McCown                1.159081
# 2022   J. Winston              -0.326052
# 2019   M. Barkley              -0.398672
# 2020   R. Griffin              -1.378765
# 2021   I. Book                 -2.523487
# 2020   N. Sudfeld              -0.887696
# 2018   S. Bradford             -0.701839
# 2022   T. Siemian              -0.643712
# 2020   R. Finley                0.050211
# 2017   K. Hogan                -0.316830
# 2020   C. Streveler            -1.141208
# 2016   J. Garoppolo             1.698994
# 2021   B. Allen                -0.967410
# 2014   J. Garoppolo            -1.019864
# 2018   M. Cassel               -0.505610
# 2019   R. Griffin III          -0.518453
# 2015   D. Orlovsky             -0.034505
# 2017   E. Manuel               -0.058005
# 2016   J. Cutler               -0.504712
#        J. Brissett             -0.565134
#        M. McGloin              -0.460412
# 2014   R. Lindley              -0.902169
# 2016   C. Cook                 -1.694365
# 2019   B. Mayfield              0.048514
# 2020   G. Gilbert              -0.389395
# 2015   J. Manziel              -0.045454
# 2017   B. Petty                -0.769938
# 2021   C. Rush                  0.098685
# 2015   A. Luck                 -0.098178

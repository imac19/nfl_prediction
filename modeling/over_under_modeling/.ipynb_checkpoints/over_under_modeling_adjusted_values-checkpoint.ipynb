# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import xgboost as xgb

from joblib import dump, load

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
stats = pd.read_csv('../../data/adjusted_value_models_combined_6_game_rolling.csv')
schedule = pd.read_csv('../../data/schedule_final.csv')
betting = pd.read_csv('../../data/betting_data_cleaned_with_returns.csv')
betting = betting.drop(columns=['Unnamed: 0'])

stats = stats.dropna()

# %%
stats.head()
# Out:
#     Unnamed: 0  season  week team          qb  qb_adjusted_value  \
# 64          64    2014     3  ARI  D. Stanton          -1.157754
# 65          65    2014     3  ATL     M. Ryan          -1.307454
# 66          66    2014     3  BAL   J. Flacco           0.652041
# 67          67    2014     3  BUF   E. Manuel           0.603547
# 68          68    2014     3  CAR   C. Newton           0.767364
#
#     rushing_adjusted_value  qb_rushing_value_pct  qb_def_adjusted_value  \
# 64                0.332257                   0.0              -0.737241
# 65                0.874004                   0.0              -0.879286
# 66               -0.098594                   0.0               0.629275
# 67               -2.148207                   0.0               1.100186
# 68               -0.738487                   0.0               0.730025
#
#     rush_def_adjusted_value  special_teams_value          team_full
# 64                 0.919733             0.811753  Arizona Cardinals
# 65                -0.600544             0.801254    Atlanta Falcons
# 66                -0.397593             0.040821   Baltimore Ravens
# 67                 1.118419             1.432238      Buffalo Bills
# 68                 0.510499             0.963767  Carolina Panthers

# %%
stats
# Out:
#       Unnamed: 0  season  week team          qb  qb_adjusted_value  \
# 64            64    2014     3  ARI  D. Stanton          -1.157754
# 65            65    2014     3  ATL     M. Ryan          -1.307454
# 66            66    2014     3  BAL   J. Flacco           0.652041
# 67            67    2014     3  BUF   E. Manuel           0.603547
# 68            68    2014     3  CAR   C. Newton           0.767364
# ...          ...     ...   ...  ...         ...                ...
# 4856        4856    2022    21  CIN   J. Burrow           0.235993
# 4857        4857    2022    21   KC  P. Mahomes           0.626274
# 4858        4858    2022    21  PHI    J. Hurts           0.756473
# 4860        4860    2022    22   KC  P. Mahomes           0.666601
# 4861        4861    2022    22  PHI    J. Hurts           0.579982
#
#       rushing_adjusted_value  qb_rushing_value_pct  qb_def_adjusted_value  \
# 64                  0.332257                   0.0              -0.737241
# 65                  0.874004                   0.0              -0.879286
# 66                 -0.098594                   0.0               0.629275
# 67                 -2.148207                   0.0               1.100186
# 68                 -0.738487                   0.0               0.730025
# ...                      ...                   ...                    ...
# 4856                0.222464                   0.0               0.210351
# 4857                0.390027                   0.0               0.641969
# 4858                2.287960                   0.0               0.513945
# 4860                0.280515                   0.0               0.579033
# 4861                1.844241                   0.0               0.614928
#
#       rush_def_adjusted_value  special_teams_value            team_full
# 64                   0.919733             0.811753    Arizona Cardinals
# 65                  -0.600544             0.801254      Atlanta Falcons
# 66                  -0.397593             0.040821     Baltimore Ravens
# 67                   1.118419             1.432238        Buffalo Bills
# 68                   0.510499             0.963767    Carolina Panthers
# ...                       ...                  ...                  ...
# 4856                 0.832600             0.139439   Cincinnati Bengals
# 4857                -0.456237            -0.444345   Kansas City Chiefs
# 4858                -0.159588             0.134125  Philadelphia Eagles
# 4860                -0.464682            -0.538741   Kansas City Chiefs
# 4861                 0.023217            -0.025276  Philadelphia Eagles
#
# [4555 rows x 12 columns]

# %%
schedule.head()
# Out:
#    Unnamed: 0        date  season  week season_type                 home  \
# 0           0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1           1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2           2  2014-09-07    2014     1         REG       Houston Texans
# 3           3  2014-09-07    2014     1         REG        Chicago Bears
# 4           4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb        home_qb_abv away_qb_abv
# 0   Aaron Rodgers          R. Wilson  A. Rodgers
# 1     Andy Dalton          J. Flacco   A. Dalton
# 2  Robert Griffin     R. Fitzpatrick  R. Griffin
# 3       EJ Manuel          J. Cutler   E. Manuel
# 4     Brian Hoyer  B. Roethlisberger    B. Hoyer

# %%
print(len(stats))
print(len(schedule))
# Out:
# 4555
# 2438

# %%
nfl = schedule.copy()
nfl = nfl.merge(stats.add_suffix('_home'), how='left', left_on = ['season', 'week', 'home', 'home_qb_abv'], 
                right_on = ['season_home', 'week_home', 'team_full_home', 'qb_home'])
nfl = nfl.merge(stats.add_suffix('_away'), how='left', left_on = ['season', 'week', 'away', 'away_qb_abv'], 
                right_on = ['season_away', 'week_away', 'team_full_away', 'qb_away'])
nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
          'qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_rushing_value_pct_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
          'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_rushing_value_pct_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away']]
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 0   Aaron Rodgers                     NaN                          NaN
# 1     Andy Dalton                     NaN                          NaN
# 2  Robert Griffin                     NaN                          NaN
# 3       EJ Manuel                     NaN                          NaN
# 4     Brian Hoyer                     NaN                          NaN
#
#    qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_home  special_teams_value_home  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    qb_adjusted_value_away  rushing_adjusted_value_away  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
print(len(nfl))
# Out:
# 2438

# %%
betting.head()
# Out:
#          date            home_team            away_team  home_score  \
# 0  2023-02-12  Philadelphia Eagles   Kansas City Chiefs          35
# 1  2023-01-29   Kansas City Chiefs   Cincinnati Bengals          23
# 2  2023-01-29  Philadelphia Eagles  San Francisco 49ers          31
# 3  2023-01-22  San Francisco 49ers       Dallas Cowboys          19
# 4  2023-01-22        Buffalo Bills   Cincinnati Bengals          10
#
#    away_score  total_score_actual  home_moneyline  away_moneyline  \
# 0          38                  73          -120.0           100.0
# 1          20                  43          -130.0           110.0
# 2           7                  38          -155.0           135.0
# 3          12                  31          -200.0           170.0
# 4          27                  37          -260.0           215.0
#
#    home_spread  away_spread  total_score_line over_under_result  \
# 0         -1.0          1.0              51.5              over
# 1         -2.0          2.0              48.5             under
# 2         -3.0          3.0              45.0             under
# 3         -3.5          3.5              46.5             under
# 4         -6.0          6.0              48.5             under
#
#    home_team_actual_line  away_team_actual_line spread_cover_result  \
# 0                      3                     -3                away
# 1                     -3                      3                home
# 2                    -24                     24                home
# 3                     -7                      7                home
# 4                     17                    -17                away
#
#    home_implied_prob  away_implied_prob game_winner  favorite_return  \
# 0           0.545455           0.500000        away          -100.00
# 1           0.565217           0.476190        home            76.92
# 2           0.607843           0.425532        home            64.52
# 3           0.666667           0.370370        home            50.00
# 4           0.722222           0.317460        away          -100.00
#
#    underdog_return  home_return  away_return  favorite_spread_return  \
# 0            100.0      -100.00        100.0                 -100.00
# 1           -100.0        76.92       -100.0                   90.91
# 2           -100.0        64.52       -100.0                   90.91
# 3           -100.0        50.00       -100.0                   90.91
# 4            215.0      -100.00        215.0                 -100.00
#
#    underdog_spread_return  home_spread_return  away_spread_return  \
# 0                   90.91             -100.00               90.91
# 1                 -100.00               90.91             -100.00
# 2                 -100.00               90.91             -100.00
# 3                 -100.00               90.91             -100.00
# 4                   90.91             -100.00               90.91
#
#    over_return  under_return
# 0        90.91       -100.00
# 1      -100.00         90.91
# 2      -100.00         90.91
# 3      -100.00         90.91
# 4      -100.00         90.91

# %%
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 0   Aaron Rodgers                     NaN                          NaN
# 1     Andy Dalton                     NaN                          NaN
# 2  Robert Griffin                     NaN                          NaN
# 3       EJ Manuel                     NaN                          NaN
# 4     Brian Hoyer                     NaN                          NaN
#
#    qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_home  special_teams_value_home  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    qb_adjusted_value_away  rushing_adjusted_value_away  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
# Join in betting data to get point spreads

nfl_cleaned_with_betting = nfl.merge(betting, left_on=['date', 'home', 'away'],
                                            right_on=['date', 'home_team','away_team'])

# %%
# Remove any pushes, add binary label for home cover

nfl_cleaned_with_betting_final = nfl_cleaned_with_betting.copy()
nfl_cleaned_with_betting_final['over_hits'] = nfl_cleaned_with_betting_final.apply(
    lambda x: 1 if x.over_under_result == 'over' else 0, axis=1)
nfl_cleaned_with_betting_final = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.over_under_result != 'push']
nfl_cleaned_with_betting_final
# Out:
#             date  season  week season_type                 home  \
# 0     2014-09-04    2014     1         REG     Seattle Seahawks
# 1     2014-09-07    2014     1         REG     Baltimore Ravens
# 2     2014-09-07    2014     1         REG       Houston Texans
# 3     2014-09-07    2014     1         REG        Chicago Bears
# 4     2014-09-07    2014     1         REG  Pittsburgh Steelers
# ...          ...     ...   ...         ...                  ...
# 2402  2023-01-22    2022    20        POST        Buffalo Bills
# 2403  2023-01-22    2022    20        POST  San Francisco 49ers
# 2404  2023-01-29    2022    21        POST  Philadelphia Eagles
# 2405  2023-01-29    2022    21        POST   Kansas City Chiefs
# 2406  2023-02-12    2022    22        POST  Philadelphia Eagles
#
#                           away  home_score_x  away_score_x  \
# 0            Green Bay Packers            36            16
# 1           Cincinnati Bengals            16            23
# 2     Washington Football Team            17             6
# 3                Buffalo Bills            20            23
# 4             Cleveland Browns            30            27
# ...                        ...           ...           ...
# 2402        Cincinnati Bengals            10            27
# 2403            Dallas Cowboys            19            12
# 2404       San Francisco 49ers            31             7
# 2405        Cincinnati Bengals            23            20
# 2406        Kansas City Chiefs            35            38
#
#                  home_qb          away_qb  qb_adjusted_value_home  \
# 0         Russell Wilson    Aaron Rodgers                     NaN
# 1             Joe Flacco      Andy Dalton                     NaN
# 2       Ryan Fitzpatrick   Robert Griffin                     NaN
# 3             Jay Cutler        EJ Manuel                     NaN
# 4     Ben Roethlisberger      Brian Hoyer                     NaN
# ...                  ...              ...                     ...
# 2402          Josh Allen       Joe Burrow                0.285539
# 2403         Brock Purdy     Dak Prescott                0.764975
# 2404         Jalen Hurts      Brock Purdy                0.756473
# 2405     Patrick Mahomes       Joe Burrow                0.626274
# 2406         Jalen Hurts  Patrick Mahomes                0.579982
#
#       rushing_adjusted_value_home  qb_rushing_value_pct_home  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 2402                     0.625543                        0.0
# 2403                     0.633274                        0.0
# 2404                     2.287960                        0.0
# 2405                     0.390027                        0.0
# 2406                     1.844241                        0.0
#
#       qb_def_adjusted_value_home  rush_def_adjusted_value_home  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 2402                    0.660321                      0.512648
# 2403                    0.686924                      0.583874
# 2404                    0.513945                     -0.159588
# 2405                    0.641969                     -0.456237
# 2406                    0.614928                      0.023217
#
#       special_teams_value_home  qb_adjusted_value_away  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 2402                  0.183350                0.310046
# 2403                  0.178761                0.207053
# 2404                  0.134125                     NaN
# 2405                 -0.444345                0.235993
# 2406                 -0.025276                0.666601
#
#       rushing_adjusted_value_away  qb_rushing_value_pct_away  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 2402                    -0.006602                        0.0
# 2403                    -0.634150                        0.0
# 2404                          NaN                        NaN
# 2405                     0.222464                        0.0
# 2406                     0.280515                        0.0
#
#       qb_def_adjusted_value_away  rush_def_adjusted_value_away  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 2402                    0.113476                      0.482189
# 2403                   -0.271663                      1.501824
# 2404                         NaN                           NaN
# 2405                    0.210351                      0.832600
# 2406                    0.579033                     -0.464682
#
#       special_teams_value_away            home_team                 away_team  \
# 0                          NaN     Seattle Seahawks         Green Bay Packers
# 1                          NaN     Baltimore Ravens        Cincinnati Bengals
# 2                          NaN       Houston Texans  Washington Football Team
# 3                          NaN        Chicago Bears             Buffalo Bills
# 4                          NaN  Pittsburgh Steelers          Cleveland Browns
# ...                        ...                  ...                       ...
# 2402                  0.151149        Buffalo Bills        Cincinnati Bengals
# 2403                 -0.517502  San Francisco 49ers            Dallas Cowboys
# 2404                       NaN  Philadelphia Eagles       San Francisco 49ers
# 2405                  0.139439   Kansas City Chiefs        Cincinnati Bengals
# 2406                 -0.538741  Philadelphia Eagles        Kansas City Chiefs
#
#       home_score_y  away_score_y  total_score_actual  home_moneyline  \
# 0               36            16                  52          -230.0
# 1               16            23                  39          -113.0
# 2               17             6                  23          -177.0
# 3               20            23                  43          -270.0
# 4               30            27                  57          -242.0
# ...            ...           ...                 ...             ...
# 2402            10            27                  37          -260.0
# 2403            19            12                  31          -200.0
# 2404            31             7                  38          -155.0
# 2405            23            20                  43          -130.0
# 2406            35            38                  73          -120.0
#
#       away_moneyline  home_spread  away_spread  total_score_line  \
# 0              205.0         -4.5          4.5              46.5
# 1              102.0         -1.0          1.0              43.5
# 2              159.0         -3.0          3.0              43.5
# 3              239.0         -7.0          7.0              47.0
# 4              216.0         -5.5          5.5              41.5
# ...              ...          ...          ...               ...
# 2402           215.0         -6.0          6.0              48.5
# 2403           170.0         -3.5          3.5              46.5
# 2404           135.0         -3.0          3.0              45.0
# 2405           110.0         -2.0          2.0              48.5
# 2406           100.0         -1.0          1.0              51.5
#
#      over_under_result  home_team_actual_line  away_team_actual_line  \
# 0                 over                    -20                     20
# 1                under                      7                     -7
# 2                under                    -11                     11
# 3                under                      3                     -3
# 4                 over                     -3                      3
# ...                ...                    ...                    ...
# 2402             under                     17                    -17
# 2403             under                     -7                      7
# 2404             under                    -24                     24
# 2405             under                     -3                      3
# 2406              over                      3                     -3
#
#      spread_cover_result  home_implied_prob  away_implied_prob game_winner  \
# 0                   home           0.696970           0.327869        home
# 1                   away           0.530516           0.495050        away
# 2                   home           0.638989           0.386100        home
# 3                   away           0.729730           0.294985        away
# 4                   away           0.707602           0.316456        home
# ...                  ...                ...                ...         ...
# 2402                away           0.722222           0.317460        away
# 2403                home           0.666667           0.370370        home
# 2404                home           0.607843           0.425532        home
# 2405                home           0.565217           0.476190        home
# 2406                away           0.545455           0.500000        away
#
#       favorite_return  underdog_return  home_return  away_return  \
# 0               43.48           -100.0        43.48       -100.0
# 1             -100.00            102.0      -100.00        102.0
# 2               56.50           -100.0        56.50       -100.0
# 3             -100.00            239.0      -100.00        239.0
# 4               41.32           -100.0        41.32       -100.0
# ...               ...              ...          ...          ...
# 2402          -100.00            215.0      -100.00        215.0
# 2403            50.00           -100.0        50.00       -100.0
# 2404            64.52           -100.0        64.52       -100.0
# 2405            76.92           -100.0        76.92       -100.0
# 2406          -100.00            100.0      -100.00        100.0
#
#       favorite_spread_return  underdog_spread_return  home_spread_return  \
# 0                      90.91                 -100.00               90.91
# 1                    -100.00                   90.91             -100.00
# 2                      90.91                 -100.00               90.91
# 3                    -100.00                   90.91             -100.00
# 4                    -100.00                   90.91             -100.00
# ...                      ...                     ...                 ...
# 2402                 -100.00                   90.91             -100.00
# 2403                   90.91                 -100.00               90.91
# 2404                   90.91                 -100.00               90.91
# 2405                   90.91                 -100.00               90.91
# 2406                 -100.00                   90.91             -100.00
#
#       away_spread_return  over_return  under_return  over_hits
# 0                -100.00        90.91       -100.00          1
# 1                  90.91      -100.00         90.91          0
# 2                -100.00      -100.00         90.91          0
# 3                  90.91      -100.00         90.91          0
# 4                  90.91        90.91       -100.00          1
# ...                  ...          ...           ...        ...
# 2402               90.91      -100.00         90.91          0
# 2403             -100.00      -100.00         90.91          0
# 2404             -100.00      -100.00         90.91          0
# 2405             -100.00      -100.00         90.91          0
# 2406               90.91        90.91       -100.00          1
#
# [2377 rows x 50 columns]

# %%
nfl_cleaned_with_betting_final.to_csv('../../data/adjusted_stats_over_under_modeling_base_df.csv')

# %%
# Split data into train and test sets, cross validation for hyperparameter tuning

train_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season <= 2021]
train_df = train_df.dropna()

test_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season == 2022]
test_df = test_df.dropna()

# %%
# NOTE
# Dont know if i need to balance this data set at all, point spread betting should be pretty 50/50


# Balance training data set

# Note: Can't balance data set and then do Cross Validation due to data leakage

# Fully balancing the data set doesnt work as well for prediction as the unbalanced, likely because the 
# home team does actually have an important advantage. But, maybe balancing the data set slightly will help

# balance_n = int(np.round((sum(train_df.home_win==1) - sum(train_df.home_win==0))/1.5))
# to_add = train_df[train_df.home_win==0].sample(n=balance_n, random_state=57, replace=True)

# train_df_balanced = pd.concat([train_df, to_add])
# train_df_balanced

# %%
# Shuffle training set before cross validation

train_df_shuffled = train_df.sample(frac=1, random_state=42)
train_df_shuffled.head()
# Out:
#             date  season  week season_type                 home  \
# 1150  2018-10-28    2018     8         REG        Chicago Bears
# 2064  2021-12-25    2021    16         REG    Green Bay Packers
# 936   2017-11-26    2017    12         REG   Cincinnati Bengals
# 216   2014-12-20    2014    16         REG  San Francisco 49ers
# 1491  2019-12-01    2019    13         REG    Arizona Cardinals
#
#                       away  home_score_x  away_score_x            home_qb  \
# 1150         New York Jets            24            10  Mitchell Trubisky
# 2064      Cleveland Browns            24            22      Aaron Rodgers
# 936       Cleveland Browns            30            16        Andy Dalton
# 216   Los Angeles Chargers            35            38   Colin Kaepernick
# 1491      Los Angeles Rams             7            34       Kyler Murray
#
#              away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 1150     Sam Darnold                0.322063                     0.386539
# 2064  Baker Mayfield                0.936377                     0.524995
# 936    DeShone Kizer               -0.123314                    -0.515470
# 216    Philip Rivers               -0.467180                    -0.474297
# 1491      Jared Goff                0.379022                     0.250964
#
#       qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 1150                        0.0                    0.172980
# 2064                        0.0                    0.252618
# 936                         0.0                    0.057543
# 216                         0.0                    0.354952
# 1491                        0.0                   -0.688157
#
#       rush_def_adjusted_value_home  special_teams_value_home  \
# 1150                      0.599055                 -0.242246
# 2064                     -0.433377                 -1.260957
# 936                       0.476494                 -0.720438
# 216                       0.323860                 -0.605833
# 1491                     -0.022747                  0.043121
#
#       qb_adjusted_value_away  rushing_adjusted_value_away  \
# 1150               -0.691952                    -0.232259
# 2064               -0.262642                     0.042247
# 936                -1.026526                     0.331169
# 216                -0.398509                    -0.222744
# 1491               -0.346171                    -1.049984
#
#       qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 1150                        0.0                    0.004134
# 2064                        0.0                    0.378820
# 936                         0.0                    0.065201
# 216                         0.0                   -0.152043
# 1491                        0.0                    0.098803
#
#       rush_def_adjusted_value_away  special_teams_value_away  \
# 1150                      0.381461                  0.353259
# 2064                     -0.288570                 -1.008349
# 936                       0.830876                 -0.380708
# 216                       0.842206                 -0.897789
# 1491                      0.387651                  0.696559
#
#                 home_team             away_team  home_score_y  away_score_y  \
# 1150        Chicago Bears         New York Jets            24            10
# 2064    Green Bay Packers      Cleveland Browns            24            22
# 936    Cincinnati Bengals      Cleveland Browns            30            16
# 216   San Francisco 49ers  Los Angeles Chargers            35            38
# 1491    Arizona Cardinals      Los Angeles Rams             7            34
#
#       total_score_actual  home_moneyline  away_moneyline  home_spread  \
# 1150                  34          -435.0           325.0         -8.5
# 2064                  46          -435.0           325.0         -7.5
# 936                   46          -326.0           285.0         -7.5
# 216                   73          -128.0           116.0         -2.0
# 1491                  41           120.0          -141.0          2.5
#
#       away_spread  total_score_line over_under_result  home_team_actual_line  \
# 1150          8.5              42.5             under                    -14
# 2064          7.5              46.5             under                     -2
# 936           7.5              39.0              over                    -14
# 216           2.0              40.5              over                      3
# 1491         -2.5              47.0             under                     27
#
#       away_team_actual_line spread_cover_result  home_implied_prob  \
# 1150                     14                home           0.813084
# 2064                      2                away           0.813084
# 936                      14                home           0.765258
# 216                      -3                away           0.561404
# 1491                    -27                away           0.454545
#
#       away_implied_prob game_winner  favorite_return  underdog_return  \
# 1150           0.235294        home            22.99           -100.0
# 2064           0.235294        home            22.99           -100.0
# 936            0.259740        home            30.67           -100.0
# 216            0.462963        away          -100.00            116.0
# 1491           0.585062        away            70.92           -100.0
#
#       home_return  away_return  favorite_spread_return  \
# 1150        22.99      -100.00                   90.91
# 2064        22.99      -100.00                 -100.00
# 936         30.67      -100.00                   90.91
# 216       -100.00       116.00                 -100.00
# 1491      -100.00        70.92                   90.91
#
#       underdog_spread_return  home_spread_return  away_spread_return  \
# 1150                 -100.00               90.91             -100.00
# 2064                   90.91             -100.00               90.91
# 936                  -100.00               90.91             -100.00
# 216                    90.91             -100.00               90.91
# 1491                 -100.00             -100.00               90.91
#
#       over_return  under_return  over_hits
# 1150      -100.00         90.91          0
# 2064      -100.00         90.91          0
# 936         90.91       -100.00          1
# 216         90.91       -100.00          1
# 1491      -100.00         90.91          0

# %%
# Prepare feature list

# feature_list = ['passing_value_home', 'rushing_value_home', 'pass_def_value_home', 'rush_def_value_home',
#                    'passing_value_away', 'rushing_value_away', 'pass_def_value_away', 'rush_def_value_away']

# feature_list = ['qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
#                    'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

feature_list = ['qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
                   'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away',
                'total_score_line']

# %%
# Get features, labels for train, val, and test sets

# train_x = train_df_balanced[feature_list].to_numpy()
# train_y = train_df_balanced.home_win.to_numpy()

train_x = train_df_shuffled[feature_list].to_numpy()
train_y = train_df_shuffled.over_hits.to_numpy()

test_x = test_df[feature_list]
test_y = test_df.over_hits.to_numpy()

# %%
train_df_shuffled.week
# Out:
# 1150     8
# 2064    16
# 936     12
# 216     16
# 1491    13
#         ..
# 1327     2
# 1515    15
# 1021    17
# 1727    11
# 1323     2
# Name: week, Length: 1801, dtype: int64

# %%
# Function to get predictions and probabilities for train, val, test sets

def get_preds(model, train_x, test_x):
    train_preds = model.predict(train_x)
    train_probs = model.predict_proba(train_x)
    
    test_preds = model.predict(test_x)
    test_probs = model.predict_proba(test_x)
    
    return train_preds, train_probs, test_preds, test_probs

# Function to get accuracy scores for train, val sets

def print_cv_results(model, train_x, train_y, cv_folds, verbose=True):
    cv_results = cross_validate(model, train_x, train_y, cv=5, return_train_score=True)
    
    train_scores = cv_results['train_score']
    val_scores = cv_results['test_score']
    
    if verbose:      
        for i, scores in enumerate(zip(train_scores, val_scores)):
            print('Fold {}, Train Accuracy: {}, Validation Accuracy: {}'.format(i+1,scores[0], scores[1]))     
        print()
        
    print('Average Training Accuracy: {}'.format(np.mean(train_scores)))
    print('Average Validation Accuracy: {}'.format(np.mean(val_scores)))
    
    return np.mean(train_scores), np.mean(val_scores)

# %%
# Simple Logistic Regression Model

lr_model = LogisticRegression()

print_cv_results(lr_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.5388888888888889, Validation Accuracy: 0.47368421052631576
# Fold 2, Train Accuracy: 0.5301873698820264, Validation Accuracy: 0.5361111111111111
# Fold 3, Train Accuracy: 0.5447605829285218, Validation Accuracy: 0.4638888888888889
# Fold 4, Train Accuracy: 0.5336571825121443, Validation Accuracy: 0.49166666666666664
# Fold 5, Train Accuracy: 0.5329632199861207, Validation Accuracy: 0.5361111111111111
#
# Average Training Accuracy: 0.5360914488395403
# Average Validation Accuracy: 0.5002923976608187
# (0.5360914488395403, 0.5002923976608187)

# %%
# Default Random Forest Classifier with no hyperparameter tuning

rf_model = RandomForestClassifier()

print_cv_results(rf_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.5484764542936288
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.4666666666666667
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.4388888888888889
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5055555555555555
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.4888888888888889
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.48969529085872576
# (1.0, 0.48969529085872576)

# %%
# Default XGBoost Model with no hyperparameter tuning

xgb_model = xgb.XGBClassifier()

print_cv_results(xgb_model, train_x, train_y, 5)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.5346260387811634
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.48333333333333334
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.5138888888888888
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5055555555555555
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.525
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5124807633117883
# (1.0, 0.5124807633117883)

# %%
# Logistic Regression, with hyperparameter tuning

def logistic_regression_tuning(train_x, train_y, verbose=True):
    
    lr_model = LogisticRegression()
    
    # Hyperparameters to tune
    penalty_list = ['none', 'l2', 'l1', 'elasticnet']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    
    params = dict(solver=solvers, penalty=penalty_list, C=c_values)
    
    clf = GridSearchCV(lr_model, params, return_train_score=True).fit(train_x, train_y)
    
    print('Best Result: {}'.format(clf.best_score_))
    print('Best Parameters: {}'.format(clf.best_params_))
    print()
    
    train_scores = clf.cv_results_['mean_train_score']
    val_scores = clf.cv_results_['mean_test_score']
    param_list = clf.cv_results_['params']
    
    if verbose:
        print('Parameter Combinations and Results:')
        for train_score, val_score, params in zip(train_scores, val_scores, param_list):
            print('Train Score: {}, Val Score: {}, Parameters: {}'.format(train_score, val_score, params))

# %%
# Can uncomment and run below to see, but hyperparameter tuning didnt change much. Can probably just roll with the 
# default logistic regression

# logistic_regression_tuning(train_x, train_y)

# %%
# Save best logistic regression model 

best_lr_model = LogisticRegression().fit(train_x, train_y)
dump(best_lr_model, 'saved_models/ou_logistic_regression_av.joblib')
# Out:
# ['saved_models/ou_logistic_regression_av.joblib']

# %%
# Save best random forest model 

best_rf_model = RandomForestClassifier().fit(train_x, train_y)
dump(best_rf_model, 'saved_models/ou_random_forest_av.joblib')
# Out:
# ['saved_models/ou_random_forest_av.joblib']

# %%
# Save best xg boost model 

best_xgb_model = xgb.XGBClassifier().fit(train_x, train_y)
dump(best_xgb_model, 'saved_models/ou_xg_boost_av.joblib')
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:29:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ['saved_models/ou_xg_boost_av.joblib']

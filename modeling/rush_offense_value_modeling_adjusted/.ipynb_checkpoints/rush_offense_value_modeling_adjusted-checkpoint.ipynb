# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import statsmodels.api as sm
from scipy import stats

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
nfl = pd.read_csv('../../data/value_models_combined.csv')
nfl_rolling = pd.read_csv('../../data/value_models_combined_6_game_rolling.csv')

# %%
rb = nfl[['season', 'week', 'team', 'opponent', 'team_full', 'opponent_full', 'score', 'opponent_score',
          'rushing_value']]
opposing_def = nfl_rolling[['season', 'week', 'team_full', 
          'rush_def_value']]

# %%
df = rb.merge(opposing_def, left_on=['season', 'week', 'opponent_full'], 
             right_on=['season', 'week', 'team_full'], suffixes = ('','_opponent'))
df = df.drop(columns=['team_full_opponent'])

# %%
def value_adjustment(value, adjusting_value, original_value_percentage=.95, adjustment_threshold=.1):
    value_over_expected = value + adjusting_value
    adjusted_value = (value_over_expected*adjustment_threshold) + (value*original_value_percentage)
    adjustment = adjusted_value - value
    
    return adjustment, adjusted_value

df[['rushing_adjustment', 'rushing_adjusted_value']] = df.apply(lambda x: value_adjustment(x.rushing_value, x.rush_def_value, 
                                original_value_percentage=.7, adjustment_threshold=.3), axis=1, result_type='expand')

# %%
df.to_csv('rush_offense_value_modeling_adjusted_data/rushing_offense_values_with_adjustment.csv')

# %%
testing = df.dropna()
testing.sort_values(by='rushing_adjustment', ascending=False)
# Out:
#       season  week team opponent                 team_full  \
# 1111    2016     2   GB      MIN         Green Bay Packers
# 2170    2018     2  DET       SF             Detroit Lions
# 3228    2020     2  CAR       TB         Carolina Panthers
# 1646    2017     2   LA      WAS          Los Angeles Rams
# 2747    2019     3  NYG       TB           New York Giants
# ...      ...   ...  ...      ...                       ...
# 4348    2022     2  MIN      PHI         Minnesota Vikings
# 2702    2019     2  DET      LAC             Detroit Lions
# 576     2015     2  DET      MIN             Detroit Lions
# 3227    2020     2  BUF      MIA             Buffalo Bills
# 4359    2022     2  WAS      DET  Washington Football Team
#
#                  opponent_full  score  opponent_score  rushing_value  \
# 1111         Minnesota Vikings     14              17      -0.209991
# 2170       San Francisco 49ers     27              30      -0.143789
# 3228      Tampa Bay Buccaneers     17              31      -0.190142
# 1646  Washington Football Team     20              27      -0.817797
# 2747      Tampa Bay Buccaneers     32              31       0.620842
# ...                        ...    ...             ...            ...
# 4348       Philadelphia Eagles      7              24       0.464429
# 2702      Los Angeles Chargers     13              10      -0.640571
# 576          Minnesota Vikings     16              26      -1.440444
# 3227            Miami Dolphins     31              28       0.010796
# 4359             Detroit Lions     27              36       0.443713
#
#       rush_def_value  rushing_adjustment  rushing_adjusted_value
# 1111        3.347693            1.004308                0.794317
# 2170        2.449265            0.734780                0.590990
# 3228        2.371562            0.711468                0.521326
# 1646        2.227347            0.668204               -0.149593
# 2747        2.218346            0.665504                1.286346
# ...              ...                 ...                     ...
# 4348       -2.130646           -0.639194               -0.174765
# 2702       -2.153798           -0.646139               -1.286710
# 576        -2.584928           -0.775478               -2.215922
# 3227       -2.770271           -0.831081               -0.820285
# 4359       -3.296809           -0.989043               -0.545329
#
# [4575 rows x 12 columns]

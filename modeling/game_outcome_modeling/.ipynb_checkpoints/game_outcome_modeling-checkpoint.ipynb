# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb

from joblib import dump, load

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
stats = pd.read_csv('../../data/value_models_combined_6_game_rolling.csv')
schedule = pd.read_csv('../../data/schedule_final.csv')

# %%
stats.head()
# Out:
#    Unnamed: 0  season  week team           qb  qb_value  passing_value  \
# 0           0    2014     1  ARI    C. Palmer       NaN            NaN
# 1           1    2014     1  ATL      M. Ryan       NaN            NaN
# 2           2    2014     1  BAL    J. Flacco       NaN            NaN
# 3           3    2014     1  BUF    E. Manuel       NaN            NaN
# 4           4    2014     1  CAR  D. Anderson       NaN            NaN
#
#    rushing_value  qb_rushing_value_pct  qb_def_value  pass_def_value  \
# 0            NaN                   NaN           NaN             NaN
# 1            NaN                   NaN           NaN             NaN
# 2            NaN                   NaN           NaN             NaN
# 3            NaN                   NaN           NaN             NaN
# 4            NaN                   NaN           NaN             NaN
#
#    rush_def_value  special_teams_value          team_full
# 0             NaN                  NaN  Arizona Cardinals
# 1             NaN                  NaN    Atlanta Falcons
# 2             NaN                  NaN   Baltimore Ravens
# 3             NaN                  NaN      Buffalo Bills
# 4             NaN                  NaN  Carolina Panthers

# %%
stats.iloc[40:50]
# Out:
#     Unnamed: 0  season  week team              qb  qb_value  passing_value  \
# 40          40    2014     2  CLE        B. Hoyer -0.013644       0.303361
# 41          41    2014     2  DAL         T. Romo -0.739976      -0.630767
# 42          42    2014     2  DEN      P. Manning  1.002503       1.130943
# 43          43    2014     2  DET     M. Stafford  1.954149       1.858069
# 44          44    2014     2   GB      A. Rodgers -0.678930      -0.569047
# 45          45    2014     2  HOU  R. Fitzpatrick  0.702541       0.801214
# 46          46    2014     2  IND         A. Luck  0.162978       0.503740
# 47          47    2014     2  JAX        C. Henne -1.271329      -1.211940
# 48          48    2014     2   KC        A. Smith -0.744867      -0.843520
# 49          49    2014     2   LA        A. Davis -1.178785      -1.074419
#
#     rushing_value  qb_rushing_value_pct  qb_def_value  pass_def_value  \
# 40       1.583139                   0.0     -0.701089       -1.079077
# 41      -0.159190                   0.0     -0.699442       -1.031174
# 42       0.324489                   0.0     -0.161430       -0.496790
# 43      -0.406035                   0.0      1.215971        1.109021
# 44       0.270025                   0.0     -0.645579       -0.421833
# 45      -1.529695                   0.0      0.829829        0.556279
# 46      -0.329765                   0.0     -0.978262       -1.106133
# 47      -1.045885                   0.0      1.212921        1.105941
# 48      -0.365013                   0.0     -1.009951       -1.149726
# 49      -0.086843                   0.0     -0.049627       -0.596694
#
#     rush_def_value  special_teams_value             team_full
# 40        0.229773            -0.828145      Cleveland Browns
# 41        0.461771             0.343324        Dallas Cowboys
# 42        0.329765            -0.973700        Denver Broncos
# 43        1.123309            -0.253815         Detroit Lions
# 44       -1.609059             0.393511     Green Bay Packers
# 45        0.424375             0.881277        Houston Texans
# 46       -0.324489             0.973700    Indianapolis Colts
# 47       -0.047989            -2.296920  Jacksonville Jaguars
# 48        0.386769            -0.998984    Kansas City Chiefs
# 49        0.161287            -0.034972      Los Angeles Rams

# %%
schedule.head()
# Out:
#    Unnamed: 0        date  season  week season_type                 home  \
# 0           0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1           1  2014-09-07    2014     1         REG       Denver Broncos
# 2           2  2014-09-07    2014     1         REG  Philadelphia Eagles
# 3           3  2014-09-07    2014     1         REG   Kansas City Chiefs
# 4           4  2014-09-07    2014     1         REG     Los Angeles Rams
#
#                    away  home_score  away_score         home_qb  \
# 0     Green Bay Packers          36          16  Russell Wilson
# 1    Indianapolis Colts          31          24  Peyton Manning
# 2  Jacksonville Jaguars          34          17      Nick Foles
# 3      Tennessee Titans          10          26      Alex Smith
# 4     Minnesota Vikings           6          34      Shaun Hill
#
#          away_qb home_qb_abv away_qb_abv
# 0  Aaron Rodgers   R. Wilson  A. Rodgers
# 1    Andrew Luck  P. Manning     A. Luck
# 2     Chad Henne    N. Foles    C. Henne
# 3    Jake Locker    A. Smith   J. Locker
# 4    Matt Cassel     S. Hill   M. Cassel

# %%
print(len(stats))
print(len(schedule))
# Out:
# 5004
# 2291

# %%
nfl = schedule.copy()
nfl = nfl.merge(stats.add_suffix('_home'), how='left', left_on = ['season', 'week', 'home', 'home_qb_abv'], 
                right_on = ['season_home', 'week_home', 'team_full_home', 'qb_home'])
nfl = nfl.merge(stats.add_suffix('_away'), how='left', left_on = ['season', 'week', 'away', 'away_qb_abv'], 
                right_on = ['season_away', 'week_away', 'team_full_away', 'qb_away'])
nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
          'qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_rushing_value_pct_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
          'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_rushing_value_pct_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']]
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG       Denver Broncos
# 2  2014-09-07    2014     1         REG  Philadelphia Eagles
# 3  2014-09-07    2014     1         REG   Kansas City Chiefs
# 4  2014-09-07    2014     1         REG     Los Angeles Rams
#
#                    away  home_score  away_score         home_qb  \
# 0     Green Bay Packers          36          16  Russell Wilson
# 1    Indianapolis Colts          31          24  Peyton Manning
# 2  Jacksonville Jaguars          34          17      Nick Foles
# 3      Tennessee Titans          10          26      Alex Smith
# 4     Minnesota Vikings           6          34      Shaun Hill
#
#          away_qb  qb_value_home  passing_value_home  rushing_value_home  \
# 0  Aaron Rodgers            NaN                 NaN                 NaN
# 1    Andrew Luck            NaN                 NaN                 NaN
# 2     Chad Henne            NaN                 NaN                 NaN
# 3    Jake Locker            NaN                 NaN                 NaN
# 4    Matt Cassel            NaN                 NaN                 NaN
#
#    qb_rushing_value_pct_home  qb_def_value_home  pass_def_value_home  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#    rush_def_value_home  special_teams_value_home  qb_value_away  \
# 0                  NaN                       NaN            NaN
# 1                  NaN                       NaN            NaN
# 2                  NaN                       NaN            NaN
# 3                  NaN                       NaN            NaN
# 4                  NaN                       NaN            NaN
#
#    passing_value_away  rushing_value_away  qb_rushing_value_pct_away  \
# 0                 NaN                 NaN                        NaN
# 1                 NaN                 NaN                        NaN
# 2                 NaN                 NaN                        NaN
# 3                 NaN                 NaN                        NaN
# 4                 NaN                 NaN                        NaN
#
#    qb_def_value_away  pass_def_value_away  rush_def_value_away  \
# 0                NaN                  NaN                  NaN
# 1                NaN                  NaN                  NaN
# 2                NaN                  NaN                  NaN
# 3                NaN                  NaN                  NaN
# 4                NaN                  NaN                  NaN
#
#    special_teams_value_away
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
print(len(nfl))
# Out:
# 2291

# %%
# Remove any ties, add binary label for home win

nfl_cleaned = nfl.copy()
nfl_cleaned = nfl_cleaned[nfl_cleaned.home_score != nfl_cleaned.away_score]
nfl_cleaned['home_win'] = nfl_cleaned.apply(lambda x: 1 if x.home_score>x.away_score else 0, axis=1)
nfl_cleaned
# Out:
#             date  season  week season_type                  home  \
# 0     2014-09-04    2014     1         REG      Seattle Seahawks
# 1     2014-09-07    2014     1         REG        Denver Broncos
# 2     2014-09-07    2014     1         REG   Philadelphia Eagles
# 3     2014-09-07    2014     1         REG    Kansas City Chiefs
# 4     2014-09-07    2014     1         REG      Los Angeles Rams
# ...          ...     ...   ...         ...                   ...
# 2286  2022-11-06    2022     9         REG     Arizona Cardinals
# 2287  2022-11-06    2022     9         REG  Tampa Bay Buccaneers
# 2288  2022-11-06    2022     9         REG    Kansas City Chiefs
# 2289  2022-11-07    2022     9         REG    New Orleans Saints
# 2290  2022-11-10    2022    10         REG     Carolina Panthers
#
#                       away  home_score  away_score          home_qb  \
# 0        Green Bay Packers          36          16   Russell Wilson
# 1       Indianapolis Colts          31          24   Peyton Manning
# 2     Jacksonville Jaguars          34          17       Nick Foles
# 3         Tennessee Titans          10          26       Alex Smith
# 4        Minnesota Vikings           6          34       Shaun Hill
# ...                    ...         ...         ...              ...
# 2286      Seattle Seahawks          21          31     Kyler Murray
# 2287      Los Angeles Rams          16          13        Tom Brady
# 2288      Tennessee Titans          20          17  Patrick Mahomes
# 2289      Baltimore Ravens          13          27      Andy Dalton
# 2290       Atlanta Falcons          25          15      P.J. Walker
#
#                away_qb  qb_value_home  passing_value_home  rushing_value_home  \
# 0        Aaron Rodgers            NaN                 NaN                 NaN
# 1          Andrew Luck            NaN                 NaN                 NaN
# 2           Chad Henne            NaN                 NaN                 NaN
# 3          Jake Locker            NaN                 NaN                 NaN
# 4          Matt Cassel            NaN                 NaN                 NaN
# ...                ...            ...                 ...                 ...
# 2286        Geno Smith      -0.264535           -0.258297            0.175101
# 2287  Matthew Stafford       0.279256            0.318806           -0.461162
# 2288      Malik Willis       1.021356            0.981503            0.580059
# 2289     Lamar Jackson       0.191471            0.204843            0.689649
# 2290    Marcus Mariota      -0.342244           -0.224174            0.501043
#
#       qb_rushing_value_pct_home  qb_def_value_home  pass_def_value_home  \
# 0                           NaN                NaN                  NaN
# 1                           NaN                NaN                  NaN
# 2                           NaN                NaN                  NaN
# 3                           NaN                NaN                  NaN
# 4                           NaN                NaN                  NaN
# ...                         ...                ...                  ...
# 2286                        0.0           0.215838             0.180996
# 2287                        0.0          -0.348004            -0.241270
# 2288                        0.0          -0.210958            -0.291437
# 2289                        0.0           0.065368             0.116469
# 2290                        0.0          -0.359778            -0.352432
#
#       rush_def_value_home  special_teams_value_home  qb_value_away  \
# 0                     NaN                       NaN            NaN
# 1                     NaN                       NaN            NaN
# 2                     NaN                       NaN            NaN
# 3                     NaN                       NaN            NaN
# 4                     NaN                       NaN            NaN
# ...                   ...                       ...            ...
# 2286             0.058589                 -0.500268       0.449501
# 2287            -0.682795                 -0.480144      -0.298033
# 2288            -0.033792                 -0.676673            NaN
# 2289            -0.085326                 -0.614245       0.030823
# 2290            -0.267549                  0.247178       0.066786
#
#       passing_value_away  rushing_value_away  qb_rushing_value_pct_away  \
# 0                    NaN                 NaN                        NaN
# 1                    NaN                 NaN                        NaN
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                        NaN
# 4                    NaN                 NaN                        NaN
# ...                  ...                 ...                        ...
# 2286            0.380528            0.465890                        0.0
# 2287           -0.288449           -0.333501                        0.0
# 2288                 NaN                 NaN                        NaN
# 2289           -0.384250            1.409225                        0.0
# 2290           -0.144220            0.825470                        0.0
#
#       qb_def_value_away  pass_def_value_away  rush_def_value_away  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 2286          -0.136129             0.019117            -0.163519
# 2287           0.160739             0.043444             0.064755
# 2288           0.031070            -0.056612             0.086195
# 2289          -0.117026            -0.018103            -0.417191
# 2290          -0.690284            -0.594260            -0.160141
#
#       special_teams_value_away  home_win
# 0                          NaN         1
# 1                          NaN         1
# 2                          NaN         1
# 3                          NaN         0
# 4                          NaN         0
# ...                        ...       ...
# 2286                  0.487233         0
# 2287                 -0.071566         1
# 2288                  0.029785         1
# 2289                  0.735114         0
# 2290                  0.059840         1
#
# [2282 rows x 27 columns]

# %%
# Split data into train and test sets, cross validation for hyperparameter tuning

train_df = nfl_cleaned[nfl_cleaned.season <= 2021]
train_df = train_df.dropna()

test_df = nfl_cleaned[nfl_cleaned.season == 2022]
test_df = test_df.dropna()

# %%
# Shuffle training set before cross validation

train_df_shuffled = train_df.sample(frac=1, random_state=42)
train_df_shuffled.head()
# Out:
#             date  season  week season_type                  home  \
# 304   2015-09-27    2015     3         REG         New York Jets
# 1517  2019-12-01    2019    13         REG    Indianapolis Colts
# 1843  2021-01-03    2020    17         REG  New England Patriots
# 1286  2018-12-16    2018    15         REG      Los Angeles Rams
# 1368  2019-09-22    2019     3         REG     Minnesota Vikings
#
#                      away  home_score  away_score           home_qb  \
# 304   Philadelphia Eagles          17          24  Ryan Fitzpatrick
# 1517     Tennessee Titans          17          31   Jacoby Brissett
# 1843        New York Jets          28          14        Cam Newton
# 1286  Philadelphia Eagles          23          30        Jared Goff
# 1368    Las Vegas Raiders          34          14      Kirk Cousins
#
#              away_qb  qb_value_home  passing_value_home  rushing_value_home  \
# 304     Sam Bradford       0.417764            0.640862           -0.527020
# 1517  Ryan Tannehill      -0.020477           -0.034575            0.456188
# 1843     Sam Darnold      -0.471448           -0.503860            0.316892
# 1286      Nick Foles       0.089584            0.185688            0.346480
# 1368      Derek Carr      -1.245544           -1.356718            1.960948
#
#       qb_rushing_value_pct_home  qb_def_value_home  pass_def_value_home  \
# 304                         0.0           0.716284             0.464662
# 1517                        0.0           0.243974             0.355374
# 1843                        0.0          -0.143777             0.008776
# 1286                        0.0          -0.222061            -0.196463
# 1368                        0.0           0.149529             0.095559
#
#       rush_def_value_home  special_teams_value_home  qb_value_away  \
# 304              1.430636                 -0.144089      -0.578512
# 1517             0.474747                 -0.493416       0.298173
# 1843            -0.763601                  1.569712      -0.479046
# 1286            -0.307967                  0.204205      -0.755374
# 1368             1.378409                 -1.128117       0.100922
#
#       passing_value_away  rushing_value_away  qb_rushing_value_pct_away  \
# 304            -0.257582           -0.876329                        0.0
# 1517            0.262237           -0.129384                        0.0
# 1843           -0.493981           -0.500095                        0.0
# 1286           -0.868071            1.014130                        0.0
# 1368            0.113974            0.476377                        0.0
#
#       qb_def_value_away  pass_def_value_away  rush_def_value_away  \
# 304           -0.086938             0.119704             0.556979
# 1517          -0.384172            -0.512734             0.832129
# 1843          -0.224612            -0.182846             0.598376
# 1286          -0.526968            -0.538797            -0.462684
# 1368          -1.292258            -1.426230             0.775834
#
#       special_teams_value_away  home_win
# 304                  -1.621455         0
# 1517                  0.043772         0
# 1843                 -0.709727         1
# 1286                  0.021069         0
# 1368                  0.032884         1

# %%
# Prepare feature list

# feature_list = ['passing_value_home', 'rushing_value_home', 'pass_def_value_home', 'rush_def_value_home',
#                    'passing_value_away', 'rushing_value_away', 'pass_def_value_away', 'rush_def_value_away']

# feature_list = ['qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
#                    'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

feature_list = ['qb_value_home', 'rushing_value_home', 'qb_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
                   'qb_value_away', 'rushing_value_away', 'qb_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

# %%
# Get features, labels for train, val, and test sets

train_x = train_df_shuffled[feature_list].to_numpy()
train_y = train_df_shuffled.home_win.to_numpy()

test_x = test_df[feature_list]
test_y = test_df.home_win.to_numpy()

# %%
# Function to get predictions and probabilities for train, val, test sets

def get_preds(model, train_x, test_x):
    train_preds = model.predict(train_x)
    train_probs = model.predict_proba(train_x)
    
    test_preds = model.predict(test_x)
    test_probs = model.predict_proba(test_x)
    
    return train_preds, train_probs, test_preds, test_probs

# Function to get accuracy scores for train, val sets

def print_cv_results(model, train_x, train_y, cv_folds):
    cv_results = cross_validate(model, train_x, train_y, cv=5, return_train_score=True)
    
    train_scores = cv_results['train_score']
    val_scores = cv_results['test_score']

    for i, scores in enumerate(zip(train_scores, val_scores)):
        print('Fold {}, Train Accuracy: {}, Validation Accuracy: {}'.format(i+1,scores[0], scores[1]))
        
    print()
    print('Average Training Accuracy: {}'.format(np.mean(train_scores)))
    print('Average Validation Accuracy: {}'.format(np.mean(val_scores)))

# %%
# Simple Logistic Regression Model

lr_model = LogisticRegression()

print_cv_results(lr_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.6031420765027322, Validation Accuracy: 0.6348773841961853
# Fold 2, Train Accuracy: 0.6095563139931741, Validation Accuracy: 0.6174863387978142
# Fold 3, Train Accuracy: 0.616382252559727, Validation Accuracy: 0.6366120218579235
# Fold 4, Train Accuracy: 0.6279863481228669, Validation Accuracy: 0.5737704918032787
# Fold 5, Train Accuracy: 0.6204778156996587, Validation Accuracy: 0.6010928961748634
#
# Average Training Accuracy: 0.6155089613756318
# Average Validation Accuracy: 0.612767826566013

# %%
# Default Random Forest Classifier with no hyperparameter tuning

rf_model = RandomForestClassifier(n_estimators=1)

print_cv_results(rf_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.8162568306010929, Validation Accuracy: 0.5367847411444142
# Fold 2, Train Accuracy: 0.8313993174061434, Validation Accuracy: 0.5273224043715847
# Fold 3, Train Accuracy: 0.8416382252559726, Validation Accuracy: 0.5327868852459017
# Fold 4, Train Accuracy: 0.8150170648464163, Validation Accuracy: 0.5819672131147541
# Fold 5, Train Accuracy: 0.837542662116041, Validation Accuracy: 0.5355191256830601
#
# Average Training Accuracy: 0.8283708200451333
# Average Validation Accuracy: 0.542876073911943

# %%
# Default XGBoost Model with no hyperparameter tuning

xgb_model = xgb.XGBClassifier()

print_cv_results(xgb_model, train_x, train_y, 5)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:52:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:52:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:52:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:52:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:52:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.5640326975476839
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.5765027322404371
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.5710382513661202
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5601092896174863
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.5601092896174863
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5663584520778426

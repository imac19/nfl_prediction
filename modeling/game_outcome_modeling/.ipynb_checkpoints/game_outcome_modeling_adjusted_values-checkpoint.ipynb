# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import xgboost as xgb

from joblib import dump, load

pd.set_option('display.max_columns', None)
# Out:
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# stats = pd.read_csv('../../data/adjusted_value_models_combined_6_game_rolling.csv')
stats = pd.read_csv('../../pipeline/data/07_adjusted_value_models_aggregated.csv')
schedule = pd.read_csv('../../data/schedule_final.csv')

stats = stats.dropna()

# %%
stats.head()
# Out:
#     Unnamed: 0  season  week team          qb  passing_value_adjusted  \
# 64          64    2014     3  ARI  D. Stanton               -0.857878
# 65          65    2014     3  ATL     M. Ryan               -0.640304
# 66          66    2014     3  BAL   J. Flacco                0.388264
# 67          67    2014     3  BUF   E. Manuel                0.531544
# 68          68    2014     3  CAR   C. Newton                0.604152
#
#     rushing_value_adjusted  total_plays_standardized  \
# 64                0.359969                 -0.101593
# 65                0.709637                  0.279779
# 66                0.048372                  1.154692
# 67               -0.912222                 -0.370797
# 68               -0.878958                 -0.101593
#
#     total_possession_time_standardized  pass_percentage_standardized  \
# 64                           -0.628596                     -0.373010
# 65                           -0.357458                      0.832298
# 66                            0.569921                     -0.103556
# 67                           -0.198053                     -1.418698
# 68                           -0.226359                      0.373782
#
#     pass_def_value_adjusted  rush_def_value_adjusted  special_teams_value  \
# 64                -0.160789                 0.607663             1.173452
# 65                -0.824354                -0.311896             1.010280
# 66                 0.786102                -0.208942             0.137405
# 67                 0.256764                 0.606452             1.562575
# 68                 0.309284                 0.344995             1.301579
#
#             team_full
# 64  Arizona Cardinals
# 65    Atlanta Falcons
# 66   Baltimore Ravens
# 67      Buffalo Bills
# 68  Carolina Panthers

# %%
stats
# Out:
#       Unnamed: 0  season  week team          qb  passing_value_adjusted  \
# 64            64    2014     3  ARI  D. Stanton               -0.857878
# 65            65    2014     3  ATL     M. Ryan               -0.640304
# 66            66    2014     3  BAL   J. Flacco                0.388264
# 67            67    2014     3  BUF   E. Manuel                0.531544
# 68            68    2014     3  CAR   C. Newton                0.604152
# ...          ...     ...   ...  ...         ...                     ...
# 4856        4856    2022    21  CIN   J. Burrow                0.363199
# 4857        4857    2022    21   KC  P. Mahomes                0.474375
# 4858        4858    2022    21  PHI    J. Hurts                0.131127
# 4860        4860    2022    22   KC  P. Mahomes                0.474073
# 4861        4861    2022    22  PHI    J. Hurts               -0.017934
#
#       rushing_value_adjusted  total_plays_standardized  \
# 64                  0.359969                 -0.101593
# 65                  0.709637                  0.279779
# 66                  0.048372                  1.154692
# 67                 -0.912222                 -0.370797
# 68                 -0.878958                 -0.101593
# ...                      ...                       ...
# 4856                0.164351                  0.520941
# 4857                0.512161                 -0.449315
# 4858                1.616761                  0.672368
# 4860                0.212715                 -0.185719
# 4861                1.316055                  0.694802
#
#       total_possession_time_standardized  pass_percentage_standardized  \
# 64                             -0.628596                     -0.373010
# 65                             -0.357458                      0.832298
# 66                              0.569921                     -0.103556
# 67                             -0.198053                     -1.418698
# 68                             -0.226359                      0.373782
# ...                                  ...                           ...
# 4856                            0.625788                      0.405253
# 4857                           -0.141815                     -0.018159
# 4858                            0.560610                     -0.941733
# 4860                            0.080905                      0.354606
# 4861                            0.915175                     -1.357129
#
#       pass_def_value_adjusted  rush_def_value_adjusted  special_teams_value  \
# 64                  -0.160789                 0.607663             1.173452
# 65                  -0.824354                -0.311896             1.010280
# 66                   0.786102                -0.208942             0.137405
# 67                   0.256764                 0.606452             1.562575
# 68                   0.309284                 0.344995             1.301579
# ...                       ...                      ...                  ...
# 4856                -0.080416                 0.555210             0.215284
# 4857                 0.781146                -0.771093            -0.504759
# 4858                 0.742787                -0.131826             0.329906
# 4860                 0.612055                -0.822898            -0.455509
# 4861                 0.526715                -0.133076             0.091893
#
#                 team_full
# 64      Arizona Cardinals
# 65        Atlanta Falcons
# 66       Baltimore Ravens
# 67          Buffalo Bills
# 68      Carolina Panthers
# ...                   ...
# 4856   Cincinnati Bengals
# 4857   Kansas City Chiefs
# 4858  Philadelphia Eagles
# 4860   Kansas City Chiefs
# 4861  Philadelphia Eagles
#
# [4555 rows x 14 columns]

# %%
schedule.head()
# Out:
#    Unnamed: 0        date  season  week season_type                 home  \
# 0           0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1           1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2           2  2014-09-07    2014     1         REG       Houston Texans
# 3           3  2014-09-07    2014     1         REG        Chicago Bears
# 4           4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb        home_qb_abv away_qb_abv
# 0   Aaron Rodgers          R. Wilson  A. Rodgers
# 1     Andy Dalton          J. Flacco   A. Dalton
# 2  Robert Griffin     R. Fitzpatrick  R. Griffin
# 3       EJ Manuel          J. Cutler   E. Manuel
# 4     Brian Hoyer  B. Roethlisberger    B. Hoyer

# %%
print(len(stats))
print(len(schedule))
# Out:
# 4555
# 2438

# %%
nfl = schedule.copy()
nfl = nfl.merge(stats.add_suffix('_home'), how='left', left_on = ['season', 'week', 'home', 'home_qb_abv'], 
                right_on = ['season_home', 'week_home', 'team_full_home', 'qb_home'])
nfl = nfl.merge(stats.add_suffix('_away'), how='left', left_on = ['season', 'week', 'away', 'away_qb_abv'], 
                right_on = ['season_away', 'week_away', 'team_full_away', 'qb_away'])
# nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
#           'qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_rushing_value_pct_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
#           'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_rushing_value_pct_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away']]
# nfl.head()
nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
          'passing_value_adjusted_home', 'rushing_value_adjusted_home', 'pass_def_value_adjusted_home', 'rush_def_value_adjusted_home', 'special_teams_value_home',
          'passing_value_adjusted_away', 'rushing_value_adjusted_away', 'pass_def_value_adjusted_away', 'rush_def_value_adjusted_away', 'special_teams_value_away']]
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  passing_value_adjusted_home  rushing_value_adjusted_home  \
# 0   Aaron Rodgers                          NaN                          NaN
# 1     Andy Dalton                          NaN                          NaN
# 2  Robert Griffin                          NaN                          NaN
# 3       EJ Manuel                          NaN                          NaN
# 4     Brian Hoyer                          NaN                          NaN
#
#    pass_def_value_adjusted_home  rush_def_value_adjusted_home  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    special_teams_value_home  passing_value_adjusted_away  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    rushing_value_adjusted_away  pass_def_value_adjusted_away  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    rush_def_value_adjusted_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
print(len(nfl))
# Out:
# 2438

# %%
# Remove any ties, add binary label for home win

nfl_cleaned = nfl.copy()
nfl_cleaned = nfl_cleaned[nfl_cleaned.home_score != nfl_cleaned.away_score]
nfl_cleaned['home_win'] = nfl_cleaned.apply(lambda x: 1 if x.home_score>x.away_score else 0, axis=1)
nfl_cleaned
# Out:
#             date  season  week season_type                 home  \
# 0     2014-09-04    2014     1         REG     Seattle Seahawks
# 1     2014-09-07    2014     1         REG     Baltimore Ravens
# 2     2014-09-07    2014     1         REG       Houston Texans
# 3     2014-09-07    2014     1         REG        Chicago Bears
# 4     2014-09-07    2014     1         REG  Pittsburgh Steelers
# ...          ...     ...   ...         ...                  ...
# 2433  2023-01-22    2022    20        POST        Buffalo Bills
# 2434  2023-01-22    2022    20        POST  San Francisco 49ers
# 2435  2023-01-29    2022    21        POST  Philadelphia Eagles
# 2436  2023-01-29    2022    21        POST   Kansas City Chiefs
# 2437  2023-02-12    2022    22        POST  Philadelphia Eagles
#
#                           away  home_score  away_score             home_qb  \
# 0            Green Bay Packers          36          16      Russell Wilson
# 1           Cincinnati Bengals          16          23          Joe Flacco
# 2     Washington Football Team          17           6    Ryan Fitzpatrick
# 3                Buffalo Bills          20          23          Jay Cutler
# 4             Cleveland Browns          30          27  Ben Roethlisberger
# ...                        ...         ...         ...                 ...
# 2433        Cincinnati Bengals          10          27          Josh Allen
# 2434            Dallas Cowboys          19          12         Brock Purdy
# 2435       San Francisco 49ers          31           7         Jalen Hurts
# 2436        Cincinnati Bengals          23          20     Patrick Mahomes
# 2437        Kansas City Chiefs          35          38         Jalen Hurts
#
#               away_qb  passing_value_adjusted_home  \
# 0       Aaron Rodgers                          NaN
# 1         Andy Dalton                          NaN
# 2      Robert Griffin                          NaN
# 3           EJ Manuel                          NaN
# 4         Brian Hoyer                          NaN
# ...               ...                          ...
# 2433       Joe Burrow                    -0.151187
# 2434     Dak Prescott                     1.271880
# 2435      Brock Purdy                     0.131127
# 2436       Joe Burrow                     0.474375
# 2437  Patrick Mahomes                    -0.017934
#
#       rushing_value_adjusted_home  pass_def_value_adjusted_home  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 2433                     0.650933                      0.483813
# 2434                     0.634522                      0.303955
# 2435                     1.616761                      0.742787
# 2436                     0.512161                      0.781146
# 2437                     1.316055                      0.526715
#
#       rush_def_value_adjusted_home  special_teams_value_home  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 2433                      0.589479                 -0.215688
# 2434                      0.348498                  0.331705
# 2435                     -0.131826                  0.329906
# 2436                     -0.771093                 -0.504759
# 2437                     -0.133076                  0.091893
#
#       passing_value_adjusted_away  rushing_value_adjusted_away  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2433                     0.002339                    -0.152032
# 2434                     0.563132                    -0.743069
# 2435                          NaN                          NaN
# 2436                     0.363199                     0.164351
# 2437                     0.474073                     0.212715
#
#       pass_def_value_adjusted_away  rush_def_value_adjusted_away  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2433                     -0.140611                      1.049708
# 2434                     -0.104332                      0.297954
# 2435                           NaN                           NaN
# 2436                     -0.080416                      0.555210
# 2437                      0.612055                     -0.822898
#
#       special_teams_value_away  home_win
# 0                          NaN         1
# 1                          NaN         0
# 2                          NaN         1
# 3                          NaN         0
# 4                          NaN         1
# ...                        ...       ...
# 2433                  0.204819         0
# 2434                 -0.500316         1
# 2435                       NaN         1
# 2436                  0.215284         1
# 2437                 -0.455509         0
#
# [2428 rows x 21 columns]

# %%
nfl_cleaned.to_csv('../../data/adjusted_stats_modeling_base_df.csv')

# %%
# Split data into train and test sets, cross validation for hyperparameter tuning

train_df = nfl_cleaned[nfl_cleaned.season <= 2021]
train_df = train_df.dropna()

test_df = nfl_cleaned[nfl_cleaned.season == 2022]
test_df = test_df.dropna()

# %%
# Balance training data set

# Note: Can't balance data set and then do Cross Validation due to data leakage

# Fully balancing the data set doesnt work as well for prediction as the unbalanced, likely because the 
# home team does actually have an important advantage. But, maybe balancing the data set slightly will help

balance_n = int(np.round((sum(train_df.home_win==1) - sum(train_df.home_win==0))/1.5))
to_add = train_df[train_df.home_win==0].sample(n=balance_n, random_state=57, replace=True)

train_df_balanced = pd.concat([train_df, to_add])
train_df_balanced
# Out:
#             date  season  week season_type                      home  \
# 33    2014-09-21    2014     3         REG      New England Patriots
# 36    2014-09-21    2014     3         REG          Cleveland Browns
# 37    2014-09-21    2014     3         REG         Carolina Panthers
# 38    2014-09-21    2014     3         REG         Arizona Cardinals
# 39    2014-09-21    2014     3         REG             Buffalo Bills
# ...          ...     ...   ...         ...                       ...
# 1188  2018-11-04    2018     9         REG  Washington Football Team
# 1925  2021-10-03    2021     4         REG       Philadelphia Eagles
# 1785  2020-12-06    2020    13         REG         Arizona Cardinals
# 580   2016-10-02    2016     4         REG          Baltimore Ravens
# 312   2015-10-04    2015     4         REG            Miami Dolphins
#
#                       away  home_score  away_score         home_qb  \
# 33       Las Vegas Raiders          16           9       Tom Brady
# 36        Baltimore Ravens          21          23     Brian Hoyer
# 37     Pittsburgh Steelers          19          37      Cam Newton
# 38     San Francisco 49ers          23          14    Drew Stanton
# 39    Los Angeles Chargers          10          22       EJ Manuel
# ...                    ...         ...         ...             ...
# 1188       Atlanta Falcons          14          38      Alex Smith
# 1925    Kansas City Chiefs          30          42     Jalen Hurts
# 1785      Los Angeles Rams          28          38    Kyler Murray
# 580      Las Vegas Raiders          27          28      Joe Flacco
# 312          New York Jets          14          27  Ryan Tannehill
#
#                  away_qb  passing_value_adjusted_home  \
# 33            Derek Carr                     0.387129
# 36            Joe Flacco                    -0.137203
# 37    Ben Roethlisberger                     0.604152
# 38      Colin Kaepernick                    -0.857878
# 39         Philip Rivers                     0.531544
# ...                  ...                          ...
# 1188           Matt Ryan                    -0.036093
# 1925     Patrick Mahomes                    -0.286919
# 1785          Jared Goff                     0.139213
# 580           Derek Carr                    -0.422515
# 312     Ryan Fitzpatrick                    -0.248890
#
#       rushing_value_adjusted_home  pass_def_value_adjusted_home  \
# 33                      -0.120190                      1.178166
# 36                       0.141640                      0.192438
# 37                      -0.878958                      0.309284
# 38                       0.359969                     -0.160789
# 39                      -0.912222                      0.256764
# ...                           ...                           ...
# 1188                     0.014031                      0.015746
# 1925                    -0.407994                     -0.125187
# 1785                    -0.061784                      0.360214
# 580                     -0.462119                      0.201390
# 312                      0.097885                     -1.526618
#
#       rush_def_value_adjusted_home  special_teams_value_home  \
# 33                        0.163060                  1.176841
# 36                       -0.869159                 -0.162922
# 37                        0.344995                  1.301579
# 38                        0.607663                  1.173452
# 39                        0.606452                  1.562575
# ...                            ...                       ...
# 1188                      0.155850                  0.616255
# 1925                      0.411511                 -0.418877
# 1785                     -0.249638                 -0.987128
# 580                       0.405589                  1.108172
# 312                       0.898376                  0.192372
#
#       passing_value_adjusted_away  rushing_value_adjusted_away  \
# 33                      -0.702046                     0.774141
# 36                       0.388264                     0.048372
# 37                      -0.782914                     0.355480
# 38                      -0.287031                    -0.471071
# 39                       0.804905                    -0.212663
# ...                           ...                          ...
# 1188                     0.573131                    -0.298159
# 1925                     0.693191                     0.428340
# 1785                    -0.710603                    -0.729298
# 580                      0.196486                     0.379760
# 312                     -0.075353                    -0.313180
#
#       pass_def_value_adjusted_away  rush_def_value_adjusted_away  \
# 33                       -0.954522                     -0.448204
# 36                        0.786102                     -0.208942
# 37                       -0.482694                     -0.196212
# 38                       -0.239934                      0.452426
# 39                       -0.100618                     -0.538650
# ...                            ...                           ...
# 1188                     -0.875016                     -0.440960
# 1925                     -0.507825                     -0.841911
# 1785                      0.646045                      1.378006
# 580                      -0.016867                     -0.449307
# 312                       0.395328                      0.721871
#
#       special_teams_value_away  home_win
# 33                   -0.351268         1
# 36                    0.137405         0
# 37                    0.017013         0
# 38                    0.402579         1
# 39                    1.051236         0
# ...                        ...       ...
# 1188                  0.220620         0
# 1925                  0.107728         0
# 1785                 -0.845659         0
# 580                  -0.028489         0
# 312                  -0.190208         0
#
# [1990 rows x 21 columns]

# %%
# Shuffle training set before cross validation

train_df_shuffled = train_df.sample(frac=1, random_state=42)
train_df_shuffled.head()
# Out:
#             date  season  week season_type               home  \
# 1838  2020-12-27    2020    16         REG  Green Bay Packers
# 1352  2019-09-15    2019     2         REG   Baltimore Ravens
# 945   2017-11-19    2017    11         REG    New York Giants
# 1792  2020-12-10    2020    14         REG   Los Angeles Rams
# 1539  2019-12-08    2019    14         REG  Arizona Cardinals
#
#                       away  home_score  away_score        home_qb  \
# 1838      Tennessee Titans          40          14  Aaron Rodgers
# 1352     Arizona Cardinals          23          17  Lamar Jackson
# 945     Kansas City Chiefs          12           9    Eli Manning
# 1792  New England Patriots          24           3     Jared Goff
# 1539   Pittsburgh Steelers          17          23   Kyler Murray
#
#              away_qb  passing_value_adjusted_home  \
# 1838  Ryan Tannehill                     0.466485
# 1352    Kyler Murray                     1.272759
# 945       Alex Smith                    -0.039829
# 1792      Cam Newton                    -0.026420
# 1539   Devlin Hodges                    -0.889550
#
#       rushing_value_adjusted_home  pass_def_value_adjusted_home  \
# 1838                     1.431765                      0.002015
# 1352                    -0.023688                      0.461062
# 945                     -0.000036                     -1.512584
# 1792                    -0.681167                      0.801688
# 1539                     0.059995                     -0.876862
#
#       rush_def_value_adjusted_home  special_teams_value_home  \
# 1838                     -0.115156                 -0.299801
# 1352                      0.217732                 -0.056824
# 945                       0.302193                 -0.999824
# 1792                      0.895408                 -0.985010
# 1539                      0.537475                  0.429780
#
#       passing_value_adjusted_away  rushing_value_adjusted_away  \
# 1838                     1.251468                     0.602539
# 1352                    -0.293510                     0.237456
# 945                      0.345401                    -0.454229
# 1792                    -0.612443                     0.577920
# 1539                     0.509469                    -0.403408
#
#       pass_def_value_adjusted_away  rush_def_value_adjusted_away  \
# 1838                     -0.650224                      0.585708
# 1352                      0.137737                     -0.511358
# 945                      -0.324199                     -0.463611
# 1792                      0.315354                     -0.001739
# 1539                      0.797254                      0.466341
#
#       special_teams_value_away  home_win
# 1838                  0.144139         1
# 1352                  1.454204         1
# 945                   1.620575         1
# 1792                  2.166391         1
# 1539                  0.357014         0

# %%
# Prepare feature list

# feature_list = ['passing_value_home', 'rushing_value_home', 'pass_def_value_home', 'rush_def_value_home',
#                    'passing_value_away', 'rushing_value_away', 'pass_def_value_away', 'rush_def_value_away']

# feature_list = ['qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
#                    'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

# feature_list = ['qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
#                    'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away']

feature_list =['passing_value_adjusted_home', 'rushing_value_adjusted_home', 'pass_def_value_adjusted_home', 'rush_def_value_adjusted_home', 'special_teams_value_home',
          'passing_value_adjusted_away', 'rushing_value_adjusted_away', 'pass_def_value_adjusted_away', 'rush_def_value_adjusted_away', 'special_teams_value_away']

# %%
# Get features, labels for train, val, and test sets

train_x = train_df_balanced[feature_list].to_numpy()
train_y = train_df_balanced.home_win.to_numpy()

# train_x = train_df_shuffled[feature_list].to_numpy()
# train_y = train_df_shuffled.home_win.to_numpy()

test_x = test_df[feature_list]
test_y = test_df.home_win.to_numpy()

# %%
train_df_shuffled.week
# Out:
# 1838    16
# 1352     2
# 945     11
# 1792    14
# 1539    14
#         ..
# 1315    17
# 1506    12
# 1014    15
# 1707     8
# 1311    17
# Name: week, Length: 1845, dtype: int64

# %%
# Function to get predictions and probabilities for train, val, test sets

def get_preds(model, train_x, test_x):
    train_preds = model.predict(train_x)
    train_probs = model.predict_proba(train_x)
    
    test_preds = model.predict(test_x)
    test_probs = model.predict_proba(test_x)
    
    return train_preds, train_probs, test_preds, test_probs

# Function to get accuracy scores for train, val sets

def print_cv_results(model, train_x, train_y, cv_folds, verbose=True):
    cv_results = cross_validate(model, train_x, train_y, cv=5, return_train_score=True)
    
    train_scores = cv_results['train_score']
    val_scores = cv_results['test_score']
    
    if verbose:      
        for i, scores in enumerate(zip(train_scores, val_scores)):
            print('Fold {}, Train Accuracy: {}, Validation Accuracy: {}'.format(i+1,scores[0], scores[1]))     
        print()
        
    print('Average Training Accuracy: {}'.format(np.mean(train_scores)))
    print('Average Validation Accuracy: {}'.format(np.mean(val_scores)))
    
    return np.mean(train_scores), np.mean(val_scores)

# %%
# Simple Logistic Regression Model

lr_model = LogisticRegression()

print_cv_results(lr_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.6199748743718593, Validation Accuracy: 0.628140703517588
# Fold 2, Train Accuracy: 0.6199748743718593, Validation Accuracy: 0.5879396984924623
# Fold 3, Train Accuracy: 0.6193467336683417, Validation Accuracy: 0.6155778894472361
# Fold 4, Train Accuracy: 0.6136934673366834, Validation Accuracy: 0.6080402010050251
# Fold 5, Train Accuracy: 0.6212311557788944, Validation Accuracy: 0.592964824120603
#
# Average Training Accuracy: 0.6188442211055276
# Average Validation Accuracy: 0.606532663316583
# (0.6188442211055276, 0.606532663316583)

# %%
# Default Random Forest Classifier with no hyperparameter tuning

rf_model = RandomForestClassifier()

print_cv_results(rf_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.6180904522613065
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.6105527638190955
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.6180904522613065
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5979899497487438
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.7462311557788944
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.6381909547738693
# (1.0, 0.6381909547738693)

# %%
# Default XGBoost Model with no hyperparameter tuning

xgb_model = xgb.XGBClassifier()

print_cv_results(xgb_model, train_x, train_y, 5)
# Out:
# [15:46:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:46:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.6130653266331658
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.6155778894472361
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.6331658291457286
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5804020100502513
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.7261306532663316
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.6336683417085427
# (1.0, 0.6336683417085427)

# %%
# Logistic Regression, with hyperparameter tuning

def logistic_regression_tuning(train_x, train_y, verbose=True):
    
    lr_model = LogisticRegression()
    
    # Hyperparameters to tune
    penalty_list = ['none', 'l2', 'l1', 'elasticnet']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    
    params = dict(solver=solvers, penalty=penalty_list, C=c_values)
    
    clf = GridSearchCV(lr_model, params, return_train_score=True).fit(train_x, train_y)
    
    print('Best Result: {}'.format(clf.best_score_))
    print('Best Parameters: {}'.format(clf.best_params_))
    print()
    
    train_scores = clf.cv_results_['mean_train_score']
    val_scores = clf.cv_results_['mean_test_score']
    param_list = clf.cv_results_['params']
    
    if verbose:
        print('Parameter Combinations and Results:')
        for train_score, val_score, params in zip(train_scores, val_scores, param_list):
            print('Train Score: {}, Val Score: {}, Parameters: {}'.format(train_score, val_score, params))

# %%
# Can uncomment and run below to see, but hyperparameter tuning didnt change much. Can probably just roll with the 
# default logistic regression

# logistic_regression_tuning(train_x, train_y)

# %%
# Save best logistic regression model 

best_lr_model = LogisticRegression().fit(train_x, train_y)
dump(best_lr_model, 'saved_models/logistic_regression_av.joblib')
# Out:
# ['saved_models/logistic_regression_av.joblib']

# %%
# Save best random forest model 

best_rf_model = RandomForestClassifier().fit(train_x, train_y)
dump(best_rf_model, 'saved_models/random_forest_av.joblib')
# Out:
# ['saved_models/random_forest_av.joblib']

# %%
# Save best xg boost model 

best_xgb_model = xgb.XGBClassifier().fit(train_x, train_y)
dump(best_xgb_model, 'saved_models/xg_boost_av.joblib')
# Out:
# [15:46:02] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/ian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ['saved_models/xg_boost_av.joblib']

# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import xgboost as xgb

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
stats = pd.read_csv('../../data/adjusted_value_models_combined_6_game_rolling.csv')
schedule = pd.read_csv('../../data/schedule_final.csv')
betting = pd.read_csv('../../data/betting_data_cleaned_with_returns.csv')
betting = betting.drop(columns=['Unnamed: 0'])

stats = stats.dropna()

# %%
stats.head()
# Out:
#     Unnamed: 0  season  week team          qb  qb_adjusted_value  \
# 64          64    2014     3  ARI  D. Stanton          -1.157754
# 65          65    2014     3  ATL     M. Ryan          -1.307454
# 66          66    2014     3  BAL   J. Flacco           0.652041
# 67          67    2014     3  BUF   E. Manuel           0.603547
# 68          68    2014     3  CAR   C. Newton           0.767364
#
#     rushing_adjusted_value  qb_rushing_value_pct  qb_def_adjusted_value  \
# 64                0.332257                   0.0              -0.737241
# 65                0.874004                   0.0              -0.879286
# 66               -0.098594                   0.0               0.629275
# 67               -2.148207                   0.0               1.100186
# 68               -0.738487                   0.0               0.730025
#
#     rush_def_adjusted_value  special_teams_value          team_full
# 64                 0.919733             0.811753  Arizona Cardinals
# 65                -0.600544             0.801254    Atlanta Falcons
# 66                -0.397593             0.040821   Baltimore Ravens
# 67                 1.118419             1.432238      Buffalo Bills
# 68                 0.510499             0.963767  Carolina Panthers

# %%
stats
# Out:
#       Unnamed: 0  season  week team          qb  qb_adjusted_value  \
# 64            64    2014     3  ARI  D. Stanton          -1.157754
# 65            65    2014     3  ATL     M. Ryan          -1.307454
# 66            66    2014     3  BAL   J. Flacco           0.652041
# 67            67    2014     3  BUF   E. Manuel           0.603547
# 68            68    2014     3  CAR   C. Newton           0.767364
# ...          ...     ...   ...  ...         ...                ...
# 4856        4856    2022    21  CIN   J. Burrow           0.235993
# 4857        4857    2022    21   KC  P. Mahomes           0.626274
# 4858        4858    2022    21  PHI    J. Hurts           0.756473
# 4860        4860    2022    22   KC  P. Mahomes           0.666601
# 4861        4861    2022    22  PHI    J. Hurts           0.579982
#
#       rushing_adjusted_value  qb_rushing_value_pct  qb_def_adjusted_value  \
# 64                  0.332257                   0.0              -0.737241
# 65                  0.874004                   0.0              -0.879286
# 66                 -0.098594                   0.0               0.629275
# 67                 -2.148207                   0.0               1.100186
# 68                 -0.738487                   0.0               0.730025
# ...                      ...                   ...                    ...
# 4856                0.222464                   0.0               0.210351
# 4857                0.390027                   0.0               0.641969
# 4858                2.287960                   0.0               0.513945
# 4860                0.280515                   0.0               0.579033
# 4861                1.844241                   0.0               0.614928
#
#       rush_def_adjusted_value  special_teams_value            team_full
# 64                   0.919733             0.811753    Arizona Cardinals
# 65                  -0.600544             0.801254      Atlanta Falcons
# 66                  -0.397593             0.040821     Baltimore Ravens
# 67                   1.118419             1.432238        Buffalo Bills
# 68                   0.510499             0.963767    Carolina Panthers
# ...                       ...                  ...                  ...
# 4856                 0.832600             0.139439   Cincinnati Bengals
# 4857                -0.456237            -0.444345   Kansas City Chiefs
# 4858                -0.159588             0.134125  Philadelphia Eagles
# 4860                -0.464682            -0.538741   Kansas City Chiefs
# 4861                 0.023217            -0.025276  Philadelphia Eagles
#
# [4555 rows x 12 columns]

# %%
schedule.head()
# Out:
#    Unnamed: 0        date  season  week season_type                 home  \
# 0           0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1           1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2           2  2014-09-07    2014     1         REG       Houston Texans
# 3           3  2014-09-07    2014     1         REG        Chicago Bears
# 4           4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb        home_qb_abv away_qb_abv
# 0   Aaron Rodgers          R. Wilson  A. Rodgers
# 1     Andy Dalton          J. Flacco   A. Dalton
# 2  Robert Griffin     R. Fitzpatrick  R. Griffin
# 3       EJ Manuel          J. Cutler   E. Manuel
# 4     Brian Hoyer  B. Roethlisberger    B. Hoyer

# %%
print(len(stats))
print(len(schedule))
# Out:
# 4555
# 2438

# %%
nfl = schedule.copy()
nfl = nfl.merge(stats.add_suffix('_home'), how='left', left_on = ['season', 'week', 'home', 'home_qb_abv'], 
                right_on = ['season_home', 'week_home', 'team_full_home', 'qb_home'])
nfl = nfl.merge(stats.add_suffix('_away'), how='left', left_on = ['season', 'week', 'away', 'away_qb_abv'], 
                right_on = ['season_away', 'week_away', 'team_full_away', 'qb_away'])
nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
          'qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_rushing_value_pct_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
          'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_rushing_value_pct_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away']]
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 0   Aaron Rodgers                     NaN                          NaN
# 1     Andy Dalton                     NaN                          NaN
# 2  Robert Griffin                     NaN                          NaN
# 3       EJ Manuel                     NaN                          NaN
# 4     Brian Hoyer                     NaN                          NaN
#
#    qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_home  special_teams_value_home  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    qb_adjusted_value_away  rushing_adjusted_value_away  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
print(len(nfl))
# Out:
# 2438

# %%
betting.head()
# Out:
#          date            home_team            away_team  home_score  \
# 0  2023-02-12  Philadelphia Eagles   Kansas City Chiefs          35
# 1  2023-01-29   Kansas City Chiefs   Cincinnati Bengals          23
# 2  2023-01-29  Philadelphia Eagles  San Francisco 49ers          31
# 3  2023-01-22  San Francisco 49ers       Dallas Cowboys          19
# 4  2023-01-22        Buffalo Bills   Cincinnati Bengals          10
#
#    away_score  total_score  home_moneyline  away_moneyline  home_spread  \
# 0          38           73          -120.0           100.0         -1.0
# 1          20           43          -130.0           110.0         -2.0
# 2           7           38          -155.0           135.0         -3.0
# 3          12           31          -200.0           170.0         -3.5
# 4          27           37          -260.0           215.0         -6.0
#
#    away_spread  total_score.1 over_under_result  home_team_actual_line  \
# 0          1.0           51.5              over                      3
# 1          2.0           48.5             under                     -3
# 2          3.0           45.0             under                    -24
# 3          3.5           46.5             under                     -7
# 4          6.0           48.5             under                     17
#
#    away_team_actual_line spread_cover_result  home_implied_prob  \
# 0                     -3                away           0.545455
# 1                      3                home           0.565217
# 2                     24                home           0.607843
# 3                      7                home           0.666667
# 4                    -17                away           0.722222
#
#    away_implied_prob game_winner  favorite_return  underdog_return  \
# 0           0.500000        away          -100.00            100.0
# 1           0.476190        home            76.92           -100.0
# 2           0.425532        home            64.52           -100.0
# 3           0.370370        home            50.00           -100.0
# 4           0.317460        away          -100.00            215.0
#
#    home_return  away_return  favorite_spread_return  underdog_spread_return  \
# 0      -100.00        100.0                 -100.00                   90.91
# 1        76.92       -100.0                   90.91                 -100.00
# 2        64.52       -100.0                   90.91                 -100.00
# 3        50.00       -100.0                   90.91                 -100.00
# 4      -100.00        215.0                 -100.00                   90.91
#
#    home_spread_return  away_spread_return  over_return  under_return
# 0             -100.00               90.91        90.91       -100.00
# 1               90.91             -100.00      -100.00         90.91
# 2               90.91             -100.00      -100.00         90.91
# 3               90.91             -100.00      -100.00         90.91
# 4             -100.00               90.91      -100.00         90.91

# %%
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 0   Aaron Rodgers                     NaN                          NaN
# 1     Andy Dalton                     NaN                          NaN
# 2  Robert Griffin                     NaN                          NaN
# 3       EJ Manuel                     NaN                          NaN
# 4     Brian Hoyer                     NaN                          NaN
#
#    qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_home  special_teams_value_home  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    qb_adjusted_value_away  rushing_adjusted_value_away  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    rush_def_adjusted_value_away  special_teams_value_away  home_win
# 0                           NaN                       NaN         1
# 1                           NaN                       NaN         0
# 2                           NaN                       NaN         1
# 3                           NaN                       NaN         0
# 4                           NaN                       NaN         1

# %%
# Join in betting data to get point spreads

nfl_cleaned_with_betting = nfl.merge(betting, left_on=['date', 'home', 'away'],
                                            right_on=['date', 'home_team','away_team'])

# %%
# Remove any pushes, add binary label for home cover

nfl_cleaned_with_betting_final = nfl_cleaned_with_betting.copy()
nfl_cleaned_with_betting_final['home_cover'] = nfl_cleaned_with_betting_final.apply(
    lambda x: 1 if x.spread_cover_result == 'home' else 0, axis=1)
nfl_cleaned_with_betting_final = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.spread_cover_result != 'push']
nfl_cleaned_with_betting_final
# Out:
#             date  season  week season_type                 home  \
# 0     2014-09-04    2014     1         REG     Seattle Seahawks
# 1     2014-09-07    2014     1         REG     Baltimore Ravens
# 2     2014-09-07    2014     1         REG       Houston Texans
# 3     2014-09-07    2014     1         REG        Chicago Bears
# 4     2014-09-07    2014     1         REG  Pittsburgh Steelers
# ...          ...     ...   ...         ...                  ...
# 2392  2023-01-22    2022    20        POST        Buffalo Bills
# 2393  2023-01-22    2022    20        POST  San Francisco 49ers
# 2394  2023-01-29    2022    21        POST  Philadelphia Eagles
# 2395  2023-01-29    2022    21        POST   Kansas City Chiefs
# 2396  2023-02-12    2022    22        POST  Philadelphia Eagles
#
#                           away  home_score_x  away_score_x  \
# 0            Green Bay Packers            36            16
# 1           Cincinnati Bengals            16            23
# 2     Washington Football Team            17             6
# 3                Buffalo Bills            20            23
# 4             Cleveland Browns            30            27
# ...                        ...           ...           ...
# 2392        Cincinnati Bengals            10            27
# 2393            Dallas Cowboys            19            12
# 2394       San Francisco 49ers            31             7
# 2395        Cincinnati Bengals            23            20
# 2396        Kansas City Chiefs            35            38
#
#                  home_qb          away_qb  qb_adjusted_value_home  \
# 0         Russell Wilson    Aaron Rodgers                     NaN
# 1             Joe Flacco      Andy Dalton                     NaN
# 2       Ryan Fitzpatrick   Robert Griffin                     NaN
# 3             Jay Cutler        EJ Manuel                     NaN
# 4     Ben Roethlisberger      Brian Hoyer                     NaN
# ...                  ...              ...                     ...
# 2392          Josh Allen       Joe Burrow                0.285539
# 2393         Brock Purdy     Dak Prescott                0.764975
# 2394         Jalen Hurts      Brock Purdy                0.756473
# 2395     Patrick Mahomes       Joe Burrow                0.626274
# 2396         Jalen Hurts  Patrick Mahomes                0.579982
#
#       rushing_adjusted_value_home  qb_rushing_value_pct_home  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 2392                     0.625543                        0.0
# 2393                     0.633274                        0.0
# 2394                     2.287960                        0.0
# 2395                     0.390027                        0.0
# 2396                     1.844241                        0.0
#
#       qb_def_adjusted_value_home  rush_def_adjusted_value_home  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 2392                    0.660321                      0.512648
# 2393                    0.686924                      0.583874
# 2394                    0.513945                     -0.159588
# 2395                    0.641969                     -0.456237
# 2396                    0.614928                      0.023217
#
#       special_teams_value_home  qb_adjusted_value_away  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 2392                  0.183350                0.310046
# 2393                  0.178761                0.207053
# 2394                  0.134125                     NaN
# 2395                 -0.444345                0.235993
# 2396                 -0.025276                0.666601
#
#       rushing_adjusted_value_away  qb_rushing_value_pct_away  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 2392                    -0.006602                        0.0
# 2393                    -0.634150                        0.0
# 2394                          NaN                        NaN
# 2395                     0.222464                        0.0
# 2396                     0.280515                        0.0
#
#       qb_def_adjusted_value_away  rush_def_adjusted_value_away  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 2392                    0.113476                      0.482189
# 2393                   -0.271663                      1.501824
# 2394                         NaN                           NaN
# 2395                    0.210351                      0.832600
# 2396                    0.579033                     -0.464682
#
#       special_teams_value_away  home_win            home_team  \
# 0                          NaN         1     Seattle Seahawks
# 1                          NaN         0     Baltimore Ravens
# 2                          NaN         1       Houston Texans
# 3                          NaN         0        Chicago Bears
# 4                          NaN         1  Pittsburgh Steelers
# ...                        ...       ...                  ...
# 2392                  0.151149         0        Buffalo Bills
# 2393                 -0.517502         1  San Francisco 49ers
# 2394                       NaN         1  Philadelphia Eagles
# 2395                  0.139439         1   Kansas City Chiefs
# 2396                 -0.538741         0  Philadelphia Eagles
#
#                      away_team  home_score_y  away_score_y  total_score  \
# 0            Green Bay Packers            36            16           52
# 1           Cincinnati Bengals            16            23           39
# 2     Washington Football Team            17             6           23
# 3                Buffalo Bills            20            23           43
# 4             Cleveland Browns            30            27           57
# ...                        ...           ...           ...          ...
# 2392        Cincinnati Bengals            10            27           37
# 2393            Dallas Cowboys            19            12           31
# 2394       San Francisco 49ers            31             7           38
# 2395        Cincinnati Bengals            23            20           43
# 2396        Kansas City Chiefs            35            38           73
#
#       home_moneyline  away_moneyline  home_spread  away_spread  total_score.1  \
# 0             -230.0           205.0         -4.5          4.5           46.5
# 1             -113.0           102.0         -1.0          1.0           43.5
# 2             -177.0           159.0         -3.0          3.0           43.5
# 3             -270.0           239.0         -7.0          7.0           47.0
# 4             -242.0           216.0         -5.5          5.5           41.5
# ...              ...             ...          ...          ...            ...
# 2392          -260.0           215.0         -6.0          6.0           48.5
# 2393          -200.0           170.0         -3.5          3.5           46.5
# 2394          -155.0           135.0         -3.0          3.0           45.0
# 2395          -130.0           110.0         -2.0          2.0           48.5
# 2396          -120.0           100.0         -1.0          1.0           51.5
#
#      over_under_result  home_team_actual_line  away_team_actual_line  \
# 0                 over                    -20                     20
# 1                under                      7                     -7
# 2                under                    -11                     11
# 3                under                      3                     -3
# 4                 over                     -3                      3
# ...                ...                    ...                    ...
# 2392             under                     17                    -17
# 2393             under                     -7                      7
# 2394             under                    -24                     24
# 2395             under                     -3                      3
# 2396              over                      3                     -3
#
#      spread_cover_result  home_implied_prob  away_implied_prob game_winner  \
# 0                   home           0.696970           0.327869        home
# 1                   away           0.530516           0.495050        away
# 2                   home           0.638989           0.386100        home
# 3                   away           0.729730           0.294985        away
# 4                   away           0.707602           0.316456        home
# ...                  ...                ...                ...         ...
# 2392                away           0.722222           0.317460        away
# 2393                home           0.666667           0.370370        home
# 2394                home           0.607843           0.425532        home
# 2395                home           0.565217           0.476190        home
# 2396                away           0.545455           0.500000        away
#
#       favorite_return  underdog_return  home_return  away_return  \
# 0               43.48           -100.0        43.48       -100.0
# 1             -100.00            102.0      -100.00        102.0
# 2               56.50           -100.0        56.50       -100.0
# 3             -100.00            239.0      -100.00        239.0
# 4               41.32           -100.0        41.32       -100.0
# ...               ...              ...          ...          ...
# 2392          -100.00            215.0      -100.00        215.0
# 2393            50.00           -100.0        50.00       -100.0
# 2394            64.52           -100.0        64.52       -100.0
# 2395            76.92           -100.0        76.92       -100.0
# 2396          -100.00            100.0      -100.00        100.0
#
#       favorite_spread_return  underdog_spread_return  home_spread_return  \
# 0                      90.91                 -100.00               90.91
# 1                    -100.00                   90.91             -100.00
# 2                      90.91                 -100.00               90.91
# 3                    -100.00                   90.91             -100.00
# 4                    -100.00                   90.91             -100.00
# ...                      ...                     ...                 ...
# 2392                 -100.00                   90.91             -100.00
# 2393                   90.91                 -100.00               90.91
# 2394                   90.91                 -100.00               90.91
# 2395                   90.91                 -100.00               90.91
# 2396                 -100.00                   90.91             -100.00
#
#       away_spread_return  over_return  under_return  home_cover
# 0                -100.00        90.91       -100.00           1
# 1                  90.91      -100.00         90.91           0
# 2                -100.00      -100.00         90.91           1
# 3                  90.91      -100.00         90.91           0
# 4                  90.91        90.91       -100.00           0
# ...                  ...          ...           ...         ...
# 2392               90.91      -100.00         90.91           0
# 2393             -100.00      -100.00         90.91           1
# 2394             -100.00      -100.00         90.91           1
# 2395             -100.00      -100.00         90.91           1
# 2396               90.91        90.91       -100.00           0
#
# [2328 rows x 51 columns]

# %%
nfl_cleaned_with_betting_final.to_csv('../../data/adjusted_stats_point_spread_modeling_base_df.csv')

# %%
# Split data into train and test sets, cross validation for hyperparameter tuning

train_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season <= 2021]
train_df = train_df.dropna()

test_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season == 2022]
test_df = test_df.dropna()

# %%
# NOTE
# Dont know if i need to balance this data set at all, point spread betting should be pretty 50/50


# Balance training data set

# Note: Can't balance data set and then do Cross Validation due to data leakage

# Fully balancing the data set doesnt work as well for prediction as the unbalanced, likely because the 
# home team does actually have an important advantage. But, maybe balancing the data set slightly will help

# balance_n = int(np.round((sum(train_df.home_win==1) - sum(train_df.home_win==0))/1.5))
# to_add = train_df[train_df.home_win==0].sample(n=balance_n, random_state=57, replace=True)

# train_df_balanced = pd.concat([train_df, to_add])
# train_df_balanced
# Out:
#             date  season  week season_type                      home  \
# 33    2014-09-21    2014     3         REG      New England Patriots
# 36    2014-09-21    2014     3         REG          Cleveland Browns
# 37    2014-09-21    2014     3         REG         Carolina Panthers
# 38    2014-09-21    2014     3         REG         Arizona Cardinals
# 39    2014-09-21    2014     3         REG             Buffalo Bills
# ...          ...     ...   ...         ...                       ...
# 1188  2018-11-04    2018     9         REG  Washington Football Team
# 1925  2021-10-03    2021     4         REG       Philadelphia Eagles
# 1785  2020-12-06    2020    13         REG         Arizona Cardinals
# 580   2016-10-02    2016     4         REG          Baltimore Ravens
# 312   2015-10-04    2015     4         REG            Miami Dolphins
#
#                       away  home_score  away_score         home_qb  \
# 33       Las Vegas Raiders          16           9       Tom Brady
# 36        Baltimore Ravens          21          23     Brian Hoyer
# 37     Pittsburgh Steelers          19          37      Cam Newton
# 38     San Francisco 49ers          23          14    Drew Stanton
# 39    Los Angeles Chargers          10          22       EJ Manuel
# ...                    ...         ...         ...             ...
# 1188       Atlanta Falcons          14          38      Alex Smith
# 1925    Kansas City Chiefs          30          42     Jalen Hurts
# 1785      Los Angeles Rams          28          38    Kyler Murray
# 580      Las Vegas Raiders          27          28      Joe Flacco
# 312          New York Jets          14          27  Ryan Tannehill
#
#                  away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 33            Derek Carr                0.456221                    -0.500777
# 36            Joe Flacco               -0.688197                     0.124970
# 37    Ben Roethlisberger                0.767364                    -0.738487
# 38      Colin Kaepernick               -1.157754                     0.332257
# 39         Philip Rivers                0.603547                    -2.148207
# ...                  ...                     ...                          ...
# 1188           Matt Ryan               -0.264829                    -0.084019
# 1925     Patrick Mahomes               -0.022404                    -0.114117
# 1785          Jared Goff                0.430281                     0.508746
# 580           Derek Carr               -0.404237                    -0.669535
# 312     Ryan Fitzpatrick               -0.223848                     0.061146
#
#       qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 33                          0.0                    2.010295
# 36                          0.0                    0.660149
# 37                          0.0                    0.730025
# 38                          0.0                   -0.737241
# 39                          0.0                    1.100186
# ...                         ...                         ...
# 1188                        0.0                   -0.104279
# 1925                        0.0                    0.122893
# 1785                        0.0                   -0.082071
# 580                         0.0                    0.362706
# 312                         0.0                   -0.957002
#
#       rush_def_adjusted_value_home  special_teams_value_home  \
# 33                        0.231263                  0.937560
# 36                       -1.343275                 -0.273793
# 37                        0.510499                  0.963767
# 38                        0.919733                  0.811753
# 39                        1.118419                  1.432238
# ...                            ...                       ...
# 1188                     -0.165206                  0.526713
# 1925                      0.436458                 -0.625807
# 1785                     -0.485238                 -0.556574
# 580                       0.043280                  0.880426
# 312                       0.554488                 -0.414452
#
#       qb_adjusted_value_away  rushing_adjusted_value_away  \
# 33                  0.007547                     0.969365
# 36                  0.652041                    -0.098594
# 37                 -0.690944                     0.546799
# 38                 -0.824994                    -1.032782
# 39                  1.482525                    -0.731489
# ...                      ...                          ...
# 1188                1.093633                    -0.270172
# 1925                0.988577                     0.612736
# 1785               -0.733724                    -0.467673
# 580                -0.247696                     0.321605
# 312                -0.151846                    -0.391472
#
#       qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 33                          0.0                   -0.691465
# 36                          0.0                    0.629275
# 37                          0.0                   -0.802556
# 38                          0.0                   -0.144545
# 39                          0.0                    0.011487
# ...                         ...                         ...
# 1188                        0.0                   -1.020006
# 1925                        0.0                   -0.260635
# 1785                        0.0                    0.835681
# 580                         0.0                   -0.061886
# 312                         0.0                    0.562131
#
#       rush_def_adjusted_value_away  special_teams_value_away  home_win
# 33                       -0.992021                 -0.444697         1
# 36                       -0.397593                  0.040821         0
# 37                       -0.322210                  0.152202         0
# 38                        0.759720                  0.278262         1
# 39                       -0.674026                  1.042154         0
# ...                            ...                       ...       ...
# 1188                     -0.785239                 -0.209668         0
# 1925                     -1.163442                 -0.334241         0
# 1785                      1.244867                 -0.866246         0
# 580                      -0.026805                  0.212009         0
# 312                       0.341441                 -0.228840         0
#
# [1990 rows x 23 columns]

# %%
# Shuffle training set before cross validation

train_df_shuffled = train_df.sample(frac=1, random_state=42)
train_df_shuffled.head()
# Out:
#             date  season  week season_type                      home  \
# 1166  2018-11-11    2018    10         REG          Cleveland Browns
# 358   2015-11-01    2015     8         REG          Los Angeles Rams
# 516   2016-09-11    2016     1         REG        Kansas City Chiefs
# 1154  2018-11-04    2018     9         REG  Washington Football Team
# 641   2016-11-13    2016    10         REG      Jacksonville Jaguars
#
#                       away  home_score_x  away_score_x         home_qb  \
# 1166       Atlanta Falcons            28            16  Baker Mayfield
# 358    San Francisco 49ers            27             6      Nick Foles
# 516   Los Angeles Chargers            33            27      Alex Smith
# 1154       Atlanta Falcons            14            38      Alex Smith
# 641         Houston Texans            21            24   Blake Bortles
#
#                away_qb  qb_adjusted_value_home  rushing_adjusted_value_home  \
# 1166         Matt Ryan               -0.941167                    -0.012252
# 358   Colin Kaepernick               -0.909849                    -0.220933
# 516      Philip Rivers                0.156926                     0.691923
# 1154         Matt Ryan               -0.264829                    -0.084019
# 641     Brock Osweiler               -0.268586                    -0.292747
#
#       qb_rushing_value_pct_home  qb_def_adjusted_value_home  \
# 1166                        0.0                   -0.190158
# 358                         0.0                    0.350701
# 516                         0.0                    0.659606
# 1154                        0.0                   -0.104279
# 641                         0.0                    0.437538
#
#       rush_def_adjusted_value_home  special_teams_value_home  \
# 1166                     -0.750509                  0.121375
# 358                       0.420085                 -0.081438
# 516                      -0.024642                  0.002125
# 1154                     -0.165206                  0.526713
# 641                      -0.322575                 -1.248456
#
#       qb_adjusted_value_away  rushing_adjusted_value_away  \
# 1166                1.112148                    -0.114530
# 358                -0.383072                    -0.351282
# 516                 0.167622                    -0.621257
# 1154                1.093633                    -0.270172
# 641                -0.943510                     0.052969
#
#       qb_rushing_value_pct_away  qb_def_adjusted_value_away  \
# 1166                        0.0                   -0.908372
# 358                         0.0                   -0.837580
# 516                         0.0                    0.158414
# 1154                        0.0                   -1.020006
# 641                         0.0                   -0.017208
#
#       rush_def_adjusted_value_away  special_teams_value_away  home_win  \
# 1166                     -0.671231                 -0.115014         1
# 358                      -0.466877                  0.125281         1
# 516                       0.178626                 -0.042608         1
# 1154                     -0.785239                 -0.209668         0
# 641                      -0.165503                 -0.400847         0
#
#                      home_team             away_team  home_score_y  \
# 1166          Cleveland Browns       Atlanta Falcons            28
# 358           Los Angeles Rams   San Francisco 49ers            27
# 516         Kansas City Chiefs  Los Angeles Chargers            33
# 1154  Washington Football Team       Atlanta Falcons            14
# 641       Jacksonville Jaguars        Houston Texans            21
#
#       away_score_y  total_score  home_moneyline  away_moneyline  home_spread  \
# 1166            16           44           215.0          -263.0          5.5
# 358              6           33          -400.0           346.0         -8.0
# 516             27           60          -275.0           244.0         -6.5
# 1154            38           52          -132.0           110.0         -2.0
# 641             24           45          -156.0           141.0         -3.0
#
#       away_spread  total_score.1 over_under_result  home_team_actual_line  \
# 1166         -5.5           49.5             under                    -12
# 358           8.0           41.0             under                    -21
# 516           6.5           45.5              over                     -6
# 1154          2.0           47.0              over                     24
# 641           3.0           42.0              over                      3
#
#       away_team_actual_line spread_cover_result  home_implied_prob  \
# 1166                     12                home           0.317460
# 358                      21                home           0.800000
# 516                       6                away           0.733333
# 1154                    -24                away           0.568966
# 641                      -3                away           0.609375
#
#       away_implied_prob game_winner  favorite_return  underdog_return  \
# 1166           0.724518        home          -100.00            215.0
# 358            0.224215        home            25.00           -100.0
# 516            0.290698        home            36.36           -100.0
# 1154           0.476190        away          -100.00            110.0
# 641            0.414938        away          -100.00            141.0
#
#       home_return  away_return  favorite_spread_return  \
# 1166       215.00       -100.0                 -100.00
# 358         25.00       -100.0                   90.91
# 516         36.36       -100.0                 -100.00
# 1154      -100.00        110.0                 -100.00
# 641       -100.00        141.0                 -100.00
#
#       underdog_spread_return  home_spread_return  away_spread_return  \
# 1166                   90.91               90.91             -100.00
# 358                  -100.00               90.91             -100.00
# 516                    90.91             -100.00               90.91
# 1154                   90.91             -100.00               90.91
# 641                    90.91             -100.00               90.91
#
#       over_return  under_return  home_cover
# 1166      -100.00         90.91           1
# 358       -100.00         90.91           1
# 516         90.91       -100.00           0
# 1154        90.91       -100.00           0
# 641         90.91       -100.00           0

# %%
# Prepare feature list

# feature_list = ['passing_value_home', 'rushing_value_home', 'pass_def_value_home', 'rush_def_value_home',
#                    'passing_value_away', 'rushing_value_away', 'pass_def_value_away', 'rush_def_value_away']

# feature_list = ['qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
#                    'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

feature_list = ['qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
                   'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away',
                'home_spread']

# %%
# Get features, labels for train, val, and test sets

# train_x = train_df_balanced[feature_list].to_numpy()
# train_y = train_df_balanced.home_win.to_numpy()

train_x = train_df_shuffled[feature_list].to_numpy()
train_y = train_df_shuffled.home_cover.to_numpy()

test_x = test_df[feature_list]
test_y = test_df.home_cover.to_numpy()

# %%
train_df_shuffled.week
# Out:
# 1166    10
# 358      8
# 516      1
# 1154     9
# 641     10
#         ..
# 1352     4
# 1553    17
# 1038     1
# 1755    14
# 1347     4
# Name: week, Length: 1770, dtype: int64

# %%
# Function to get predictions and probabilities for train, val, test sets

def get_preds(model, train_x, test_x):
    train_preds = model.predict(train_x)
    train_probs = model.predict_proba(train_x)
    
    test_preds = model.predict(test_x)
    test_probs = model.predict_proba(test_x)
    
    return train_preds, train_probs, test_preds, test_probs

# Function to get accuracy scores for train, val sets

def print_cv_results(model, train_x, train_y, cv_folds, verbose=True):
    cv_results = cross_validate(model, train_x, train_y, cv=5, return_train_score=True)
    
    train_scores = cv_results['train_score']
    val_scores = cv_results['test_score']
    
    if verbose:      
        for i, scores in enumerate(zip(train_scores, val_scores)):
            print('Fold {}, Train Accuracy: {}, Validation Accuracy: {}'.format(i+1,scores[0], scores[1]))     
        print()
        
    print('Average Training Accuracy: {}'.format(np.mean(train_scores)))
    print('Average Validation Accuracy: {}'.format(np.mean(val_scores)))
    
    return np.mean(train_scores), np.mean(val_scores)

# %%
# Simple Logistic Regression Model

lr_model = LogisticRegression()

print_cv_results(lr_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.5494350282485876, Validation Accuracy: 0.5
# Fold 2, Train Accuracy: 0.538135593220339, Validation Accuracy: 0.536723163841808
# Fold 3, Train Accuracy: 0.556497175141243, Validation Accuracy: 0.5225988700564972
# Fold 4, Train Accuracy: 0.5416666666666666, Validation Accuracy: 0.5056497175141242
# Fold 5, Train Accuracy: 0.5331920903954802, Validation Accuracy: 0.5423728813559322
#
# Average Training Accuracy: 0.5437853107344632
# Average Validation Accuracy: 0.5214689265536723
# (0.5437853107344632, 0.5214689265536723)

# %%
# Default Random Forest Classifier with no hyperparameter tuning

rf_model = RandomForestClassifier()

print_cv_results(rf_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.5084745762711864
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.4774011299435028
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.5141242937853108
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.4830508474576271
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.5480225988700564
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5062146892655367
# (1.0, 0.5062146892655367)

# %%
# Default XGBoost Model with no hyperparameter tuning

xgb_model = xgb.XGBClassifier()

print_cv_results(xgb_model, train_x, train_y, 5)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:22:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:22:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:22:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:22:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:22:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.4915254237288136
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.4887005649717514
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.5423728813559322
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5141242937853108
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.480225988700565
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5033898305084745
# (1.0, 0.5033898305084745)

# %%
# Logistic Regression, with hyperparameter tuning

def logistic_regression_tuning(train_x, train_y, verbose=True):
    
    lr_model = LogisticRegression()
    
    # Hyperparameters to tune
    penalty_list = ['none', 'l2', 'l1', 'elasticnet']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    
    params = dict(solver=solvers, penalty=penalty_list, C=c_values)
    
    clf = GridSearchCV(lr_model, params, return_train_score=True).fit(train_x, train_y)
    
    print('Best Result: {}'.format(clf.best_score_))
    print('Best Parameters: {}'.format(clf.best_params_))
    print()
    
    train_scores = clf.cv_results_['mean_train_score']
    val_scores = clf.cv_results_['mean_test_score']
    param_list = clf.cv_results_['params']
    
    if verbose:
        print('Parameter Combinations and Results:')
        for train_score, val_score, params in zip(train_scores, val_scores, param_list):
            print('Train Score: {}, Val Score: {}, Parameters: {}'.format(train_score, val_score, params))

# %%
# Can uncomment and run below to see, but hyperparameter tuning didnt change much. Can probably just roll with the 
# default logistic regression

# logistic_regression_tuning(train_x, train_y)

# %%
# Save best logistic regression model 

best_lr_model = LogisticRegression().fit(train_x, train_y)
dump(best_lr_model, 'saved_models/ps_logistic_regression_av.joblib')
# Out:
# ['saved_models/ps_logistic_regression_av.joblib']

# %%
# Save best random forest model 

best_rf_model = RandomForestClassifier().fit(train_x, train_y)
dump(best_rf_model, 'saved_models/ps_random_forest_av.joblib')
# Out:
# ['saved_models/ps_random_forest_av.joblib']

# %%
# Save best xg boost model 

best_xgb_model = xgb.XGBClassifier().fit(train_x, train_y)
dump(best_xgb_model, 'saved_models/ps_xg_boost_av.joblib')
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:25:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ['saved_models/ps_xg_boost_av.joblib']

# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import xgboost as xgb

from joblib import dump, load

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# stats = pd.read_csv('../../data/adjusted_value_models_combined_6_game_rolling.csv')
stats = pd.read_csv('../../pipeline/data/07_adjusted_value_models_aggregated.csv')
schedule = pd.read_csv('../../data/schedule_final.csv')
betting = pd.read_csv('../../data/betting_data_cleaned_with_returns.csv')
betting = betting.drop(columns=['Unnamed: 0'])

stats = stats.dropna()

# %%
stats.head()
# Out:
#     Unnamed: 0  season  week team          qb  passing_value_adjusted  \
# 64          64    2014     3  ARI  D. Stanton               -0.857878
# 65          65    2014     3  ATL     M. Ryan               -0.640304
# 66          66    2014     3  BAL   J. Flacco                0.388264
# 67          67    2014     3  BUF   E. Manuel                0.531544
# 68          68    2014     3  CAR   C. Newton                0.604152
#
#     rushing_value_adjusted  total_plays_standardized  \
# 64                0.359969                 -0.101593
# 65                0.709637                  0.279779
# 66                0.048372                  1.154692
# 67               -0.912222                 -0.370797
# 68               -0.878958                 -0.101593
#
#     total_possession_time_standardized  pass_percentage_standardized  \
# 64                           -0.628596                     -0.373010
# 65                           -0.357458                      0.832298
# 66                            0.569921                     -0.103556
# 67                           -0.198053                     -1.418698
# 68                           -0.226359                      0.373782
#
#     pass_def_value_adjusted  rush_def_value_adjusted  special_teams_value  \
# 64                -0.160789                 0.607663             1.173452
# 65                -0.824354                -0.311896             1.010280
# 66                 0.786102                -0.208942             0.137405
# 67                 0.256764                 0.606452             1.562575
# 68                 0.309284                 0.344995             1.301579
#
#             team_full
# 64  Arizona Cardinals
# 65    Atlanta Falcons
# 66   Baltimore Ravens
# 67      Buffalo Bills
# 68  Carolina Panthers

# %%
stats
# Out:
#       Unnamed: 0  season  week team          qb  passing_value_adjusted  \
# 64            64    2014     3  ARI  D. Stanton               -0.857878
# 65            65    2014     3  ATL     M. Ryan               -0.640304
# 66            66    2014     3  BAL   J. Flacco                0.388264
# 67            67    2014     3  BUF   E. Manuel                0.531544
# 68            68    2014     3  CAR   C. Newton                0.604152
# ...          ...     ...   ...  ...         ...                     ...
# 4856        4856    2022    21  CIN   J. Burrow                0.363199
# 4857        4857    2022    21   KC  P. Mahomes                0.474375
# 4858        4858    2022    21  PHI    J. Hurts                0.131127
# 4860        4860    2022    22   KC  P. Mahomes                0.474073
# 4861        4861    2022    22  PHI    J. Hurts               -0.017934
#
#       rushing_value_adjusted  total_plays_standardized  \
# 64                  0.359969                 -0.101593
# 65                  0.709637                  0.279779
# 66                  0.048372                  1.154692
# 67                 -0.912222                 -0.370797
# 68                 -0.878958                 -0.101593
# ...                      ...                       ...
# 4856                0.164351                  0.520941
# 4857                0.512161                 -0.449315
# 4858                1.616761                  0.672368
# 4860                0.212715                 -0.185719
# 4861                1.316055                  0.694802
#
#       total_possession_time_standardized  pass_percentage_standardized  \
# 64                             -0.628596                     -0.373010
# 65                             -0.357458                      0.832298
# 66                              0.569921                     -0.103556
# 67                             -0.198053                     -1.418698
# 68                             -0.226359                      0.373782
# ...                                  ...                           ...
# 4856                            0.625788                      0.405253
# 4857                           -0.141815                     -0.018159
# 4858                            0.560610                     -0.941733
# 4860                            0.080905                      0.354606
# 4861                            0.915175                     -1.357129
#
#       pass_def_value_adjusted  rush_def_value_adjusted  special_teams_value  \
# 64                  -0.160789                 0.607663             1.173452
# 65                  -0.824354                -0.311896             1.010280
# 66                   0.786102                -0.208942             0.137405
# 67                   0.256764                 0.606452             1.562575
# 68                   0.309284                 0.344995             1.301579
# ...                       ...                      ...                  ...
# 4856                -0.080416                 0.555210             0.215284
# 4857                 0.781146                -0.771093            -0.504759
# 4858                 0.742787                -0.131826             0.329906
# 4860                 0.612055                -0.822898            -0.455509
# 4861                 0.526715                -0.133076             0.091893
#
#                 team_full
# 64      Arizona Cardinals
# 65        Atlanta Falcons
# 66       Baltimore Ravens
# 67          Buffalo Bills
# 68      Carolina Panthers
# ...                   ...
# 4856   Cincinnati Bengals
# 4857   Kansas City Chiefs
# 4858  Philadelphia Eagles
# 4860   Kansas City Chiefs
# 4861  Philadelphia Eagles
#
# [4555 rows x 14 columns]

# %%
schedule.head()
# Out:
#    Unnamed: 0        date  season  week season_type                 home  \
# 0           0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1           1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2           2  2014-09-07    2014     1         REG       Houston Texans
# 3           3  2014-09-07    2014     1         REG        Chicago Bears
# 4           4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb        home_qb_abv away_qb_abv
# 0   Aaron Rodgers          R. Wilson  A. Rodgers
# 1     Andy Dalton          J. Flacco   A. Dalton
# 2  Robert Griffin     R. Fitzpatrick  R. Griffin
# 3       EJ Manuel          J. Cutler   E. Manuel
# 4     Brian Hoyer  B. Roethlisberger    B. Hoyer

# %%
print(len(stats))
print(len(schedule))
# Out:
# 4555
# 2438

# %%
nfl = schedule.copy()
nfl = nfl.merge(stats.add_suffix('_home'), how='left', left_on = ['season', 'week', 'home', 'home_qb_abv'], 
                right_on = ['season_home', 'week_home', 'team_full_home', 'qb_home'])
nfl = nfl.merge(stats.add_suffix('_away'), how='left', left_on = ['season', 'week', 'away', 'away_qb_abv'], 
                right_on = ['season_away', 'week_away', 'team_full_away', 'qb_away'])
# nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
#           'qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_rushing_value_pct_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
#           'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_rushing_value_pct_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away']]
# nfl.head()
nfl = nfl[['date', 'season', 'week', 'season_type', 'home', 'away', 'home_score', 'away_score', 'home_qb', 'away_qb',
          'passing_value_adjusted_home', 'rushing_value_adjusted_home', 'pass_def_value_adjusted_home', 'rush_def_value_adjusted_home', 'special_teams_value_home',
          'passing_value_adjusted_away', 'rushing_value_adjusted_away', 'pass_def_value_adjusted_away', 'rush_def_value_adjusted_away', 'special_teams_value_away']]
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  passing_value_adjusted_home  rushing_value_adjusted_home  \
# 0   Aaron Rodgers                          NaN                          NaN
# 1     Andy Dalton                          NaN                          NaN
# 2  Robert Griffin                          NaN                          NaN
# 3       EJ Manuel                          NaN                          NaN
# 4     Brian Hoyer                          NaN                          NaN
#
#    pass_def_value_adjusted_home  rush_def_value_adjusted_home  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    special_teams_value_home  passing_value_adjusted_away  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    rushing_value_adjusted_away  pass_def_value_adjusted_away  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    rush_def_value_adjusted_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
print(len(nfl))
# Out:
# 2438

# %%
betting.head()
# Out:
#          date            home_team            away_team  home_score  \
# 0  2023-02-12  Philadelphia Eagles   Kansas City Chiefs          35
# 1  2023-01-29   Kansas City Chiefs   Cincinnati Bengals          23
# 2  2023-01-29  Philadelphia Eagles  San Francisco 49ers          31
# 3  2023-01-22  San Francisco 49ers       Dallas Cowboys          19
# 4  2023-01-22        Buffalo Bills   Cincinnati Bengals          10
#
#    away_score  total_score_actual  home_moneyline  away_moneyline  \
# 0          38                  73          -120.0           100.0
# 1          20                  43          -130.0           110.0
# 2           7                  38          -155.0           135.0
# 3          12                  31          -200.0           170.0
# 4          27                  37          -260.0           215.0
#
#    home_spread  away_spread  total_score_line over_under_result  \
# 0         -1.0          1.0              51.5              over
# 1         -2.0          2.0              48.5             under
# 2         -3.0          3.0              45.0             under
# 3         -3.5          3.5              46.5             under
# 4         -6.0          6.0              48.5             under
#
#    home_team_actual_line  away_team_actual_line spread_cover_result  \
# 0                      3                     -3                away
# 1                     -3                      3                home
# 2                    -24                     24                home
# 3                     -7                      7                home
# 4                     17                    -17                away
#
#    home_implied_prob  away_implied_prob game_winner  favorite_return  \
# 0           0.545455           0.500000        away          -100.00
# 1           0.565217           0.476190        home            76.92
# 2           0.607843           0.425532        home            64.52
# 3           0.666667           0.370370        home            50.00
# 4           0.722222           0.317460        away          -100.00
#
#    underdog_return  home_return  away_return  favorite_spread_return  \
# 0            100.0      -100.00        100.0                 -100.00
# 1           -100.0        76.92       -100.0                   90.91
# 2           -100.0        64.52       -100.0                   90.91
# 3           -100.0        50.00       -100.0                   90.91
# 4            215.0      -100.00        215.0                 -100.00
#
#    underdog_spread_return  home_spread_return  away_spread_return  \
# 0                   90.91             -100.00               90.91
# 1                 -100.00               90.91             -100.00
# 2                 -100.00               90.91             -100.00
# 3                 -100.00               90.91             -100.00
# 4                   90.91             -100.00               90.91
#
#    over_return  under_return
# 0        90.91       -100.00
# 1      -100.00         90.91
# 2      -100.00         90.91
# 3      -100.00         90.91
# 4      -100.00         90.91

# %%
nfl.head()
# Out:
#          date  season  week season_type                 home  \
# 0  2014-09-04    2014     1         REG     Seattle Seahawks
# 1  2014-09-07    2014     1         REG     Baltimore Ravens
# 2  2014-09-07    2014     1         REG       Houston Texans
# 3  2014-09-07    2014     1         REG        Chicago Bears
# 4  2014-09-07    2014     1         REG  Pittsburgh Steelers
#
#                        away  home_score  away_score             home_qb  \
# 0         Green Bay Packers          36          16      Russell Wilson
# 1        Cincinnati Bengals          16          23          Joe Flacco
# 2  Washington Football Team          17           6    Ryan Fitzpatrick
# 3             Buffalo Bills          20          23          Jay Cutler
# 4          Cleveland Browns          30          27  Ben Roethlisberger
#
#           away_qb  passing_value_adjusted_home  rushing_value_adjusted_home  \
# 0   Aaron Rodgers                          NaN                          NaN
# 1     Andy Dalton                          NaN                          NaN
# 2  Robert Griffin                          NaN                          NaN
# 3       EJ Manuel                          NaN                          NaN
# 4     Brian Hoyer                          NaN                          NaN
#
#    pass_def_value_adjusted_home  rush_def_value_adjusted_home  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    special_teams_value_home  passing_value_adjusted_away  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    rushing_value_adjusted_away  pass_def_value_adjusted_away  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    rush_def_value_adjusted_away  special_teams_value_away
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN

# %%
# Join in betting data to get point spreads

nfl_cleaned_with_betting = nfl.merge(betting, left_on=['date', 'home', 'away'],
                                            right_on=['date', 'home_team','away_team'])

# %%
# Remove any pushes, add binary label for home cover

nfl_cleaned_with_betting_final = nfl_cleaned_with_betting.copy()
nfl_cleaned_with_betting_final['home_cover'] = nfl_cleaned_with_betting_final.apply(
    lambda x: 1 if x.spread_cover_result == 'home' else 0, axis=1)
nfl_cleaned_with_betting_final = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.spread_cover_result != 'push']
nfl_cleaned_with_betting_final
# Out:
#             date  season  week season_type                 home  \
# 0     2014-09-04    2014     1         REG     Seattle Seahawks
# 1     2014-09-07    2014     1         REG     Baltimore Ravens
# 2     2014-09-07    2014     1         REG       Houston Texans
# 3     2014-09-07    2014     1         REG        Chicago Bears
# 4     2014-09-07    2014     1         REG  Pittsburgh Steelers
# ...          ...     ...   ...         ...                  ...
# 2402  2023-01-22    2022    20        POST        Buffalo Bills
# 2403  2023-01-22    2022    20        POST  San Francisco 49ers
# 2404  2023-01-29    2022    21        POST  Philadelphia Eagles
# 2405  2023-01-29    2022    21        POST   Kansas City Chiefs
# 2406  2023-02-12    2022    22        POST  Philadelphia Eagles
#
#                           away  home_score_x  away_score_x  \
# 0            Green Bay Packers            36            16
# 1           Cincinnati Bengals            16            23
# 2     Washington Football Team            17             6
# 3                Buffalo Bills            20            23
# 4             Cleveland Browns            30            27
# ...                        ...           ...           ...
# 2402        Cincinnati Bengals            10            27
# 2403            Dallas Cowboys            19            12
# 2404       San Francisco 49ers            31             7
# 2405        Cincinnati Bengals            23            20
# 2406        Kansas City Chiefs            35            38
#
#                  home_qb          away_qb  passing_value_adjusted_home  \
# 0         Russell Wilson    Aaron Rodgers                          NaN
# 1             Joe Flacco      Andy Dalton                          NaN
# 2       Ryan Fitzpatrick   Robert Griffin                          NaN
# 3             Jay Cutler        EJ Manuel                          NaN
# 4     Ben Roethlisberger      Brian Hoyer                          NaN
# ...                  ...              ...                          ...
# 2402          Josh Allen       Joe Burrow                    -0.151187
# 2403         Brock Purdy     Dak Prescott                     1.271880
# 2404         Jalen Hurts      Brock Purdy                     0.131127
# 2405     Patrick Mahomes       Joe Burrow                     0.474375
# 2406         Jalen Hurts  Patrick Mahomes                    -0.017934
#
#       rushing_value_adjusted_home  pass_def_value_adjusted_home  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 2402                     0.650933                      0.483813
# 2403                     0.634522                      0.303955
# 2404                     1.616761                      0.742787
# 2405                     0.512161                      0.781146
# 2406                     1.316055                      0.526715
#
#       rush_def_value_adjusted_home  special_teams_value_home  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 2402                      0.589479                 -0.215688
# 2403                      0.348498                  0.331705
# 2404                     -0.131826                  0.329906
# 2405                     -0.771093                 -0.504759
# 2406                     -0.133076                  0.091893
#
#       passing_value_adjusted_away  rushing_value_adjusted_away  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2402                     0.002339                    -0.152032
# 2403                     0.563132                    -0.743069
# 2404                          NaN                          NaN
# 2405                     0.363199                     0.164351
# 2406                     0.474073                     0.212715
#
#       pass_def_value_adjusted_away  rush_def_value_adjusted_away  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2402                     -0.140611                      1.049708
# 2403                     -0.104332                      0.297954
# 2404                           NaN                           NaN
# 2405                     -0.080416                      0.555210
# 2406                      0.612055                     -0.822898
#
#       special_teams_value_away            home_team                 away_team  \
# 0                          NaN     Seattle Seahawks         Green Bay Packers
# 1                          NaN     Baltimore Ravens        Cincinnati Bengals
# 2                          NaN       Houston Texans  Washington Football Team
# 3                          NaN        Chicago Bears             Buffalo Bills
# 4                          NaN  Pittsburgh Steelers          Cleveland Browns
# ...                        ...                  ...                       ...
# 2402                  0.204819        Buffalo Bills        Cincinnati Bengals
# 2403                 -0.500316  San Francisco 49ers            Dallas Cowboys
# 2404                       NaN  Philadelphia Eagles       San Francisco 49ers
# 2405                  0.215284   Kansas City Chiefs        Cincinnati Bengals
# 2406                 -0.455509  Philadelphia Eagles        Kansas City Chiefs
#
#       home_score_y  away_score_y  total_score_actual  home_moneyline  \
# 0               36            16                  52          -230.0
# 1               16            23                  39          -113.0
# 2               17             6                  23          -177.0
# 3               20            23                  43          -270.0
# 4               30            27                  57          -242.0
# ...            ...           ...                 ...             ...
# 2402            10            27                  37          -260.0
# 2403            19            12                  31          -200.0
# 2404            31             7                  38          -155.0
# 2405            23            20                  43          -130.0
# 2406            35            38                  73          -120.0
#
#       away_moneyline  home_spread  away_spread  total_score_line  \
# 0              205.0         -4.5          4.5              46.5
# 1              102.0         -1.0          1.0              43.5
# 2              159.0         -3.0          3.0              43.5
# 3              239.0         -7.0          7.0              47.0
# 4              216.0         -5.5          5.5              41.5
# ...              ...          ...          ...               ...
# 2402           215.0         -6.0          6.0              48.5
# 2403           170.0         -3.5          3.5              46.5
# 2404           135.0         -3.0          3.0              45.0
# 2405           110.0         -2.0          2.0              48.5
# 2406           100.0         -1.0          1.0              51.5
#
#      over_under_result  home_team_actual_line  away_team_actual_line  \
# 0                 over                    -20                     20
# 1                under                      7                     -7
# 2                under                    -11                     11
# 3                under                      3                     -3
# 4                 over                     -3                      3
# ...                ...                    ...                    ...
# 2402             under                     17                    -17
# 2403             under                     -7                      7
# 2404             under                    -24                     24
# 2405             under                     -3                      3
# 2406              over                      3                     -3
#
#      spread_cover_result  home_implied_prob  away_implied_prob game_winner  \
# 0                   home           0.696970           0.327869        home
# 1                   away           0.530516           0.495050        away
# 2                   home           0.638989           0.386100        home
# 3                   away           0.729730           0.294985        away
# 4                   away           0.707602           0.316456        home
# ...                  ...                ...                ...         ...
# 2402                away           0.722222           0.317460        away
# 2403                home           0.666667           0.370370        home
# 2404                home           0.607843           0.425532        home
# 2405                home           0.565217           0.476190        home
# 2406                away           0.545455           0.500000        away
#
#       favorite_return  underdog_return  home_return  away_return  \
# 0               43.48           -100.0        43.48       -100.0
# 1             -100.00            102.0      -100.00        102.0
# 2               56.50           -100.0        56.50       -100.0
# 3             -100.00            239.0      -100.00        239.0
# 4               41.32           -100.0        41.32       -100.0
# ...               ...              ...          ...          ...
# 2402          -100.00            215.0      -100.00        215.0
# 2403            50.00           -100.0        50.00       -100.0
# 2404            64.52           -100.0        64.52       -100.0
# 2405            76.92           -100.0        76.92       -100.0
# 2406          -100.00            100.0      -100.00        100.0
#
#       favorite_spread_return  underdog_spread_return  home_spread_return  \
# 0                      90.91                 -100.00               90.91
# 1                    -100.00                   90.91             -100.00
# 2                      90.91                 -100.00               90.91
# 3                    -100.00                   90.91             -100.00
# 4                    -100.00                   90.91             -100.00
# ...                      ...                     ...                 ...
# 2402                 -100.00                   90.91             -100.00
# 2403                   90.91                 -100.00               90.91
# 2404                   90.91                 -100.00               90.91
# 2405                   90.91                 -100.00               90.91
# 2406                 -100.00                   90.91             -100.00
#
#       away_spread_return  over_return  under_return  home_cover
# 0                -100.00        90.91       -100.00           1
# 1                  90.91      -100.00         90.91           0
# 2                -100.00      -100.00         90.91           1
# 3                  90.91      -100.00         90.91           0
# 4                  90.91        90.91       -100.00           0
# ...                  ...          ...           ...         ...
# 2402               90.91      -100.00         90.91           0
# 2403             -100.00      -100.00         90.91           1
# 2404             -100.00      -100.00         90.91           1
# 2405             -100.00      -100.00         90.91           1
# 2406               90.91        90.91       -100.00           0
#
# [2338 rows x 48 columns]

# %%
nfl_cleaned_with_betting_final.to_csv('../../data/adjusted_stats_point_spread_modeling_base_df.csv')

# %%
# Split data into train and test sets, cross validation for hyperparameter tuning

train_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season <= 2021]
train_df = train_df.dropna()

test_df = nfl_cleaned_with_betting_final[nfl_cleaned_with_betting_final.season == 2022]
test_df = test_df.dropna()

# %%
# NOTE
# Dont know if i need to balance this data set at all, point spread betting should be pretty 50/50


# Balance training data set

# Note: Can't balance data set and then do Cross Validation due to data leakage

# Fully balancing the data set doesnt work as well for prediction as the unbalanced, likely because the 
# home team does actually have an important advantage. But, maybe balancing the data set slightly will help

# balance_n = int(np.round((sum(train_df.home_win==1) - sum(train_df.home_win==0))/1.5))
# to_add = train_df[train_df.home_win==0].sample(n=balance_n, random_state=57, replace=True)

# train_df_balanced = pd.concat([train_df, to_add])
# train_df_balanced

# %%
# Shuffle training set before cross validation

train_df_shuffled = train_df.sample(frac=1, random_state=42)
train_df_shuffled.head()
# Out:
#             date  season  week season_type                  home  \
# 109   2014-10-26    2014     8         REG  New England Patriots
# 1130  2018-10-21    2018     7         REG         Chicago Bears
# 2063  2021-12-23    2021    16         REG      Tennessee Titans
# 2036  2021-12-12    2021    14         REG     Carolina Panthers
# 969   2017-12-10    2017    14         REG        Denver Broncos
#
#                       away  home_score_x  away_score_x            home_qb  \
# 109          Chicago Bears            51            23          Tom Brady
# 1130  New England Patriots            31            38  Mitchell Trubisky
# 2063   San Francisco 49ers            20            17     Ryan Tannehill
# 2036       Atlanta Falcons            21            29         Cam Newton
# 969          New York Jets            23             0     Trevor Siemian
#
#               away_qb  passing_value_adjusted_home  \
# 109        Jay Cutler                     0.545729
# 1130        Tom Brady                     0.733866
# 2063  Jimmy Garoppolo                    -0.866203
# 2036        Matt Ryan                    -0.859637
# 969       Josh McCown                    -1.076691
#
#       rushing_value_adjusted_home  pass_def_value_adjusted_home  \
# 109                     -0.229171                     -0.303151
# 1130                     0.223499                      0.349366
# 2063                     0.126611                      0.376509
# 2036                    -0.263685                      0.061029
# 969                     -0.465095                      0.015986
#
#       rush_def_value_adjusted_home  special_teams_value_home  \
# 109                      -0.428371                  0.468593
# 1130                      0.309202                 -0.143926
# 2063                      0.392349                 -0.495853
# 2036                      0.370571                 -0.222273
# 969                       0.582976                 -0.990004
#
#       passing_value_adjusted_away  rushing_value_adjusted_away  \
# 109                     -0.325933                     0.180907
# 1130                     0.175294                     0.603860
# 2063                     0.682361                     0.640189
# 2036                    -0.536184                    -0.187227
# 969                      0.375078                    -0.079633
#
#       pass_def_value_adjusted_away  rush_def_value_adjusted_away  \
# 109                      -0.407935                     -0.348726
# 1130                     -0.025431                      0.068549
# 2063                      0.131382                      0.480717
# 2036                     -0.367921                      0.267332
# 969                      -0.395611                      0.119256
#
#       special_teams_value_away             home_team             away_team  \
# 109                  -0.089622  New England Patriots         Chicago Bears
# 1130                 -0.339206         Chicago Bears  New England Patriots
# 2063                 -0.813730      Tennessee Titans   San Francisco 49ers
# 2036                 -0.416394     Carolina Panthers       Atlanta Falcons
# 969                  -0.482455        Denver Broncos         New York Jets
#
#       home_score_y  away_score_y  total_score_actual  home_moneyline  \
# 109             51            23                  74          -260.0
# 1130            31            38                  69           105.0
# 2063            20            17                  37           150.0
# 2036            21            29                  50          -147.0
# 969             23             0                  23          -106.0
#
#       away_moneyline  home_spread  away_spread  total_score_line  \
# 109            231.0         -6.0          6.0              51.5
# 1130          -125.0          1.5         -1.5              48.5
# 2063          -172.0          3.5         -3.5              45.5
# 2036           125.0         -2.5          2.5              41.5
# 969           -104.0          1.0         -1.0              40.5
#
#      over_under_result  home_team_actual_line  away_team_actual_line  \
# 109               over                    -28                     28
# 1130              over                      7                     -7
# 2063             under                     -3                      3
# 2036              over                      8                     -8
# 969              under                    -23                     23
#
#      spread_cover_result  home_implied_prob  away_implied_prob game_winner  \
# 109                 home           0.722222           0.302115        home
# 1130                away           0.487805           0.555556        away
# 2063                home           0.400000           0.632353        home
# 2036                away           0.595142           0.444444        away
# 969                 home           0.514563           0.509804        home
#
#       favorite_return  underdog_return  home_return  away_return  \
# 109             38.46           -100.0        38.46       -100.0
# 1130            80.00           -100.0      -100.00         80.0
# 2063          -100.00            150.0       150.00       -100.0
# 2036          -100.00            125.0      -100.00        125.0
# 969             94.34           -100.0        94.34       -100.0
#
#       favorite_spread_return  underdog_spread_return  home_spread_return  \
# 109                    90.91                 -100.00               90.91
# 1130                   90.91                 -100.00             -100.00
# 2063                 -100.00                   90.91               90.91
# 2036                 -100.00                   90.91             -100.00
# 969                  -100.00                   90.91               90.91
#
#       away_spread_return  over_return  under_return  home_cover
# 109              -100.00        90.91       -100.00           1
# 1130               90.91        90.91       -100.00           0
# 2063             -100.00      -100.00         90.91           1
# 2036               90.91        90.91       -100.00           0
# 969              -100.00      -100.00         90.91           1

# %%
# Prepare feature list

# feature_list = ['passing_value_home', 'rushing_value_home', 'pass_def_value_home', 'rush_def_value_home',
#                    'passing_value_away', 'rushing_value_away', 'pass_def_value_away', 'rush_def_value_away']

# feature_list = ['qb_value_home', 'passing_value_home', 'rushing_value_home', 'qb_def_value_home', 'pass_def_value_home', 'rush_def_value_home', 'special_teams_value_home',
#                    'qb_value_away', 'passing_value_away', 'rushing_value_away', 'qb_def_value_away', 'pass_def_value_away', 'rush_def_value_away', 'special_teams_value_away']

# feature_list = ['qb_adjusted_value_home', 'rushing_adjusted_value_home', 'qb_def_adjusted_value_home', 'rush_def_adjusted_value_home', 'special_teams_value_home',
#                    'qb_adjusted_value_away', 'rushing_adjusted_value_away', 'qb_def_adjusted_value_away', 'rush_def_adjusted_value_away', 'special_teams_value_away',
#                 'home_spread']
feature_list =['passing_value_adjusted_home', 'rushing_value_adjusted_home', 'pass_def_value_adjusted_home', 'rush_def_value_adjusted_home', 'special_teams_value_home',
          'passing_value_adjusted_away', 'rushing_value_adjusted_away', 'pass_def_value_adjusted_away', 'rush_def_value_adjusted_away', 'special_teams_value_away',
              'home_spread']

# %%
# Get features, labels for train, val, and test sets

# train_x = train_df_balanced[feature_list].to_numpy()
# train_y = train_df_balanced.home_win.to_numpy()

train_x = train_df_shuffled[feature_list].to_numpy()
train_y = train_df_shuffled.home_cover.to_numpy()

test_x = test_df[feature_list]
test_y = test_df.home_cover.to_numpy()

# %%
train_df_shuffled.week
# Out:
# 109      8
# 1130     7
# 2063    16
# 2036    14
# 969     14
#         ..
# 1353     4
# 1551    17
# 1036     1
# 1757    13
# 1349     4
# Name: week, Length: 1776, dtype: int64

# %%
# Function to get predictions and probabilities for train, val, test sets

def get_preds(model, train_x, test_x):
    train_preds = model.predict(train_x)
    train_probs = model.predict_proba(train_x)
    
    test_preds = model.predict(test_x)
    test_probs = model.predict_proba(test_x)
    
    return train_preds, train_probs, test_preds, test_probs

# Function to get accuracy scores for train, val sets

def print_cv_results(model, train_x, train_y, cv_folds, verbose=True):
    cv_results = cross_validate(model, train_x, train_y, cv=5, return_train_score=True)
    
    train_scores = cv_results['train_score']
    val_scores = cv_results['test_score']
    
    if verbose:      
        for i, scores in enumerate(zip(train_scores, val_scores)):
            print('Fold {}, Train Accuracy: {}, Validation Accuracy: {}'.format(i+1,scores[0], scores[1]))     
        print()
        
    print('Average Training Accuracy: {}'.format(np.mean(train_scores)))
    print('Average Validation Accuracy: {}'.format(np.mean(val_scores)))
    
    return np.mean(train_scores), np.mean(val_scores)

# %%
# Simple Logistic Regression Model

lr_model = LogisticRegression()

print_cv_results(lr_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 0.55, Validation Accuracy: 0.5308988764044944
# Fold 2, Train Accuracy: 0.541871921182266, Validation Accuracy: 0.523943661971831
# Fold 3, Train Accuracy: 0.5453905700211119, Validation Accuracy: 0.5154929577464789
# Fold 4, Train Accuracy: 0.5411681914144968, Validation Accuracy: 0.5098591549295775
# Fold 5, Train Accuracy: 0.553835327234342, Validation Accuracy: 0.523943661971831
#
# Average Training Accuracy: 0.5464532019704433
# Average Validation Accuracy: 0.5208276626048425
# (0.5464532019704433, 0.5208276626048425)

# %%
# Default Random Forest Classifier with no hyperparameter tuning

rf_model = RandomForestClassifier()

print_cv_results(rf_model, train_x, train_y, 5)
# Out:
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.4747191011235955
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.5774647887323944
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.5183098591549296
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5267605633802817
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.5211267605633803
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5236762145909163
# (1.0, 0.5236762145909163)

# %%
# Default XGBoost Model with no hyperparameter tuning

xgb_model = xgb.XGBClassifier()

print_cv_results(xgb_model, train_x, train_y, 5)
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fold 1, Train Accuracy: 1.0, Validation Accuracy: 0.4747191011235955
# Fold 2, Train Accuracy: 1.0, Validation Accuracy: 0.4732394366197183
# Fold 3, Train Accuracy: 1.0, Validation Accuracy: 0.532394366197183
# Fold 4, Train Accuracy: 1.0, Validation Accuracy: 0.5295774647887324
# Fold 5, Train Accuracy: 1.0, Validation Accuracy: 0.5380281690140845
#
# Average Training Accuracy: 1.0
# Average Validation Accuracy: 0.5095917075486627
# (1.0, 0.5095917075486627)

# %%
# Logistic Regression, with hyperparameter tuning

def logistic_regression_tuning(train_x, train_y, verbose=True):
    
    lr_model = LogisticRegression()
    
    # Hyperparameters to tune
    penalty_list = ['none', 'l2', 'l1', 'elasticnet']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    
    params = dict(solver=solvers, penalty=penalty_list, C=c_values)
    
    clf = GridSearchCV(lr_model, params, return_train_score=True).fit(train_x, train_y)
    
    print('Best Result: {}'.format(clf.best_score_))
    print('Best Parameters: {}'.format(clf.best_params_))
    print()
    
    train_scores = clf.cv_results_['mean_train_score']
    val_scores = clf.cv_results_['mean_test_score']
    param_list = clf.cv_results_['params']
    
    if verbose:
        print('Parameter Combinations and Results:')
        for train_score, val_score, params in zip(train_scores, val_scores, param_list):
            print('Train Score: {}, Val Score: {}, Parameters: {}'.format(train_score, val_score, params))

# %%
# Can uncomment and run below to see, but hyperparameter tuning didnt change much. Can probably just roll with the 
# default logistic regression

# logistic_regression_tuning(train_x, train_y)

# %%
# Save best logistic regression model 

best_lr_model = LogisticRegression().fit(train_x, train_y)
dump(best_lr_model, 'saved_models/ps_logistic_regression_av.joblib')
# Out:
# ['saved_models/ps_logistic_regression_av.joblib']

# %%
# Save best random forest model 

best_rf_model = RandomForestClassifier().fit(train_x, train_y)
dump(best_rf_model, 'saved_models/ps_random_forest_av.joblib')
# Out:
# ['saved_models/ps_random_forest_av.joblib']

# %%
# Save best xg boost model 

best_xgb_model = xgb.XGBClassifier().fit(train_x, train_y)
dump(best_xgb_model, 'saved_models/ps_xg_boost_av.joblib')
# Out:
# C:\Users\imacd_0odruq3\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:31:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ['saved_models/ps_xg_boost_av.joblib']

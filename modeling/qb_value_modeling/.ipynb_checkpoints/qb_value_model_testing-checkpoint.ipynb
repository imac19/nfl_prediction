# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from joblib import dump, load

pd.set_option('display.max_columns', None)

# %%
qb = pd.read_csv('qb_value_data/qb.csv')
qb = qb.drop(columns = ['Unnamed: 0'])

# %%
# Import selected model for testing

model_name = 'logistic_regression'
model_filepath = 'qb_value_saved_models/' + model_name + '.joblib'

clf = load(model_filepath)

# %%
# Add model predictions to the data frame

from qb_value_helper_functions import get_features, get_label

qb_features = get_features(qb)
qb_win_pred = clf.predict(qb_features)
qb_win_probs = clf.predict_proba(qb_features)[:,1]

qb['qb_win_pred'] = qb_win_pred
qb['qb_value'] = qb_win_probs

# %%
# See descriptive stats for qb value

qb.qb_value.describe()
# Out:
# count    4745.000000
# mean        0.491453
# std         0.283024
# min         0.002421
# 25%         0.238217
# 50%         0.503927
# 75%         0.741187
# max         0.990888
# Name: qb_value, dtype: float64

# %%
# See what factors were most important to qb value

feature_importance = qb_features.columns.to_frame().reset_index(drop=True)
feature_importance.columns = ['feature']
feature_importance['mean'] = qb_features.mean().to_numpy()
feature_importance['std'] = qb_features.std().to_numpy()
feature_importance['importance'] = clf.coef_[0]
feature_importance['importance'] = feature_importance['importance'] * feature_importance['std']
feature_importance['abs_importance'] = abs(feature_importance.importance)
feature_importance_sorted = feature_importance.sort_values(by='abs_importance', ascending=False)
feature_importance_sorted
# Out:
#                     feature        mean        std  importance  abs_importance
# 3               passing_epa    1.080985  10.741704    1.218447        1.218447
# 0       total_pass_attempts   33.408008   9.374471   -0.718952        0.718952
# 2               completions   21.278398   6.613314    0.295348        0.295348
# 11  interceptions_thrown_qb    0.775132   0.907746   -0.211929        0.211929
# 1       total_passing_yards  240.248894  81.137522   -0.180378        0.180378
# 4                  pass_tds    1.502002   1.169835    0.177842        0.177842
# 7            qb_rushing_epa    0.626903   2.368890    0.128344        0.128344
# 10          lost_fumbles_qb    0.338672   0.581247   -0.096125        0.096125
# 8               qb_rush_tds    0.141623   0.386544    0.091616        0.091616
# 6             qb_rush_yards   15.003372  19.891675   -0.067750        0.067750
# 5                  avg_cpoe    0.221790   9.018794    0.065363        0.065363
# 9                fumbles_qb    0.762908   0.896201   -0.008718        0.008718

# %%
feature_importance_sorted.plot.bar(x='feature', y='importance')

feature_importance_sorted.plot.bar(x='feature', y='abs_importance')

# %%
# See where the algorithm went wrong

incorrect = qb[qb.qb_win != qb_win_pred]
pred_win_but_loss = len(incorrect[incorrect.qb_win_pred==1])
pred_loss_but_win = len(incorrect[incorrect.qb_win_pred==0])
total = len(incorrect)

print('Predicted Win, Actual Loss: {}, {}%'.format(pred_win_but_loss, np.round(pred_win_but_loss*100/total, 2)))
print('Predicted Loss, Actual Win: {}, {}%'.format(pred_loss_but_win, np.round(pred_loss_but_win*100/total, 2)))
# Out:
# Predicted Win, Actual Loss: 647, 52.64%
# Predicted Loss, Actual Win: 582, 47.36%

# %%
incorrect.head(10)
# Out:
#     season  week team opponent  score  opponent_score            qb  \
# 7     2014     1  CLE      PIT     27              30      B. Hoyer
# 20    2014     1  MIA       NE     33              20  R. Tannehill
# 23    2014     1   NO      ATL     34              37      D. Brees
# 25    2014     1  NYJ       LV     19              14      G. Smith
# 26    2014     1  PHI      JAX     34              17      N. Foles
# 33    2014     2  ARI      NYG     25              14    D. Stanton
# 40    2014     2  CLE       NO     26              24      B. Hoyer
# 46    2014     2  IND      PHI     27              30       A. Luck
# 48    2014     2   KC      DEN     17              24      A. Smith
# 57    2014     2  NYJ       GB     24              31      G. Smith
#
#     total_pass_attempts  total_passing_yards  completions  passing_epa  \
# 7                    30                222.0         18.0     4.287779
# 20                   32                178.0         18.0    -5.483662
# 23                   42                333.0         29.0     9.202585
# 25                   29                221.0         23.0    -1.407630
# 26                   44                322.0         27.0   -11.213566
# 33                   29                167.0         14.0    -3.911987
# 40                   40                204.0         24.0     1.381880
# 46                   34                172.0         20.0     4.730769
# 48                   42                255.0         26.0    11.218429
# 57                   32                176.0         16.0     0.995191
#
#     pass_tds  air_yards  yards_after_catch    air_epa    yac_epa   avg_cpoe  \
# 7        1.0      154.0               68.0  11.608848   6.760200  -3.234241
# 20       2.0       76.0              102.0   1.586622   8.987242  -5.776945
# 23       1.0      141.0              192.0   1.711281  22.435846  -0.291977
# 25       1.0       73.0              148.0  -7.200376  19.153248  11.702978
# 26       2.0      183.0              139.0   1.699987  19.193558  -1.086598
# 33       0.0      117.0               50.0   6.287091   5.216219  -7.342040
# 40       1.0      110.0               94.0  -1.045171  13.762691  -1.256537
# 46       3.0       76.0               96.0  -7.295096  26.469380  -4.899310
# 48       0.0      166.0               89.0  10.566546  13.780125   0.225186
# 57       1.0       83.0               93.0   3.077199  18.345318  -9.855559
#
#        qb_epa  qb_rush_yards  qb_rushing_epa  qb_rush_tds  sacks_taken_qb  \
# 7    2.151025           -2.0       -2.136754          0.0             3.0
# 20  -1.597986            0.0       -0.908166          0.0             1.0
# 23  13.906331            2.0       -0.387024          0.0             0.0
# 25  -3.449841           40.0       -2.042210          0.0             2.0
# 26 -11.213566            0.0        0.000000          0.0             5.0
# 33  -3.911987            0.0        0.000000          0.0             4.0
# 40   1.381880            0.0        0.000000          0.0             1.0
# 46   4.474362           21.0       -0.256407          0.0             0.0
# 48  12.394057           38.0        1.175629          0.0             2.0
# 57   6.560496           64.0        5.565304          1.0             1.0
#
#     qb_hits_taken_qb  fumbles_qb  lost_fumbles_qb  interceptions_thrown_qb  \
# 7                4.0         0.0              0.0                      0.0
# 20               3.0         2.0              1.0                      1.0
# 23               0.0         1.0              1.0                      1.0
# 25               1.0         2.0              1.0                      1.0
# 26               4.0         3.0              2.0                      1.0
# 33              10.0         0.0              0.0                      0.0
# 40               6.0         0.0              0.0                      0.0
# 46               3.0         0.0              0.0                      1.0
# 48               5.0         1.0              0.0                      0.0
# 57               5.0         0.0              0.0                      1.0
#
#     qb_win  qb_win_pred  qb_value
# 7        0            1  0.609458
# 20       1            0  0.280118
# 23       0            1  0.505158
# 25       1            0  0.414168
# 26       1            0  0.074176
# 33       1            0  0.368748
# 40       1            0  0.445159
# 46       0            1  0.615629
# 48       0            1  0.622773
# 57       0            1  0.519781

# %%
# Look at some of the best qbs by qb value

qb_avg_value = qb.groupby(by='qb').qb_value.agg(['mean', 'min', 'max', 'count'])
qb_avg_value.sort_values(by='mean', ascending=False)
# Out:
#                   mean       min       max  count
# qb
# A. Tanney     0.772393  0.772393  0.772393      1
# P. Mahomes    0.652725  0.032974  0.978768     83
# B. Zappe      0.642897  0.456419  0.801528      4
# T. Romo       0.641880  0.064912  0.982590     21
# J. Garoppolo  0.618422  0.018998  0.959035     61
# ...                ...       ...       ...    ...
# S. Tolzien    0.085178  0.038032  0.132325      2
# W. Grier      0.041304  0.041304  0.041304      1
# I. Book       0.038208  0.038208  0.038208      1
# C. Ponder     0.033205  0.033205  0.033205      1
# B. DiNucci    0.023014  0.023014  0.023014      1
#
# [152 rows x 4 columns]

# %%
# Look at those that have more than 10 games played 

qb_avg_value_many_games = qb_avg_value.reset_index()
qb_avg_value_many_games.columns = ['qb', 'mean', 'min', 'max', 'cnt']
qb_avg_value_many_games[qb_avg_value_many_games.cnt > 10].sort_values(by='mean', ascending=False).head(50)
# Out:
#                     qb      mean       min       max  cnt
# 116         P. Mahomes  0.652725  0.032974  0.978768   83
# 143            T. Romo  0.641880  0.064912  0.982590   21
# 69        J. Garoppolo  0.618422  0.018998  0.959035   61
# 146      T. Tagovailoa  0.618060  0.010122  0.925040   29
# 39            D. Brees  0.591950  0.020186  0.983292  107
# 4           A. Rodgers  0.587093  0.032489  0.988947  139
# 51           D. Watson  0.584073  0.061761  0.986141   57
# 91          L. Jackson  0.577479  0.011901  0.990888   61
# 136           T. Brady  0.576288  0.021216  0.987878  156
# 127          R. Wilson  0.572027  0.015838  0.981484  144
# 61           J. Burrow  0.571617  0.014528  0.966416   38
# 72            J. Hurts  0.561404  0.055939  0.913981   30
# 49         D. Prescott  0.557723  0.016521  0.979573   92
# 147          T. Taylor  0.554691  0.023750  0.957602   54
# 59            J. Allen  0.554638  0.032336  0.979636   75
# 126       R. Tannehill  0.551434  0.025028  0.981932  113
# 101           M. Moore  0.539392  0.007917  0.939823   11
# 28            C. McCoy  0.537672  0.041673  0.901694   15
# 137     T. Bridgewater  0.536403  0.018667  0.977756   68
# 118          P. Rivers  0.533585  0.011145  0.977695  115
# 84          K. Cousins  0.527170  0.014124  0.971546  127
# 5             A. Smith  0.525714  0.069852  0.956329   83
# 27          C. Kessler  0.520312  0.135108  0.882250   13
# 99          M. Mariota  0.519831  0.041593  0.977188   74
# 103            M. Ryan  0.518097  0.006721  0.976126  140
# 71          J. Herbert  0.517897  0.005690  0.948442   41
# 57            G. Smith  0.514346  0.105550  0.958782   29
# 55          G. Minshew  0.510715  0.114617  0.924029   11
# 16   B. Roethlisberger  0.508546  0.007707  0.986984  114
# 30           C. Palmer  0.507565  0.015374  0.931602   45
# 121     R. Fitzpatrick  0.504822  0.002421  0.981458   76
# 102         M. Rudolph  0.500797  0.006311  0.859283   11
# 106        M. Stafford  0.499656  0.005538  0.978845  133
# 81          J. Winston  0.497344  0.008908  0.971376   83
# 87           K. Murray  0.484731  0.022898  0.936601   55
# 70             J. Goff  0.481247  0.004080  0.974248   97
# 0            A. Dalton  0.478939  0.010318  0.969454  107
# 29           C. Newton  0.476511  0.033569  0.947599  102
# 83            K. Allen  0.474647  0.008466  0.902151   19
# 40             D. Carr  0.472690  0.014619  0.940715  136
# 112         N. Mullens  0.471925  0.016541  0.948605   19
# 13         B. Mayfield  0.471285  0.016769  0.968399   68
# 119          P. Walker  0.469355  0.165203  0.823850   11
# 65           J. Fields  0.469137  0.016303  0.774087   21
# 2              A. Luck  0.467828  0.006092  0.970351   59
# 26           C. Keenum  0.465662  0.018460  0.950361   62
# 94          M. Barkley  0.463330  0.093601  0.891172   11
# 107        M. Trubisky  0.462850  0.050553  0.976328   55
# 98            M. Jones  0.458627  0.024447  0.952654   22
# 35            C. Wentz  0.458147  0.027922  0.916731   90

# %%
incorrect.sort_values(by='qb_value', ascending=True).head(20)
# Out:
#       season  week team opponent  score  opponent_score                 qb  \
# 405     2014    14  IND      CLE     25              24            A. Luck
# 4614    2022     6  LAC      DEN     19              16         J. Herbert
# 2408    2018     7   TB      CLE     26              23         J. Winston
# 3207    2019    16   GB      MIN     23              10         A. Rodgers
# 715     2015     6  DEN      CLE     26              23         P. Manning
# 4373    2021    17  PIT      CLE     26              14  B. Roethlisberger
# 1932    2017    10  JAX      LAC     20              17         B. Bortles
# 200     2014     7  JAX      CLE     24               6         B. Bortles
# 1322    2016     8  DEN      LAC     27              19         T. Siemian
# 2858    2019     4   NE      BUF     16              10           T. Brady
# 1367    2016    10  ARI       SF     23              20          C. Palmer
# 3037    2019    10  SEA       SF     27              24          R. Wilson
# 2133    2017    16  PHI       LV     19              10           N. Foles
# 678     2015     5  ATL      WAS     25              19            M. Ryan
# 26      2014     1  PHI      JAX     34              17           N. Foles
# 146     2014     5   NO       TB     37              31           D. Brees
# 1945    2017    10  TEN      CIN     24              20         M. Mariota
# 471     2014    16  HOU      BAL     25              13          C. Keenum
# 4580    2022     5  IND      DEN     12               9            M. Ryan
# 4004    2021     5  PHI      CAR     21              18           J. Hurts
#
#       total_pass_attempts  total_passing_yards  completions  passing_epa  \
# 405                    55                294.0         24.0   -26.402798
# 4614                   57                238.0         37.0   -15.727187
# 2408                   52                365.0         32.0   -10.559706
# 3207                   41                218.0         26.0   -16.766912
# 715                    47                290.0         26.0   -11.036047
# 4373                   46                123.0         24.0   -17.463140
# 1932                   52                275.0         28.0    -8.576179
# 200                    31                159.0         17.0   -20.167440
# 1322                   38                276.0         20.0   -12.338333
# 2858                   39                150.0         18.0   -15.861764
# 1367                   48                376.0         30.0    -6.953930
# 3037                   33                232.0         24.0   -19.248543
# 2133                   38                163.0         19.0   -16.282055
# 678                    43                254.0         24.0    -8.854908
# 26                     44                322.0         27.0   -11.213566
# 146                    58                371.0         35.0    -1.758193
# 1945                   44                264.0         25.0   -10.845867
# 471                    42                185.0         20.0   -10.864660
# 4580                   40                251.0         26.0   -11.034748
# 4004                   38                200.0         22.0   -16.145420
#
#       pass_tds  air_yards  yards_after_catch    air_epa    yac_epa   avg_cpoe  \
# 405        2.0      149.0              145.0   8.997225   8.048368 -12.472804
# 4614       0.0       90.0              148.0 -12.683794  23.828299  -5.279695
# 2408       0.0      276.0               89.0  11.942575   8.444420  -1.898486
# 3207       0.0       71.0              145.0  -6.424846  11.879609  -3.885243
# 715        1.0      146.0              144.0  -0.391160  17.926317  -5.272662
# 4373       1.0       40.0               83.0 -10.386809  15.872578 -15.945429
# 1932       1.0      151.0              122.0   0.758406  18.177588  -8.753787
# 200        1.0       52.0              107.0  -4.476719  13.827379  -9.708472
# 1322       0.0      170.0              106.0   3.924968   8.759214  -6.035019
# 2858       0.0       60.0               90.0  -7.124165  13.268537 -12.735606
# 1367       1.0      282.0               94.0  13.390155   6.663824   0.254406
# 3037       1.0       85.0              147.0   0.785591  11.482067   4.215434
# 2133       1.0       55.0              108.0  -6.524403  15.441836 -11.641945
# 678        0.0      162.0               92.0   9.931152  15.705060  -7.492527
# 26         2.0      183.0              139.0   1.699987  19.193558  -1.086598
# 146        2.0      124.0              247.0  -6.567783  33.441030  -7.000309
# 1945       1.0      163.0              101.0   2.055175  11.928215  -6.212206
# 471        0.0       91.0               94.0  -2.803085  12.445595 -16.216759
# 4580       0.0      138.0              113.0   0.938432  15.604197   2.990805
# 4004       0.0      103.0               95.0  -0.686201   3.217714  -4.926337
#
#          qb_epa  qb_rush_yards  qb_rushing_epa  qb_rush_tds  sacks_taken_qb  \
# 405  -16.615574           37.0        4.855909          1.0             3.0
# 4614 -15.857578            9.0       -0.130391          0.0             2.0
# 2408  -0.197464           56.0        5.528169          1.0             4.0
# 3207  -7.240831            0.0        0.000000          0.0             3.0
# 715  -11.036047            0.0        0.000000          0.0             0.0
# 4373 -17.463140            0.0        0.000000          0.0             2.0
# 1932  -8.912751           34.0       -0.336572          0.0             3.0
# 200  -16.901745           38.0        3.265695          0.0             2.0
# 1322  -9.504921            0.0       -1.251839          0.0             1.0
# 2858 -15.861764            0.0        0.000000          0.0             0.0
# 1367   1.052192           16.0        2.463790          0.0             2.0
# 3037  -9.547621           53.0        3.816448          0.0             5.0
# 2133 -17.229053            0.0       -0.947000          0.0             2.0
# 678   -6.731129           20.0        2.123778          0.0             3.0
# 26   -11.213566            0.0        0.000000          0.0             5.0
# 146   -1.758193            0.0        0.000000          0.0             0.0
# 1945   0.298512           51.0        4.240356          0.0             4.0
# 471   -8.514750           19.0        2.349911          0.0             0.0
# 4580 -12.377019            1.0       -1.342270          0.0             6.0
# 4004  -8.126279           32.0        1.354295          2.0             2.0
#
#       qb_hits_taken_qb  fumbles_qb  lost_fumbles_qb  interceptions_thrown_qb  \
# 405               16.0         2.0              2.0                      2.0
# 4614               8.0         1.0              0.0                      1.0
# 2408               8.0         3.0              2.0                      2.0
# 3207               5.0         3.0              2.0                      1.0
# 715                2.0         0.0              0.0                      3.0
# 4373               4.0         1.0              0.0                      1.0
# 1932              10.0         0.0              0.0                      2.0
# 200                5.0         0.0              0.0                      3.0
# 1322               6.0         3.0              2.0                      1.0
# 2858               4.0         1.0              0.0                      1.0
# 1367               4.0         2.0              2.0                      2.0
# 3037               8.0         2.0              2.0                      1.0
# 2133               6.0         1.0              0.0                      1.0
# 678                5.0         2.0              1.0                      2.0
# 26                 4.0         3.0              2.0                      1.0
# 146                7.0         0.0              0.0                      3.0
# 1945               8.0         1.0              1.0                      1.0
# 471                6.0         1.0              0.0                      1.0
# 4580              11.0         3.0              0.0                      2.0
# 4004               4.0         2.0              1.0                      1.0
#
#       qb_win  qb_win_pred  qb_value
# 405        1            0  0.006092
# 4614       1            0  0.031620
# 2408       1            0  0.041746
# 3207       1            0  0.044708
# 715        1            0  0.047559
# 4373       1            0  0.047989
# 1932       1            0  0.051925
# 200        1            0  0.052099
# 1322       1            0  0.056799
# 2858       1            0  0.061465
# 1367       1            0  0.067802
# 3037       1            0  0.068910
# 2133       1            0  0.070934
# 678        1            0  0.074145
# 26         1            0  0.074176
# 146        1            0  0.081144
# 1945       1            0  0.083845
# 471        1            0  0.087847
# 4580       1            0  0.088077
# 4004       1            0  0.091626

# %%
qb_avg_value.loc['T. Brady']
# Out:
# mean       0.576288
# min        0.021216
# max        0.987878
# count    156.000000
# Name: T. Brady, dtype: float64

# %%
# Look at some of the best qbs by qb value, season by season

qb_avg_value = qb.groupby(by=['qb', 'season']).qb_value.agg(['mean', 'min', 'max', 'count'])
qb_avg_value[150:200]
# Out:
#                         mean       min       max  count
# qb          season
# D. Carr     2014    0.328770  0.020744  0.900151     16
#             2015    0.450489  0.014619  0.878270     16
#             2016    0.564617  0.049800  0.849969     15
#             2017    0.445697  0.050705  0.940715     15
#             2018    0.459415  0.062424  0.921160     16
#             2019    0.595925  0.103022  0.926968     16
#             2020    0.546805  0.019206  0.890079     15
#             2021    0.409106  0.075785  0.909348     18
#             2022    0.467955  0.151353  0.851882      9
# D. Fales    2017    0.348686  0.348686  0.348686      1
# D. Haskins  2019    0.398974  0.094373  0.931893      8
#             2020    0.260869  0.072150  0.636070      7
# D. Hodges   2019    0.510701  0.047746  0.850571      7
# D. Jones    2019    0.328770  0.026914  0.943505     12
#             2020    0.374611  0.110528  0.795903     14
#             2021    0.476362  0.017573  0.751589     11
#             2022    0.613504  0.123300  0.919453      9
# D. Kizer    2017    0.267697  0.010313  0.742074     15
#             2018    0.080995  0.080995  0.080995      1
# D. Lock     2019    0.554209  0.070737  0.931252      5
#             2020    0.335986  0.010020  0.824301     12
#             2021    0.610369  0.319714  0.765958      5
# D. Mills    2021    0.422716  0.020517  0.917523     13
#             2022    0.320783  0.120505  0.544200      8
# D. Orlovsky 2015    0.342620  0.342620  0.342620      1
# D. Prescott 2016    0.699477  0.016560  0.966383     16
#             2017    0.503488  0.016521  0.925939     16
#             2018    0.531292  0.109208  0.824833     18
#             2019    0.568350  0.133600  0.978711     16
#             2020    0.442879  0.238390  0.718513      5
#             2021    0.543547  0.047954  0.979573     17
#             2022    0.487893  0.147478  0.915276      4
# D. Stanton  2014    0.440549  0.105866  0.734149      8
#             2015    0.250946  0.250946  0.250946      1
#             2016    0.470038  0.381549  0.558527      2
#             2017    0.315582  0.207384  0.538100      5
# D. Watson   2017    0.602760  0.147089  0.938853      7
#             2018    0.539384  0.070549  0.962947     17
#             2019    0.571074  0.061761  0.986141     17
#             2020    0.637189  0.200581  0.937460     16
# E. Manning  2014    0.457644  0.018979  0.966151     16
#             2015    0.467722  0.027505  0.951886     16
#             2016    0.362058  0.051054  0.808888     17
#             2017    0.318177  0.022380  0.718487     15
#             2018    0.468410  0.048386  0.915958     16
#             2019    0.340920  0.093940  0.474969      4
# E. Manuel   2014    0.418847  0.042756  0.737097      4
#             2015    0.234596  0.032574  0.436617      2
#             2016    0.398472  0.398472  0.398472      1
#             2017    0.436733  0.260494  0.612972      2

# %%
# Look at games for current season

qb[(qb.season == 2022) & (qb.team == 'GB')]
# Out:
#       season  week team opponent  score  opponent_score          qb  \
# 4450    2022     1   GB      MIN      7              23  A. Rodgers
# 4480    2022     2   GB      CHI     27              10  A. Rodgers
# 4512    2022     3   GB       TB     14              12  A. Rodgers
# 4544    2022     4   GB       NE     27              24  A. Rodgers
# 4578    2022     5   GB      NYG     22              27  A. Rodgers
# 4609    2022     6   GB      NYJ     10              27  A. Rodgers
# 4639    2022     7   GB      WAS     21              23  A. Rodgers
# 4668    2022     8   GB      BUF     17              27  A. Rodgers
# 4697    2022     9   GB      DET      9              15  A. Rodgers
# 4724    2022    10   GB      DAL     31              28  A. Rodgers
# 4743    2022    11   GB      TEN     17              27  A. Rodgers
#
#       total_pass_attempts  total_passing_yards  completions  passing_epa  \
# 4450                   34                195.0         22.0   -11.627544
# 4480                   25                234.0         19.0    11.532071
# 4512                   35                255.0         27.0     0.730554
# 4544                   35                251.0         21.0    -4.546093
# 4578                   39                222.0         25.0     2.820491
# 4609                   41                246.0         26.0   -13.293249
# 4639                   34                194.0         23.0    -2.831697
# 4668                   30                203.0         19.0    -1.400027
# 4697                   44                291.0         23.0   -13.542640
# 4724                   20                224.0         14.0     6.877323
# 4743                   40                229.0         24.0     2.710084
#
#       pass_tds  air_yards  yards_after_catch    air_epa    yac_epa   avg_cpoe  \
# 4450       0.0       61.0              134.0  -6.501235  20.848576  -2.784771
# 4480       2.0      104.0              130.0   3.426131  15.460117   4.686914
# 4512       2.0       77.0              178.0 -13.849911  25.629654  10.921985
# 4544       2.0      123.0              128.0   5.398765   8.992539   0.136496
# 4578       2.0       72.0              150.0  -4.275764  22.607023  -2.485055
# 4609       1.0      146.0              100.0  -1.053414  11.738617  -2.022382
# 4639       2.0      102.0               98.0  -4.338515  12.916915  -3.858410
# 4668       2.0      101.0              102.0   1.322018  11.660726  -0.268133
# 4697       1.0      182.0              109.0   8.121739  15.959337  -4.740061
# 4724       3.0      134.0               90.0  10.976910  10.889734  11.042888
# 4743       2.0      137.0               90.0   8.515738   8.720034  -0.817273
#
#          qb_epa  qb_rush_yards  qb_rushing_epa  qb_rush_tds  sacks_taken_qb  \
# 4450 -11.627544            0.0        0.000000          0.0             4.0
# 4480   7.936544           11.0       -3.595527          0.0             3.0
# 4512   4.507948            0.0        0.000000          0.0             1.0
# 4544   0.181049            1.0       -0.244707          0.0             1.0
# 4578   2.820491            0.0        0.000000          0.0             2.0
# 4609 -18.085117            0.0       -4.791869          0.0             4.0
# 4639  -2.831697            0.0        0.000000          0.0             0.0
# 4668  -0.208485           11.0        1.191543          0.0             2.0
# 4697  -5.769335           41.0        7.773305          0.0             1.0
# 4724   8.209897            7.0        1.332574          0.0             2.0
# 4743   2.710084            0.0        0.000000          0.0             1.0
#
#       qb_hits_taken_qb  fumbles_qb  lost_fumbles_qb  interceptions_thrown_qb  \
# 4450               5.0         1.0              1.0                      1.0
# 4480               4.0         1.0              1.0                      0.0
# 4512               6.0         2.0              1.0                      1.0
# 4544               3.0         2.0              1.0                      1.0
# 4578               6.0         1.0              0.0                      0.0
# 4609               9.0         2.0              1.0                      0.0
# 4639               1.0         1.0              0.0                      0.0
# 4668               4.0         0.0              0.0                      1.0
# 4697               5.0         2.0              0.0                      3.0
# 4724               2.0         1.0              1.0                      0.0
# 4743               3.0         0.0              0.0                      0.0
#
#       qb_win  qb_win_pred  qb_value
# 4450       0            0  0.132762
# 4480       1            1  0.829095
# 4512       1            0  0.482986
# 4544       1            0  0.264927
# 4578       0            1  0.539334
# 4609       0            0  0.081990
# 4639       0            0  0.465794
# 4668       0            0  0.490715
# 4697       0            0  0.051096
# 4724       1            1  0.847139
# 4743       0            1  0.507509
